# %%
import json
import pandas as pd
import numpy as np

# %%
from scipy.spatial.distance import cdist

# %%
with open('offices.json', encoding='utf-8') as f:
    offices = json.load(f)

# %%
kremlin_lat = 55.752
kremlin_lon = 37.618
degree_to_meter = 111319
moscow_rad = 70000 / degree_to_meter
office_latitudes = []
office_longitudes = []
max_people = []
opening_times = [[] for _ in range(7)]
closing_times = [[] for _ in range(7)]
business_morning = [[] for _ in range(7)]
business_day = [[] for _ in range(7)]
business_evening = [[] for _ in range(7)]

# %%
ord_to_day = {0: 'mn', 1: 'ts', 2: 'wd', 3: 'th', 4: 'fr', 5: 'st', 6: 'sn'}
day_to_ord = {'пн': 0, 'вт': 1, 'ср': 2, 'чт': 3, 'пт': 4, 'сб': 5, 'вс': 6}
ans = []
for obj in offices:
    if  'Не' in obj['openHours'][0]['days']:
        continue

    if len(obj['openHours']) == 7:
        ans.append((obj['openHours'] + [float(obj['latitude']), float(obj['longitude'])]).copy())
        continue

    new_dict_list = list()
    for l in obj['openHours']:
        if l["days"] == 'перерыв':
            for i in range(len(new_dict_list)):
                new_dict_list[i]['hours'] = new_dict_list[i]['hours'][:5] + '-' + l['hours'][:5] + ', ' + l['hours'][6:] + '-' + new_dict_list[i]['hours'][6:]
        elif len(l["days"]) > 2:
            s_front = l["days"][:2]
            s_back = l["days"][3:]

            for i in range(day_to_ord[s_front], day_to_ord[s_back] + 1):
                if i + 1 <= len(new_dict_list):
                    continue
                new_dict_list.append({'days': ord_to_day[i], "hours": l["hours"]})
        else:
            new_dict_list.append({"days": l["days"], "hours": l["hours"]})
    ans.append((new_dict_list + [float(obj['latitude']), float(obj['longitude'])]).copy())

# %%
ans
# Out:
# [[{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.184479,
#   36.984314],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   56.183239,
#   36.9757],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.012386,
#   37.482059],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.010849,
#   37.854359],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.008335,
#   37.851467],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.000401,
#   37.208775],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.979717,
#   37.162693],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.947811,
#   37.499382],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.939659,
#   37.516071],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.921768,
#   37.844116],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.918736,
#   37.761627],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.917068,
#   37.995396],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.915436,
#   37.996597],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.915363,
#   36.859612],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.912254,
#   37.868309],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.910648,
#   37.867706],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.904148,
#   37.72485],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.903538,
#   37.71344],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.901184,
#   37.407536],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.900169,
#   37.588306],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.892334,
#   37.440552],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.890957,
#   37.407825],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.888763,
#   37.433525],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.888107,
#   37.66246],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.885498,
#   37.604683],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.868855,
#   37.667446],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.865288,
#   37.661438],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.863358,
#   37.43351],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.862343,
#   37.608948],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.859764,
#   37.121326],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.855362,
#   37.562981],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.854996,
#   37.653389],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.851986,
#   37.443012],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.848015,
#   37.355202],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.847076,
#   37.362152],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.835659,
#   37.490498],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.833855,
#   37.298939],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.833855,
#   37.298939],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.829266,
#   37.451313],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.827133,
#   37.312019],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.818714,
#   37.573502],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.818684,
#   37.497196],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.809105,
#   37.636337],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.807396,
#   37.406281],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.805214,
#   37.508186],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.803135,
#   37.934631],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.802914,
#   37.51889],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.801319,
#   37.634335],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'fr', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:45'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.797817,
#   37.946049],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.797306,
#   37.718723],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.797077,
#   37.725388],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.796345,
#   37.80584],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.796009,
#   37.583389],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.794807,
#   37.967934],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.792191,
#   37.496796],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.79071,
#   37.635178],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.789921,
#   37.677895],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.788677,
#   37.589157],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.788631,
#   37.466789],
#  [{'days': 'mn', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'th', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-14:15, 15:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.787449,
#   37.681145],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.787273,
#   37.600353],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.785767,
#   37.568821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.783611,
#   37.721302],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.783394,
#   37.596867],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.781616,
#   37.632637],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.779068,
#   37.586929],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.778736,
#   37.602024],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.777794,
#   37.465748],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.77433,
#   37.604584],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.773155,
#   37.625908],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.773033,
#   37.675766],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.771809,
#   37.636669],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.770432,
#   37.599194],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.76997,
#   37.669083],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.768871,
#   37.651806],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.766045,
#   37.638081],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.764393,
#   37.556145],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.764275,
#   37.620392],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762936,
#   37.628845],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762936,
#   37.628845],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762119,
#   37.609638],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.761307,
#   37.656288],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.761307,
#   37.656288],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.760258,
#   37.611446],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.759033,
#   37.658295],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.757092,
#   37.595619],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.754257,
#   37.715244],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.754158,
#   37.859192],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.753666,
#   37.577129],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.75259,
#   37.604752],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.750858,
#   37.815983],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749634,
#   37.537434],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749546,
#   38.007694],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749359,
#   37.786266],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.748947,
#   37.65514],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.747784,
#   37.586689],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.746796,
#   37.421307],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.746483,
#   37.682617],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.743633,
#   38.012463],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.740589,
#   37.501286],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737984,
#   37.244133],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737507,
#   37.518379],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737446,
#   37.617958],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737183,
#   37.663952],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.736599,
#   37.5881],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.735596,
#   37.519539],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.734203,
#   37.618866],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.733501,
#   36.853474],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.733055,
#   37.664951],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.731953,
#   37.637085],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.723206,
#   37.603947],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.721241,
#   37.576824],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.721203,
#   37.823063],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.718632,
#   37.788269],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.715729,
#   37.797684],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.714561,
#   37.623833],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.70945,
#   37.661041],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.707363,
#   37.577751],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.692474,
#   37.551727],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'fr', 'hours': '09:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.690491,
#   37.863586],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.690372,
#   37.550655],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.686108,
#   37.303127],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.686005,
#   37.575829],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.685436,
#   37.570122],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.684502,
#   37.621948],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.681713,
#   37.516449],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.681534,
#   37.849888],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.679031,
#   37.283516],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.678787,
#   37.894928],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.677097,
#   37.256618],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.676552,
#   37.891171],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.674576,
#   37.760235],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.663513,
#   37.6054],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:45'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.66169,
#   37.747414],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.660671,
#   37.91338],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.650631,
#   37.394447],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.650505,
#   37.745926],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.629959,
#   37.850281],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.61813,
#   37.507484],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.617748,
#   37.505722],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.612274,
#   37.722126],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.611511,
#   37.71962],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.610489,
#   37.360321],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.608814,
#   37.535412],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.596458,
#   37.599823],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.589993,
#   38.123306],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.573448,
#   38.23138],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.568867,
#   38.226074],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.555126,
#   37.708778],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.547852,
#   37.543255],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.545261,
#   37.708141],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.478329,
#   37.298706],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.43874,
#   37.767536],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.432919,
#   37.550838],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.427883,
#   37.55011],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.421104,
#   38.260525]]

# %%
for elem in ans:
    office_latitudes.append(elem[7])
    office_longitudes.append(elem[8])
    max_people.append(np.random.randint(1000, 3000))
    for i in range(7):
        opening_times[i].append(elem[i]['hours'][:5] if elem[i]['hours'] != 'выходной' else None)
        closing_times[i].append(elem[i]['hours'][-5:] if elem[i]['hours'] != 'выходной' else None)
        business_morning[i].append(round(np.random.uniform(0.01, 0.5), 2))
        business_day[i].append(round(np.random.uniform(0.01, 1), 2))
        business_evening[i].append(round(np.random.uniform(0.01, 0.5), 2))

# %%
len(office_latitudes)
# Out:
# 160

# %%
len(office_longitudes)
# Out:
# 160

# %%
len(max_people)
# Out:
# 160

# %%
for i in range(7):
    print(len(opening_times[i]))
    print(len(closing_times[i]))
    print(len(business_morning[i]))
    print(len(business_day[i]))
    print(len(business_evening[i]))
# Out:
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160

# %%
db = pd.DataFrame()
db['Latitude'] = pd.Series(office_latitudes)

# %%
db
# Out:
#       Latitude
# 0    56.184479
# 1    56.183239
# 2    56.012386
# 3    56.010849
# 4    56.008335
# ..         ...
# 155  55.478329
# 156  55.438740
# 157  55.432919
# 158  55.427883
# 159  55.421104
#
# [160 rows x 1 columns]

# %%
db['Longitude'] = pd.Series(office_longitudes)
db['Max_People'] = pd.Series(max_people)
for i in range(7):
    db[f'opening_{ord_to_day[i]}'] = pd.Series(opening_times[i]).str[:2].fillna(0).astype(int)
    db[f'closing_{ord_to_day[i]}'] = pd.Series(closing_times[i]).str[:2].fillna(0).astype(int)
    db[f'morning_{ord_to_day[i]}'] = pd.Series(business_morning[i])
    db[f'day_{ord_to_day[i]}'] = pd.Series(business_day[i])
    db[f'evening_{ord_to_day[i]}'] = pd.Series(business_evening[i])

# %%
db
# Out:
#       Latitude  Longitude  Max_People  opening_mn  closing_mn  morning_mn  \
# 0    56.184479  36.984314        1119           9          18        0.50
# 1    56.183239  36.975700        1570           9          18        0.27
# 2    56.012386  37.482059        1361          10          19        0.42
# 3    56.010849  37.854359        1730           9          18        0.11
# 4    56.008335  37.851467        2500           9          18        0.26
# ..         ...        ...         ...         ...         ...         ...
# 155  55.478329  37.298706        1416           9          18        0.38
# 156  55.438740  37.767536        2273           9          18        0.21
# 157  55.432919  37.550838        2847           9          18        0.32
# 158  55.427883  37.550110        1081           9          18        0.07
# 159  55.421104  38.260525        2242           9          18        0.25
#
#      day_mn  evening_mn  opening_ts  closing_ts  ...  opening_st  closing_st  \
# 0      0.11        0.15           9          18  ...           0           0
# 1      0.78        0.04           9          18  ...           0           0
# 2      0.72        0.47          10          19  ...           0           0
# 3      0.65        0.38           9          18  ...           0           0
# 4      0.23        0.45           9          18  ...           0           0
# ..      ...         ...         ...         ...  ...         ...         ...
# 155    0.67        0.32           9          18  ...           0           0
# 156    0.80        0.18           9          18  ...           0           0
# 157    0.86        0.08           9          18  ...           0           0
# 158    0.76        0.48           9          18  ...           0           0
# 159    0.56        0.19           9          18  ...           0           0
#
#      morning_st  day_st  evening_st  opening_sn  closing_sn  morning_sn  \
# 0          0.29    0.54        0.38           0           0        0.37
# 1          0.35    0.42        0.37           0           0        0.42
# 2          0.17    0.52        0.16           0           0        0.06
# 3          0.09    0.04        0.04           0           0        0.34
# 4          0.24    0.92        0.20           0           0        0.49
# ..          ...     ...         ...         ...         ...         ...
# 155        0.48    0.17        0.21           0           0        0.25
# 156        0.34    0.53        0.17           0           0        0.12
# 157        0.33    0.21        0.44           0           0        0.48
# 158        0.21    0.05        0.43           0           0        0.45
# 159        0.23    0.12        0.06           0           0        0.49
#
#      day_sn  evening_sn
# 0      0.63        0.04
# 1      0.40        0.36
# 2      0.19        0.34
# 3      0.03        0.14
# 4      0.13        0.24
# ..      ...         ...
# 155    0.48        0.07
# 156    0.64        0.16
# 157    0.41        0.12
# 158    0.10        0.16
# 159    0.03        0.15
#
# [160 rows x 38 columns]

# %%
examples_quantity = 8192
examples = pd.DataFrame()
usr_lat = []
usr_lon = []
days = [np.random.randint(0, 5) for i in range(examples_quantity)]
time = [np.random.uniform(9, 19) for i in range(examples_quantity)]
for i in range(examples_quantity):
    rho = np.random.uniform(0, moscow_rad)
    phi = np.random.uniform(0, 2 * np.pi)
    usr_lat.append(kremlin_lat + rho * np.sin(phi))
    usr_lon.append(kremlin_lon + rho * np.cos(phi))

# %%
examples['Latitude'] = usr_lat
examples['Longitude'] = usr_lon
examples['day'] = days
examples['time'] = time

# %%
examples
# Out:
#        Latitude  Longitude  day       time
# 0     55.278084  37.545769    4  18.360393
# 1     55.964956  37.437843    4  12.927843
# 2     55.545711  37.637862    0  11.504942
# 3     56.218027  37.999053    1  13.414385
# 4     56.309958  37.411617    1   9.926999
# ...         ...        ...  ...        ...
# 8187  55.196264  37.878805    3   9.964708
# 8188  56.178225  37.528902    1  12.723628
# 8189  56.012880  38.069750    0   9.305767
# 8190  55.799446  37.621591    2  18.161057
# 8191  55.187662  37.420491    1  17.706737
#
# [8192 rows x 4 columns]

# %%
db
# Out:
#       Latitude  Longitude  Max_People  opening_mn  closing_mn  morning_mn  \
# 0    56.184479  36.984314        1119           9          18        0.50
# 1    56.183239  36.975700        1570           9          18        0.27
# 2    56.012386  37.482059        1361          10          19        0.42
# 3    56.010849  37.854359        1730           9          18        0.11
# 4    56.008335  37.851467        2500           9          18        0.26
# ..         ...        ...         ...         ...         ...         ...
# 155  55.478329  37.298706        1416           9          18        0.38
# 156  55.438740  37.767536        2273           9          18        0.21
# 157  55.432919  37.550838        2847           9          18        0.32
# 158  55.427883  37.550110        1081           9          18        0.07
# 159  55.421104  38.260525        2242           9          18        0.25
#
#      day_mn  evening_mn  opening_ts  closing_ts  ...  opening_st  closing_st  \
# 0      0.11        0.15           9          18  ...           0           0
# 1      0.78        0.04           9          18  ...           0           0
# 2      0.72        0.47          10          19  ...           0           0
# 3      0.65        0.38           9          18  ...           0           0
# 4      0.23        0.45           9          18  ...           0           0
# ..      ...         ...         ...         ...  ...         ...         ...
# 155    0.67        0.32           9          18  ...           0           0
# 156    0.80        0.18           9          18  ...           0           0
# 157    0.86        0.08           9          18  ...           0           0
# 158    0.76        0.48           9          18  ...           0           0
# 159    0.56        0.19           9          18  ...           0           0
#
#      morning_st  day_st  evening_st  opening_sn  closing_sn  morning_sn  \
# 0          0.29    0.54        0.38           0           0        0.37
# 1          0.35    0.42        0.37           0           0        0.42
# 2          0.17    0.52        0.16           0           0        0.06
# 3          0.09    0.04        0.04           0           0        0.34
# 4          0.24    0.92        0.20           0           0        0.49
# ..          ...     ...         ...         ...         ...         ...
# 155        0.48    0.17        0.21           0           0        0.25
# 156        0.34    0.53        0.17           0           0        0.12
# 157        0.33    0.21        0.44           0           0        0.48
# 158        0.21    0.05        0.43           0           0        0.45
# 159        0.23    0.12        0.06           0           0        0.49
#
#      day_sn  evening_sn
# 0      0.63        0.04
# 1      0.40        0.36
# 2      0.19        0.34
# 3      0.03        0.14
# 4      0.13        0.24
# ..      ...         ...
# 155    0.48        0.07
# 156    0.64        0.16
# 157    0.41        0.12
# 158    0.10        0.16
# 159    0.03        0.15
#
# [160 rows x 38 columns]

# %%
points1 = db.loc[:, ['Latitude', 'Longitude']].values

# %%
points2 = examples.loc[:, ['Latitude', 'Longitude']].values

# %%
distances = cdist(points1, points2)
distances_df = pd.DataFrame(distances, index=db.index, columns=['dist' + str(idx) for idx in examples.index])
distances_df
# Out:
#         dist0     dist1     dist2     dist3     dist4     dist5     dist6  \
# 0    1.066200  0.503864  0.913865  1.015293  0.445345  0.758696  0.764851
# 1    1.069712  0.511100  0.919184  1.023944  0.453961  0.765128  0.771256
# 2    0.737060  0.064843  0.491995  0.556391  0.305796  0.286663  0.293783
# 3    0.795093  0.419037  0.513054  0.252704  0.534310  0.352636  0.355248
# 4    0.791655  0.415893  0.509556  0.256422  0.533334  0.348821  0.351439
# ..        ...       ...       ...       ...       ...       ...       ...
# 155  0.318022  0.506127  0.345784  1.018646  0.839259  0.417596  0.415639
# 156  0.273845  0.620968  0.168102  0.812951  0.941116  0.354094  0.346973
# 157  0.154918  0.543904  0.142461  0.904042  0.888020  0.328657  0.322903
# 158  0.149862  0.548681  0.146915  0.908778  0.892881  0.333741  0.327984
# 159  0.728925  0.986195  0.635009  0.838722  1.229108  0.731266  0.725625
#
#         dist7     dist8     dist9  ...  dist8182  dist8183  dist8184  \
# 0    0.450607  0.976429  0.183994  ...  0.657463  0.850623  0.592302
# 1    0.457494  0.979957  0.190513  ...  0.662863  0.854556  0.594393
# 2    0.118834  0.657343  0.352313  ...  0.283504  0.526574  0.469977
# 3    0.481788  0.745244  0.721278  ...  0.484899  0.650734  0.752318
# 4    0.478654  0.741658  0.718650  ...  0.481086  0.646998  0.748556
# ..        ...       ...       ...  ...       ...       ...       ...
# 155  0.488054  0.235856  0.624197  ...  0.298332  0.171190  0.182728
# 156  0.652673  0.280324  0.900445  ...  0.424007  0.301530  0.597215
# 157  0.555896  0.092840  0.769277  ...  0.310703  0.096913  0.401673
# 158  0.560449  0.088256  0.773135  ...  0.315308  0.099167  0.403593
# 159  1.036600  0.763445  1.303451  ...  0.858719  0.793454  1.078588
#
#      dist8185  dist8186  dist8187  dist8188  dist8189  dist8190  dist8191
# 0    1.230349  0.845541  1.332922  0.544624  1.098917  0.744562  1.088069
# 1    1.233966  0.853115  1.337803  0.553224  1.107234  0.751314  1.090418
# 2    0.880277  0.320090  0.907448  0.172328  0.587692  0.254583  0.827019
# 3    0.887846  0.159072  0.814951  0.365974  0.215401  0.314439  0.930526
# 4    0.884728  0.155422  0.812531  0.364570  0.218331  0.310608  0.926955
# ..        ...       ...       ...       ...       ...       ...       ...
# 155  0.480038  0.617108  0.645039  0.736780  0.938219  0.455380  0.315149
# 156  0.315198  0.436482  0.266787  0.777036  0.648823  0.389113  0.428346
# 157  0.300948  0.494171  0.404435  0.745629  0.778219  0.373294  0.277744
# 158  0.296415  0.499006  0.402104  0.750642  0.782463  0.378376  0.272960
# 159  0.672013  0.667522  0.443016  1.052856  0.621767  0.742549  0.871867
#
# [160 rows x 8192 columns]

# %%
examples['day'].values
# Out:
# array([4, 4, 0, ..., 0, 2, 1], dtype=int64)

# %%
diff_matrix = [[0] * 8192 for _ in range(160)]
days = examples['day'].values
coming = examples['time'].values
for i in range(160):
    for j in range(8192):
        closing_hours = db[f'closing_{ord_to_day[days[j]]}'].values
        diff_matrix[i][j] = 1 / max(closing_hours[i] - coming[j], 0.0001)

# %%
diff_df = pd.DataFrame(diff_matrix, index=db.index, columns=['diff' + str(idx) for idx in examples.index])

# %%
diff_df
# Out:
#        diff0     diff1     diff2     diff3     diff4     diff5     diff6  \
# 0    10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
# 1    10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
# 2    10000.0  0.197155  0.133421  0.179031  0.110217  0.316966  0.140696
# 3    10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
# 4    10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
# ..       ...       ...       ...       ...       ...       ...       ...
# 155  10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
# 156  10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
# 157  10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
# 158  10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
# 159  10000.0  0.245570  0.153963  0.218073  0.123870  0.464057  0.163732
#
#         diff7        diff8     diff9  ...  diff8182      diff8183  diff8184  \
# 0    1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
# 1    1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
# 2    0.644639      3.48606  0.739619  ...  0.105194     29.645424  0.235648
# 3    1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
# 4    1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
# ..        ...          ...       ...  ...       ...           ...       ...
# 155  1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
# 156  1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
# 157  1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
# 158  1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
# 159  1.814041  10000.00000  2.840532  ...  0.117560  10000.000000  0.308298
#
#      diff8185      diff8186  diff8187  diff8188  diff8189      diff8190  \
# 0    0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
# 1    0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
# 2    0.281367      1.417606  0.110677  0.159328  0.103154      1.191976
# 3    0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
# 4    0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
# ..        ...           ...       ...       ...       ...           ...
# 155  0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
# 156  0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
# 157  0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
# 158  0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
# 159  0.391531  10000.000000  0.124451  0.189524  0.115019  10000.000000
#
#      diff8191
# 0    3.409908
# 1    3.409908
# 2    0.773238
# 3    3.409908
# 4    3.409908
# ..        ...
# 155  3.409908
# 156  3.409908
# 157  3.409908
# 158  3.409908
# 159  3.409908
#
# [160 rows x 8192 columns]

# %%
busy_matrix = [[0] * 8192 for _ in range(160)]
days = examples['day'].values
time = examples['time'].values
for i in range(160):
    for j in range(8192):
        if time[j] < 12:
            business = db[f'morning_{ord_to_day[days[j]]}'].values
        elif time[j] > 15:
            business = db[f'evening_{ord_to_day[days[j]]}'].values
        else:
            business = db[f'day_{ord_to_day[days[j]]}'].values
        busy_matrix[i][j] = business[i]

# %%
busy_df = pd.DataFrame(busy_matrix, index=db.index, columns=['busy' + str(idx) for idx in examples.index])

# %%
busy_df
# Out:
#      busy0  busy1  busy2  busy3  busy4  busy5  busy6  busy7  busy8  busy9  \
# 0     0.42   0.96   0.50   0.33   0.04   0.02   0.50   0.15   0.42   0.21
# 1     0.05   0.43   0.27   0.58   0.46   0.26   0.27   0.04   0.05   0.30
# 2     0.38   0.11   0.42   0.32   0.07   0.05   0.42   0.47   0.38   0.36
# 3     0.43   0.69   0.11   0.03   0.06   0.48   0.11   0.38   0.43   0.08
# 4     0.04   0.84   0.26   0.23   0.03   0.11   0.26   0.45   0.04   0.17
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 155   0.25   0.32   0.38   0.33   0.09   0.10   0.38   0.32   0.25   0.27
# 156   0.48   0.49   0.21   0.35   0.38   0.28   0.21   0.18   0.48   0.10
# 157   0.10   0.83   0.32   0.54   0.08   0.24   0.32   0.08   0.10   0.05
# 158   0.49   0.27   0.07   0.06   0.30   0.31   0.07   0.48   0.49   0.17
# 159   0.36   0.88   0.25   0.01   0.16   0.37   0.25   0.19   0.36   0.16
#
#      ...  busy8182  busy8183  busy8184  busy8185  busy8186  busy8187  \
# 0    ...      0.18      0.15      0.33      0.15      0.21      0.18
# 1    ...      0.43      0.04      0.58      0.04      0.30      0.43
# 2    ...      0.49      0.47      0.32      0.47      0.36      0.49
# 3    ...      0.24      0.38      0.03      0.38      0.08      0.24
# 4    ...      0.26      0.45      0.23      0.45      0.17      0.26
# ..   ...       ...       ...       ...       ...       ...       ...
# 155  ...      0.36      0.32      0.33      0.32      0.27      0.36
# 156  ...      0.43      0.18      0.35      0.18      0.10      0.43
# 157  ...      0.08      0.08      0.54      0.08      0.05      0.08
# 158  ...      0.37      0.48      0.06      0.48      0.17      0.37
# 159  ...      0.02      0.19      0.01      0.19      0.16      0.02
#
#      busy8188  busy8189  busy8190  busy8191
# 0        0.33      0.50      0.48      0.02
# 1        0.58      0.27      0.10      0.26
# 2        0.32      0.42      0.28      0.05
# 3        0.03      0.11      0.49      0.48
# 4        0.23      0.26      0.28      0.11
# ..        ...       ...       ...       ...
# 155      0.33      0.38      0.34      0.10
# 156      0.35      0.21      0.08      0.28
# 157      0.54      0.32      0.13      0.24
# 158      0.06      0.07      0.17      0.31
# 159      0.01      0.25      0.28      0.37
#
# [160 rows x 8192 columns]

# %%
vect = []
for i in range(8192):
    dist = distances_df.loc[:, f'dist{i}']
    diff = diff_df.loc[:, f'diff{i}']
    busy = busy_df.loc[:, f'busy{i}']
    result = pd.concat([dist, diff, busy], axis=1, join="outer")
    result = result.sort_values(by=[f'dist{i}', f'diff{i}', f'busy{i}'])
    vect.append(list(result.loc[[result.index[0], result.index[-1]]].values))

# %%
vect
# Out:
# [[array([1.49861636e-01, 1.00000000e+04, 4.90000000e-01]),
#   array([1.06971187e+00, 1.00000000e+04, 5.00000000e-02])],
#  [array([0.06388294, 0.19715477, 0.22      ]),
#   array([0.98619526, 0.24557008, 0.88      ])],
#  [array([0.06342037, 0.13342125, 0.16      ]),
#   array([0.91918404, 0.15396322, 0.27      ])],
#  [array([0.25270365, 0.21807328, 0.03      ]),
#   array([1.24383143, 0.21807328, 0.09      ])],
#  [array([0.30579591, 0.11021712, 0.07      ]),
#   array([1.22910806, 0.12386968, 0.16      ])],
#  [array([0.00424897, 0.3169663 , 0.2       ]),
#   array([0.76759969, 0.46405661, 0.4       ])],
#  [array([0.00927111, 0.16373208, 0.1       ]),
#   array([0.77193203, 0.16373208, 0.49      ])],
#  [array([0.06741139, 0.64463918, 0.32      ]),
#   array([1.03659999, 1.81404121, 0.19      ])],
#  [array([8.82561565e-02, 1.00000000e+04, 4.90000000e-01]),
#   array([9.79957268e-01, 1.00000000e+04, 5.00000000e-02])],
#  [array([0.10469454, 2.8405315 , 0.01      ]),
#   array([1.30345149, 2.8405315 , 0.16      ])],
#  [array([0.25254816, 0.13967944, 0.24      ]),
#   array([0.96758727, 0.13967944, 0.02      ])],
#  [array([0.01003763, 0.30903265, 0.2       ]),
#   array([0.77795102, 0.30903265, 0.13      ])],
#  [array([0.0193495 , 0.15572439, 0.39      ]),
#   array([0.77558934, 0.15572439, 0.16      ])],
#  [array([0.13353403, 0.12538211, 0.41      ]),
#   array([0.99894019, 0.12538211, 0.33      ])],
#  [array([0.05797194, 0.15355308, 0.05      ]),
#   array([1.08244144, 0.15355308, 0.16      ])],
#  [array([0.19969084, 0.12434197, 0.36      ]),
#   array([1.15302562, 0.12434197, 0.02      ])],
#  [array([0.00579073, 0.1961106 , 0.05      ]),
#   array([0.80270892, 0.1961106 , 0.13      ])],
#  [array([0.02348989, 0.34105189, 0.92      ]),
#   array([0.80203048, 0.34105189, 0.43      ])],
#  [array([0.22493924, 0.15041851, 0.04      ]),
#   array([1.05887174, 0.15041851, 0.29      ])],
#  [array([0.08807358, 0.27340404, 0.79      ]),
#   array([1.13380988, 0.27340404, 0.01      ])],
#  [array([0.15988112, 1.40321637, 0.49      ]),
#   array([1.07683725, 1.40321637, 0.05      ])],
#  [array([0.04764906, 0.17690788, 0.39      ]),
#   array([1.15472764, 0.17690788, 0.12      ])],
#  [array([0.17003503, 0.45138613, 0.32      ]),
#   array([0.96936811, 0.45138613, 0.13      ])],
#  [array([0.04363737, 0.22687064, 0.24      ]),
#   array([0.99373374, 0.22687064, 0.78      ])],
#  [array([2.14413679e-01, 1.00000000e+04, 2.80000000e-01]),
#   array([9.22711531e-01, 1.00000000e+04, 6.00000000e-02])],
#  [array([0.00456044, 1.21417755, 0.28      ]),
#   array([0.76992784, 1.21417755, 0.37      ])],
#  [array([0.05809515, 0.2213624 , 1.        ]),
#   array([0.8976067 , 0.28429452, 0.43      ])],
#  [array([0.00518825, 0.49377319, 0.32      ]),
#   array([0.82191027, 0.49377319, 0.28      ])],
#  [array([0.20378706, 0.17165942, 0.11      ]),
#   array([0.91526675, 0.2072329 , 0.88      ])],
#  [array([0.00710072, 0.16119526, 0.03      ]),
#   array([0.82345877, 0.19217257, 0.76      ])],
#  [array([0.00697362, 0.85286888, 0.5       ]),
#   array([0.7911335 , 5.79665873, 0.26      ])],
#  [array([0.04370416, 0.11935623, 0.03      ]),
#   array([0.85546385, 0.13553293, 0.04      ])],
#  [array([6.688349e-02, 1.000000e+04, 1.700000e-01]),
#   array([9.82211431e-01, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.04604964, 0.38099183, 0.13      ]),
#   array([1.08469709, 0.38099183, 0.04      ])],
#  [array([7.30719708e-03, 1.00000000e+04, 3.50000000e-01]),
#   array([7.64100526e-01, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.03451046, 0.22828346, 0.96      ]),
#   array([0.88761234, 0.29581258, 0.56      ])],
#  [array([0.05678739, 6.90777181, 0.08      ]),
#   array([1.11334955, 6.90777181, 0.03      ])],
#  [array([0.02775684, 0.10801492, 0.14      ]),
#   array([0.7960574 , 0.12109498, 0.47      ])],
#  [array([0.25797619, 0.31291948, 0.69      ]),
#   array([1.02838902, 0.31291948, 0.38      ])],
#  [array([5.44649343e-02, 1.00000000e+04, 8.00000000e-02]),
#   array([1.11726771e+00, 1.00000000e+04, 1.00000000e-01])],
#  [array([3.53989464e-01, 1.00000000e+04, 4.30000000e-01]),
#   array([1.06891908e+00, 1.00000000e+04, 3.60000000e-01])],
#  [array([2.15774167e-01, 1.00000000e+04, 4.30000000e-01]),
#   array([9.94537868e-01, 1.00000000e+04, 1.10000000e-01])],
#  [array([0.01854795, 0.25387908, 0.26      ]),
#   array([0.83500319, 0.34026534, 0.11      ])],
#  [array([0.09996298, 0.11322827, 0.11      ]),
#   array([1.20919933, 0.11322827, 0.47      ])],
#  [array([0.23985008, 0.16430286, 0.06      ]),
#   array([1.38708879, 0.16430286, 0.4       ])],
#  [array([0.04063997, 0.25371319, 0.46      ]),
#   array([0.86033696, 0.25371319, 0.56      ])],
#  [array([0.07123606, 0.42735762, 0.1       ]),
#   array([0.92344684, 0.74629059, 0.1       ])],
#  [array([0.19555291, 0.12387588, 0.03      ]),
#   array([1.32639191, 0.12387588, 0.4       ])],
#  [array([0.00274194, 0.12583105, 0.03      ]),
#   array([0.79523235, 0.14394363, 0.13      ])],
#  [array([0.02063915, 0.17945723, 0.57      ]),
#   array([0.81973448, 0.21870551, 0.38      ])],
#  [array([0.01433012, 0.13930244, 0.32      ]),
#   array([0.95140074, 0.1618483 , 0.13      ])],
#  [array([0.00771518, 0.12286371, 0.46      ]),
#   array([0.93180776, 0.12286371, 0.47      ])],
#  [array([0.10440077, 0.26171772, 0.92      ]),
#   array([1.38063598, 0.26171772, 0.13      ])],
#  [array([0.02896848, 2.42598377, 0.04      ]),
#   array([0.99178523, 2.42598377, 0.17      ])],
#  [array([0.14637325, 0.22144382, 0.91      ]),
#   array([1.30458544, 0.22144382, 0.25      ])],
#  [array([0.04056311, 6.4458159 , 0.03      ]),
#   array([0.81412362, 6.4458159 , 0.05      ])],
#  [array([0.03974975, 0.11054468, 0.25      ]),
#   array([0.88016889, 0.12428357, 0.4       ])],
#  [array([0.06063293, 0.29356241, 0.03      ]),
#   array([1.20902038, 0.29356241, 0.5       ])],
#  [array([0.00654968, 0.1489313 , 0.32      ]),
#   array([0.95122796, 0.1489313 , 0.27      ])],
#  [array([0.03397071, 0.13001843, 0.44      ]),
#   array([0.91190575, 0.14944963, 0.46      ])],
#  [array([0.05119464, 0.9407068 , 0.1       ]),
#   array([0.96888279, 0.9407068 , 0.37      ])],
#  [array([0.05671842, 0.26468143, 0.34      ]),
#   array([1.07217116, 0.26468143, 0.38      ])],
#  [array([0.03577521, 0.18511342, 0.22      ]),
#   array([1.03051554, 0.22716465, 0.5       ])],
#  [array([0.12759506, 0.91481714, 0.48      ]),
#   array([1.11199258, 0.91481714, 0.05      ])],
#  [array([6.88205853e-02, 1.00000000e+04, 4.90000000e-01]),
#   array([9.87939683e-01, 1.00000000e+04, 5.00000000e-02])],
#  [array([0.02727958, 0.1441804 , 0.49      ]),
#   array([0.9236015 , 0.16847055, 0.13      ])],
#  [array([0.02060164, 0.42744143, 0.47      ]),
#   array([0.79165868, 0.74654622, 0.11      ])],
#  [array([0.02214171, 0.2806391 , 0.97      ]),
#   array([0.85754627, 0.2806391 , 0.13      ])],
#  [array([0.12326622, 0.16978452, 0.65      ]),
#   array([0.9902553 , 0.16978452, 0.47      ])],
#  [array([0.06946558, 0.12908963, 0.44      ]),
#   array([0.85056037, 0.12908963, 0.13      ])],
#  [array([0.02201805, 0.51121754, 0.08      ]),
#   array([0.85137984, 0.51121754, 0.2       ])],
#  [array([0.0982724 , 0.31416739, 0.39      ]),
#   array([1.15488286, 0.31416739, 0.12      ])],
#  [array([ 0.22327735, 22.20234595,  0.48      ]),
#   array([ 1.12368006, 22.20234595,  0.04      ])],
#  [array([4.99617458e-02, 1.00000000e+04, 2.30000000e-01]),
#   array([8.9899698e-01, 1.0000000e+04, 3.7000000e-01])],
#  [array([0.0085102 , 0.35149497, 0.88      ]),
#   array([0.77505363, 0.35149497, 0.43      ])],
#  [array([0.01626094, 0.45178859, 0.25      ]),
#   array([0.75805758, 0.45178859, 0.38      ])],
#  [array([0.2017647 , 0.13846151, 0.03      ]),
#   array([0.92112421, 0.13846151, 0.4       ])],
#  [array([0.02193216, 0.22696821, 0.54      ]),
#   array([0.86070481, 0.22696821, 0.5       ])],
#  [array([0.03102905, 1.0217396 , 0.03      ]),
#   array([1.00075036, 1.0217396 , 0.28      ])],
#  [array([0.02514258, 0.11789289, 0.26      ]),
#   array([0.89156117, 0.13364918, 0.37      ])],
#  [array([1.55213766e-01, 1.00000000e+04, 8.00000000e-02]),
#   array([9.90919699e-01, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.02717888, 1.13967339, 0.34      ]),
#   array([0.85736359, 1.13967339, 0.26      ])],
#  [array([0.01483961, 0.41081945, 0.16      ]),
#   array([0.84207555, 0.6972726 , 0.05      ])],
#  [array([0.19804698, 0.29421635, 0.03      ]),
#   array([0.97791148, 0.29421635, 0.09      ])],
#  [array([0.05499864, 0.11118577, 0.11      ]),
#   array([1.00806569, 0.1250945 , 0.47      ])],
#  [array([0.23910233, 3.59768712, 0.28      ]),
#   array([1.31616135, 3.59768712, 0.26      ])],
#  [array([0.21518698, 0.34358755, 0.48      ]),
#   array([1.24336698, 0.34358755, 0.23      ])],
#  [array([0.23768434, 0.15061898, 0.32      ]),
#   array([1.13996859, 0.17732793, 0.13      ])],
#  [array([1.08158310e-03, 3.47878906e+00, 5.00000000e-01]),
#   array([7.59176181e-01, 1.00000000e+04, 2.00000000e-01])],
#  [array([0.01990704, 0.23168949, 0.57      ]),
#   array([0.79948234, 0.23168949, 0.12      ])],
#  [array([0.19501089, 0.17483806, 0.51      ]),
#   array([1.28023256, 0.17483806, 1.        ])],
#  [array([0.10921533, 0.1309285 , 0.18      ]),
#   array([1.0237525, 0.1309285, 0.13     ])],
#  [array([9.27708657e-02, 1.00000000e+04, 4.90000000e-01]),
#   array([9.80114181e-01, 1.00000000e+04, 5.00000000e-02])],
#  [array([0.09113323, 0.10488886, 0.18      ]),
#   array([0.99770038, 0.11717971, 0.25      ])],
#  [array([0.0492249 , 0.11082732, 0.42      ]),
#   array([1.01002339, 0.12464094, 0.25      ])],
#  [array([0.16881435, 0.22367722, 0.32      ]),
#   array([0.98566196, 0.22367722, 0.13      ])],
#  [array([0.06629779, 0.20949319, 0.78      ]),
#   array([1.07977351, 0.20949319, 0.88      ])],
#  [array([0.04229854, 0.23832537, 0.56      ]),
#   array([0.9848775 , 0.23832537, 1.        ])],
#  [array([0.00809479, 0.65626036, 0.45      ]),
#   array([0.81499317, 1.90917859, 0.49      ])],
#  [array([0.15695009, 0.40433725, 0.32      ]),
#   array([1.32070683, 0.40433725, 0.35      ])],
#  [array([0.03741272, 0.13310854, 0.41      ]),
#   array([0.99748823, 0.15354696, 0.32      ])],
#  [array([0.03447301, 0.19160326, 0.32      ]),
#   array([0.96695866, 0.23701637, 0.01      ])],
#  [array([0.01318125, 0.56223244, 0.08      ]),
#   array([1.09451472, 0.56223244, 0.23      ])],
#  [array([0.1356505, 0.2837144, 0.4      ]),
#   array([1.15016941, 0.39609117, 0.3       ])],
#  [array([6.37100434e-02, 1.00000000e+04, 4.90000000e-01]),
#   array([1.10229653e+00, 1.00000000e+04, 6.00000000e-02])],
#  [array([0.02086971, 0.52215063, 0.09      ]),
#   array([0.7675321 , 0.52215063, 0.28      ])],
#  [array([0.18181863, 0.13402879, 0.26      ]),
#   array([0.9642263 , 0.13402879, 0.1       ])],
#  [array([0.04553148, 0.52559992, 0.2       ]),
#   array([1.0781769 , 1.10792543, 0.05      ])],
#  [array([0.12735764, 0.24218904, 0.84      ]),
#   array([1.20473489, 0.24218904, 0.58      ])],
#  [array([0.0022725, 0.2398294, 0.42     ]),
#   array([0.75063391, 0.2398294 , 0.25      ])],
#  [array([0.03029924, 6.88942061, 0.29      ]),
#   array([8.41746453e-01, 1.00000000e+04, 1.90000000e-01])],
#  [array([0.24058066, 0.25449244, 0.05      ]),
#   array([1.14057534, 0.34136801, 0.37      ])],
#  [array([0.06259271, 0.14305571, 0.59      ]),
#   array([0.93064083, 0.16693701, 0.23      ])],
#  [array([0.07705483, 0.20828558, 0.23      ]),
#   array([1.11198124, 0.20828558, 0.5       ])],
#  [array([0.02157705, 1.0575795 , 0.5       ]),
#   array([8.6814829e-01, 1.0000000e+04, 3.0000000e-01])],
#  [array([0.14280673, 0.13675744, 0.22      ]),
#   array([1.00069805, 0.13675744, 0.04      ])],
#  [array([8.08301358e-02, 1.00000000e+04, 4.80000000e-01]),
#   array([1.12591918e+00, 1.00000000e+04, 5.00000000e-02])],
#  [array([0.12012806, 0.51044314, 0.28      ]),
#   array([1.09478117, 1.04266364, 0.28      ])],
#  [array([0.03128782, 0.27617562, 0.14      ]),
#   array([0.90978992, 0.3815506 , 0.16      ])],
#  [array([0.01396035, 0.12991179, 0.24      ]),
#   array([0.77903483, 0.14930875, 0.43      ])],
#  [array([0.07102813, 0.20367237, 0.84      ]),
#   array([1.02995812, 0.20367237, 0.47      ])],
#  [array([2.82311426e-01, 1.00000000e+04, 4.90000000e-01]),
#   array([1.1875011e+00, 1.0000000e+04, 5.0000000e-02])],
#  [array([1.26615703e-01, 1.00000000e+04, 3.40000000e-01]),
#   array([1.2700404e+00, 1.0000000e+04, 1.1000000e-01])],
#  [array([0.03115715, 5.4246982 , 0.31      ]),
#   array([0.97578129, 5.4246982 , 0.26      ])],
#  [array([0.0048242 , 0.71906597, 0.16      ]),
#   array([0.78987602, 2.5595545 , 0.17      ])],
#  [array([0.07520895, 1.14053527, 0.43      ]),
#   array([1.19000522, 1.14053527, 0.19      ])],
#  [array([0.17636786, 0.14986506, 0.15      ]),
#   array([1.24219508, 0.14986506, 0.13      ])],
#  [array([0.19228563, 0.65722074, 0.35      ]),
#   array([1.30599808, 0.65722074, 0.04      ])],
#  [array([0.03696501, 0.17309918, 0.21      ]),
#   array([0.96623782, 0.17309918, 0.47      ])],
#  [array([0.09172768, 0.18978566, 0.63      ]),
#   array([0.91392402, 0.18978566, 0.09      ])],
#  [array([0.03483383, 0.12939092, 0.43      ]),
#   array([1.02725226, 0.14862115, 0.13      ])],
#  [array([0.04406824, 0.14066748, 0.07      ]),
#   array([1.18273078, 0.14066748, 0.37      ])],
#  [array([0.01380676, 1.64608834, 0.43      ]),
#   array([8.24465016e-01, 1.00000000e+04, 4.00000000e-02])],
#  [array([0.07264272, 0.24043179, 0.11      ]),
#   array([1.14325678, 0.24043179, 0.76      ])],
#  [array([0.04979772, 0.27178324, 0.58      ]),
#   array([0.93764083, 0.27178324, 0.5       ])],
#  [array([0.12084746, 0.4260627 , 0.05      ]),
#   array([1.12695035, 0.4260627 , 0.28      ])],
#  [array([0.09716706, 0.10259292, 0.26      ]),
#   array([1.05027199, 0.11432149, 0.27      ])],
#  [array([0.07268868, 0.20464388, 0.57      ]),
#   array([1.31205948, 0.20464388, 0.26      ])],
#  [array([ 0.09606199, 51.74278584,  0.34      ]),
#   array([8.51702229e-01, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.01919352, 0.21054237, 0.19      ]),
#   array([0.85562944, 0.21054237, 0.13      ])],
#  [array([0.04304163, 0.4597602 , 0.46      ]),
#   array([0.86705571, 0.4597602 , 0.23      ])],
#  [array([0.07114195, 1.5056188 , 0.34      ]),
#   array([0.92147439, 1.5056188 , 0.28      ])],
#  [array([0.09454442, 0.16803753, 0.62      ]),
#   array([1.00815732, 0.20197729, 0.47      ])],
#  [array([0.17537757, 0.3658243 , 0.47      ]),
#   array([1.14243116, 0.57685008, 0.19      ])],
#  [array([0.02230603, 2.82701459, 0.24      ]),
#   array([8.27601696e-01, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.00959273, 0.22723982, 0.25      ]),
#   array([0.77676211, 0.22723982, 0.5       ])],
#  [array([0.26605999, 0.25581768, 0.03      ]),
#   array([1.03639903, 0.25581768, 0.09      ])],
#  [array([0.10223333, 0.36877468, 0.23      ]),
#   array([1.20636751, 0.36877468, 0.35      ])],
#  [array([0.09952414, 0.11607997, 0.05      ]),
#   array([0.96099868, 0.11607997, 0.32      ])],
#  [array([0.04128998, 0.15919414, 0.2       ]),
#   array([0.88026694, 0.15919414, 0.46      ])],
#  [array([0.24896879, 0.45337114, 0.28      ]),
#   array([1.20509533, 0.82939482, 0.28      ])],
#  [array([0.02423275, 0.36525835, 0.13      ]),
#   array([0.81481405, 0.57544412, 0.16      ])],
#  [array([0.05069124, 0.20811492, 0.03      ]),
#   array([1.06314149, 0.20811492, 0.5       ])],
#  [array([0.00213874, 0.37066091, 0.16      ]),
#   array([0.80730876, 0.37066091, 0.17      ])],
#  [array([0.06780109, 0.25248043, 0.16      ]),
#   array([0.96226533, 0.33775762, 0.11      ])],
#  [array([0.28641175, 0.13256508, 0.38      ]),
#   array([1.32516878, 0.13256508, 0.46      ])],
#  [array([0.00850436, 0.32972907, 0.77      ]),
#   array([1.01733498, 0.32972907, 0.12      ])],
#  [array([0.03971395, 1.28810987, 0.01      ]),
#   array([0.85887354, 1.28810987, 0.37      ])],
#  [array([0.09707342, 0.11434401, 0.4       ]),
#   array([1.21905752, 0.11434401, 0.47      ])],
#  [array([0.03775622, 0.2418364 , 0.59      ]),
#   array([0.87310586, 0.2418364 , 0.23      ])],
#  [array([0.08461277, 0.14607683, 0.46      ]),
#   array([1.21804288, 0.14607683, 0.46      ])],
#  [array([0.20212017, 0.5457058 , 0.48      ]),
#   array([1.13058195, 0.5457058 , 0.04      ])],
#  [array([0.34316994, 0.54686502, 0.38      ]),
#   array([1.08238579, 1.20684796, 0.36      ])],
#  [array([0.00517161, 0.14138538, 0.4       ]),
#   array([0.77622629, 0.16466687, 0.27      ])],
#  [array([0.1955204, 0.1143206, 0.19     ]),
#   array([1.21952077, 0.1143206 , 0.02      ])],
#  [array([0.02623403, 0.30866426, 0.15      ]),
#   array([0.80327285, 0.4464752 , 0.16      ])],
#  [array([0.00897361, 0.49819508, 0.48      ]),
#   array([0.80772366, 0.49819508, 0.2       ])],
#  [array([0.09913949, 0.1084275 , 0.42      ]),
#   array([1.05526374, 0.12161377, 0.25      ])],
#  [array([0.11007934, 0.18512265, 0.13      ]),
#   array([1.3307619 , 0.18512265, 0.13      ])],
#  [array([0.11886714, 0.18057902, 0.84      ]),
#   array([1.27163191, 0.18057902, 0.58      ])],
#  [array([0.00609951, 1.31085832, 0.32      ]),
#   array([1.00232918, 1.31085832, 0.03      ])],
#  [array([0.01207174, 0.94038412, 0.16      ]),
#   array([ 0.77357583, 15.7740537 ,  0.17      ])],
#  [array([0.02425714, 0.55585351, 0.26      ]),
#   array([0.88743575, 1.2515094 , 0.16      ])],
#  [array([0.0617911 , 0.70713828, 0.35      ]),
#   array([0.87098382, 2.41458079, 0.28      ])],
#  [array([ 0.03303823, 19.13396742,  0.33      ]),
#   array([ 1.0403326 , 19.13396742,  0.4       ])],
#  [array([1.27924256e-01, 1.00000000e+04, 3.40000000e-01]),
#   array([1.08567726e+00, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.02575743, 0.17182398, 0.01      ]),
#   array([0.79207705, 0.20747278, 0.43      ])],
#  [array([0.0034722, 0.5326411, 0.24     ]),
#   array([0.79460713, 0.5326411 , 0.37      ])],
#  [array([0.25332015, 0.11984104, 0.3       ]),
#   array([1.1961706 , 0.11984104, 0.46      ])],
#  [array([0.10239895, 1.38315498, 0.28      ]),
#   array([1.09132284, 1.38315498, 0.16      ])],
#  [array([0.0425623 , 0.10077395, 0.38      ]),
#   array([0.8563383 , 0.11206743, 0.33      ])],
#  [array([0.06187002, 0.38351627, 0.95      ]),
#   array([1.27297111, 0.38351627, 0.88      ])],
#  [array([0.03601062, 0.33712981, 0.18      ]),
#   array([0.88270555, 0.508591  , 0.06      ])],
#  [array([0.01672693, 0.20441083, 0.82      ]),
#   array([0.81455724, 0.25693013, 0.58      ])],
#  [array([2.80649592e-01, 1.00000000e+04, 1.80000000e-01]),
#   array([1.36595212e+00, 1.00000000e+04, 4.00000000e-02])],
#  [array([0.04144745, 0.1607444 , 0.34      ]),
#   array([0.89040084, 0.1607444 , 0.46      ])],
#  [array([0.07224074, 0.13745153, 0.36      ]),
#   array([0.892883  , 0.13745153, 0.02      ])],
#  [array([0.00193856, 0.29019087, 0.41      ]),
#   array([0.78566012, 0.29019087, 0.26      ])],
#  [array([0.0249814 , 0.16376151, 0.48      ]),
#   array([0.7807188 , 0.16376151, 0.16      ])],
#  [array([0.05014986, 0.10159933, 0.07      ]),
#   array([0.98873234, 0.1130891 , 0.16      ])],
#  [array([0.03432774, 1.62238295, 0.08      ]),
#   array([0.79247837, 1.62238295, 0.3       ])],
#  [array([0.00547984, 0.21947031, 0.53      ]),
#   array([0.75522092, 0.21947031, 0.47      ])],
#  [array([0.01055915, 0.12319663, 0.32      ]),
#   array([0.77503833, 0.14050656, 0.32      ])],
#  [array([0.02431836, 0.36575846, 0.29      ]),
#   array([0.89977431, 0.57668637, 0.36      ])],
#  [array([0.26513555, 0.15110889, 0.04      ]),
#   array([1.18433337, 0.15110889, 0.29      ])],
#  [array([0.14148311, 0.46799016, 0.08      ]),
#   array([1.25675418, 0.46799016, 0.03      ])],
#  [array([0.15601569, 0.30822881, 0.3       ]),
#   array([1.27542661, 0.30822881, 0.23      ])],
#  [array([0.02879536, 0.13858679, 0.11      ]),
#   array([0.98306438, 0.16088305, 0.47      ])],
#  [array([0.16882447, 0.64516231, 0.16      ]),
#   array([1.38248317, 0.64516231, 0.3       ])],
#  [array([0.07469997, 0.63095778, 0.27      ]),
#   array([0.91253574, 1.70971704, 0.37      ])],
#  [array([0.02509035, 0.20207121, 0.22      ]),
#   array([0.84041063, 0.25324467, 0.01      ])],
#  [array([0.23052709, 1.6629365 , 0.49      ]),
#   array([1.2498487, 1.6629365, 0.06     ])],
#  [array([0.00638479, 0.12292852, 0.07      ]),
#   array([0.77899825, 0.12292852, 0.49      ])],
#  [array([0.02199402, 0.50309349, 0.34      ]),
#   array([1.02874691, 0.50309349, 0.28      ])],
#  [array([0.04318689, 0.26177502, 0.2       ]),
#   array([0.87595692, 0.26177502, 0.78      ])],
#  [array([0.01215335, 0.10917287, 0.36      ]),
#   array([0.8177173 , 0.12255224, 0.4       ])],
#  [array([0.30056712, 0.14468317, 0.22      ]),
#   array([1.01543522, 0.14468317, 0.13      ])],
#  [array([0.04715746, 0.51460589, 0.04      ]),
#   array([0.86280781, 0.51460589, 0.36      ])],
#  [array([3.94202329e-02, 1.00000000e+04, 2.20000000e-01]),
#   array([9.57723666e-01, 1.00000000e+04, 2.30000000e-01])],
#  [array([0.09437571, 0.1184185 , 0.34      ]),
#   array([0.85547861, 0.13432507, 0.22      ])],
#  [array([1.27401913e-01, 1.00000000e+04, 3.80000000e-01]),
#   array([1.07638812e+00, 1.00000000e+04, 1.10000000e-01])],
#  [array([0.12738472, 0.90744291, 0.11      ]),
#   array([0.95725334, 0.90744291, 0.23      ])],
#  [array([0.03221033, 0.15487063, 0.22      ]),
#   array([1.02839253, 0.15487063, 0.37      ])],
#  [array([4.77889762e-02, 1.00000000e+04, 2.30000000e-01]),
#   array([0.884284  , 3.33306732, 0.05      ])],
#  [array([1.94308914e-01, 1.00000000e+04, 3.80000000e-01]),
#   array([1.17104223e+00, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.12610952, 0.81976522, 0.14      ]),
#   array([1.21715205, 0.81976522, 0.3       ])],
#  [array([0.04227755, 0.13514504, 0.15      ]),
#   array([0.869505  , 0.15626324, 0.22      ])],
#  [array([0.09082477, 1.30024111, 0.5       ]),
#   array([1.27412191, 1.30024111, 0.4       ])],
#  [array([0.04479894, 0.17218455, 0.18      ]),
#   array([0.96569685, 0.17218455, 0.13      ])],
#  [array([0.02309522, 0.13920735, 0.37      ]),
#   array([0.80953778, 0.16171995, 0.04      ])],
#  [array([0.00891316, 0.50350519, 0.2       ]),
#   array([0.77581086, 1.01411976, 0.4       ])],
#  [array([1.13022105e-01, 1.00000000e+04, 3.70000000e-01]),
#   array([1.18689317e+00, 1.00000000e+04, 4.00000000e-01])],
#  [array([0.03056396, 7.24809614, 0.32      ]),
#   array([0.84684717, 7.24809614, 0.28      ])],
#  [array([1.99964153e-01, 1.00000000e+04, 8.00000000e-02]),
#   array([1.23998975e+00, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.03508687, 2.93491627, 0.08      ]),
#   array([1.05697719, 2.93491627, 0.1       ])],
#  [array([0.09910648, 0.37132912, 0.35      ]),
#   array([1.29383582, 0.37132912, 0.2       ])],
#  [array([0.0655675 , 2.07809507, 0.3       ]),
#   array([0.91694544, 2.07809507, 0.1       ])],
#  [array([0.00580004, 0.63157734, 0.03      ]),
#   array([0.79246631, 0.63157734, 0.37      ])],
#  [array([0.24939265, 0.89579905, 0.43      ]),
#   array([1.01426534, 0.89579905, 0.11      ])],
#  [array([0.02288618, 0.10626662, 0.42      ]),
#   array([0.77819976, 0.11890193, 0.16      ])],
#  [array([0.03611308, 0.19984409, 0.86      ]),
#   array([0.97250234, 0.19984409, 0.5       ])],
#  [array([0.05765255, 0.14952753, 0.19      ]),
#   array([0.99735641, 0.17581701, 0.29      ])],
#  [array([0.1894686, 0.1764753, 0.72     ]),
#   array([1.11639368, 0.21429265, 0.56      ])],
#  [array([0.20005079, 0.17200192, 0.51      ]),
#   array([1.28572376, 0.17200192, 1.        ])],
#  [array([0.0336981 , 0.32261913, 0.43      ]),
#   array([0.84819029, 0.47627435, 0.04      ])],
#  [array([0.03119379, 0.27590264, 0.39      ]),
#   array([0.96445227, 0.27590264, 0.58      ])],
#  [array([0.06762248, 0.4497198 , 0.44      ]),
#   array([1.19802175, 0.4497198 , 0.37      ])],
#  [array([0.0185783 , 0.13912476, 0.2       ]),
#   array([0.85116354, 0.1616085 , 0.23      ])],
#  [array([0.04716169, 0.18015811, 0.57      ]),
#   array([1.26157519, 0.18015811, 0.26      ])],
#  [array([0.02275908, 0.10629878, 0.3       ]),
#   array([0.83090012, 0.11894218, 0.43      ])],
#  [array([0.06713089, 3.25722253, 0.47      ]),
#   array([1.03085864e+00, 1.00000000e+04, 1.90000000e-01])],
#  [array([0.34561007, 0.12265637, 0.07      ]),
#   array([1.22842629, 0.13980425, 0.22      ])],
#  [array([0.08497131, 0.29496842, 0.46      ]),
#   array([0.83553896, 0.41837617, 0.16      ])],
#  [array([0.12285228, 3.96017965, 0.15      ]),
#   array([1.28820454, 3.96017965, 0.2       ])],
#  [array([0.0305749 , 0.12760473, 0.19      ]),
#   array([0.90260606, 0.12760473, 0.32      ])],
#  [array([0.19110312, 0.13992483, 0.18      ]),
#   array([1.15381485, 0.13992483, 0.13      ])],
#  [array([0.07330234, 0.18201377, 0.12      ]),
#   array([0.86114165, 0.18201377, 0.29      ])],
#  [array([0.18526577, 0.45820224, 0.46      ]),
#   array([0.89299619, 0.45820224, 0.37      ])],
#  [array([0.03861859, 0.54648142, 0.06      ]),
#   array([0.8886667 , 0.54648142, 0.28      ])],
#  [array([1.7074908e-01, 1.0000000e+04, 1.8000000e-01]),
#   array([1.19555946e+00, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.27256917, 0.4638053 , 0.28      ]),
#   array([1.33040458, 0.4638053 , 0.26      ])],
#  [array([0.02241816, 0.26338993, 0.91      ]),
#   array([0.85169623, 0.26338993, 0.69      ])],
#  [array([0.17742843, 0.26787211, 0.28      ]),
#   array([0.89594771, 0.36588158, 0.28      ])],
#  [array([0.06205179, 0.11223681, 0.16      ]),
#   array([1.12113631, 0.12642651, 0.13      ])],
#  [array([0.15560944, 0.13406988, 0.09      ]),
#   array([1.01022715, 0.13406988, 0.16      ])],
#  [array([0.16092453, 0.28989424, 0.97      ]),
#   array([1.32467516, 0.28989424, 0.26      ])],
#  [array([0.2950409, 0.2361671, 0.55     ]),
#   array([1.29895958, 0.2361671 , 0.5       ])],
#  [array([0.05152888, 0.21503012, 0.59      ]),
#   array([1.08642522, 0.27393423, 0.78      ])],
#  [array([0.14635651, 0.12643948, 0.03      ]),
#   array([0.86747938, 0.12643948, 0.4       ])],
#  [array([0.19823083, 0.2841838 , 0.33      ]),
#   array([1.15721234, 0.2841838 , 0.01      ])],
#  [array([2.063253e-02, 1.000000e+04, 3.000000e-02]),
#   array([1.03247434e+00, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.30914967, 0.75730683, 0.48      ]),
#   array([1.10815748, 0.75730683, 0.23      ])],
#  [array([0.02054194, 0.12382047, 0.09      ]),
#   array([0.76157572, 0.12382047, 0.33      ])],
#  [array([0.01994089, 0.15249137, 0.62      ]),
#   array([0.99547297, 0.17992899, 0.47      ])],
#  [array([0.22841115, 0.22126746, 0.43      ]),
#   array([1.24036376, 0.22126746, 0.56      ])],
#  [array([0.09402992, 0.38479501, 0.05      ]),
#   array([1.07113648, 0.62547446, 0.37      ])],
#  [array([0.03156348, 0.14498107, 0.21      ]),
#   array([0.8390783 , 0.16956475, 0.56      ])],
#  [array([0.13741481, 0.75232338, 0.1       ]),
#   array([0.89590853, 0.75232338, 0.26      ])],
#  [array([0.03683522, 0.8972962 , 0.43      ]),
#   array([1.07451424, 0.8972962 , 0.37      ])],
#  [array([0.03222609, 0.5030379 , 0.11      ]),
#   array([0.98738457, 0.5030379 , 0.35      ])],
#  [array([0.07124315, 0.11306996, 0.08      ]),
#   array([0.9971756 , 0.11306996, 0.02      ])],
#  [array([ 0.04516366, 24.10304532,  0.15      ]),
#   array([ 1.08151262, 24.10304532,  0.37      ])],
#  [array([0.04294822, 0.35252158, 0.25      ]),
#   array([1.01247336, 0.35252158, 0.26      ])],
#  [array([0.00289023, 0.34744808, 0.48      ]),
#   array([0.87263631, 0.53244511, 0.28      ])],
#  [array([3.72676205e-02, 1.00000000e+04, 2.90000000e-01]),
#   array([9.76096772e-01, 1.00000000e+04, 1.10000000e-01])],
#  [array([0.0275256 , 0.22770486, 0.81      ]),
#   array([0.92626352, 0.29484176, 0.12      ])],
#  [array([0.05832913, 0.1395616 , 0.1       ]),
#   array([1.36469952, 0.1395616 , 0.46      ])],
#  [array([0.02779747, 0.17359599, 0.91      ]),
#   array([0.83703526, 0.17359599, 0.47      ])],
#  [array([0.01479222, 0.27017565, 0.68      ]),
#   array([1.15442212, 0.27017565, 0.38      ])],
#  [array([0.06660124, 1.08383374, 0.48      ]),
#   array([1.13021561, 1.08383374, 0.05      ])],
#  [array([0.20886081, 0.14092828, 0.22      ]),
#   array([1.10575582, 0.14092828, 0.04      ])],
#  [array([0.0261442 , 0.16571105, 0.32      ]),
#   array([0.91705698, 0.19862548, 0.13      ])],
#  [array([0.2160698 , 1.75139799, 0.49      ]),
#   array([1.17166726, 1.75139799, 0.06      ])],
#  [array([5.81163209e-02, 1.00000000e+04, 4.00000000e-02]),
#   array([1.25448583e+00, 1.00000000e+04, 1.60000000e-01])],
#  [array([0.00705314, 0.25160102, 0.2       ]),
#   array([0.77350552, 0.33618568, 0.4       ])],
#  [array([0.3167374 , 0.11921439, 0.41      ]),
#   array([1.03264101, 0.11921439, 0.22      ])],
#  [array([0.00236038, 0.52427611, 0.14      ]),
#   array([0.78337303, 0.52427611, 0.04      ])],
#  [array([0.19727471, 0.35095907, 0.05      ]),
#   array([0.97249008, 0.54073487, 0.37      ])],
#  [array([0.30363938, 1.37976095, 0.17      ]),
#   array([1.22414888, 1.37976095, 0.1       ])],
#  [array([0.06538114, 0.19998602, 0.11      ]),
#   array([1.14538022, 0.19998602, 0.76      ])],
#  [array([0.02283971, 0.8022518 , 0.27      ]),
#   array([0.75880129, 0.8022518 , 0.11      ])],
#  [array([0.12328945, 0.13068913, 0.32      ]),
#   array([1.09929317, 0.15033647, 0.13      ])],
#  [array([0.02720059, 0.11484507, 0.4       ]),
#   array([0.9527655 , 0.12974573, 0.13      ])],
#  [array([0.05492995, 0.43667389, 0.27      ]),
#   array([0.96386551, 0.43667389, 0.16      ])],
#  [array([8.80629363e-02, 1.00000000e+04, 1.80000000e-01]),
#   array([1.03259125e+00, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.03913705, 0.59841371, 0.07      ]),
#   array([0.80180995, 1.49012488, 0.36      ])],
#  [array([0.03745331, 0.19351985, 0.06      ]),
#   array([0.9713997 , 0.19351985, 0.58      ])],
#  [array([8.99921953e-03, 1.00000000e+04, 8.00000000e-02]),
#   array([9.40848399e-01, 1.00000000e+04, 4.00000000e-02])],
#  [array([0.01012114, 0.17535747, 0.01      ]),
#   array([0.81968717, 0.17535747, 0.29      ])],
#  [array([0.04724695, 0.23433359, 0.22      ]),
#   array([1.05827292, 0.30605181, 0.5       ])],
#  [array([0.03622459, 0.21625746, 0.55      ]),
#   array([1.06551072, 0.21625746, 0.5       ])],
#  [array([0.02331662, 0.17908664, 0.43      ]),
#   array([0.79918988, 0.17908664, 0.29      ])],
#  [array([0.05463563, 0.11156689, 0.19      ]),
#   array([0.99438719, 0.12557714, 0.29      ])],
#  [array([0.02156516, 0.30789842, 0.16      ]),
#   array([0.76785849, 0.30789842, 0.88      ])],
#  [array([0.04083763, 0.11125461, 0.13      ]),
#   array([0.9002044 , 0.12518165, 0.32      ])],
#  [array([0.01507557, 0.16084223, 0.13      ]),
#   array([0.92316224, 0.19167103, 0.29      ])],
#  [array([0.02317322, 0.55838785, 0.21      ]),
#   array([0.8668145 , 1.26443046, 0.04      ])],
#  [array([1.47672652e-02, 1.00000000e+04, 4.90000000e-01]),
#   array([8.16534419e-01, 1.00000000e+04, 3.00000000e-01])],
#  [array([0.2406537 , 2.16821212, 0.17      ]),
#   array([1.16836284, 2.16821212, 0.3       ])],
#  [array([0.04011234, 0.28282736, 0.62      ]),
#   array([0.9971256 , 0.28282736, 0.47      ])],
#  [array([0.12249401, 0.21218043, 0.35      ]),
#   array([1.1671719 , 0.21218043, 0.58      ])],
#  [array([0.00387839, 0.20898875, 0.71      ]),
#   array([0.80588844, 0.20898875, 1.        ])],
#  [array([0.12528317, 0.2685999 , 0.86      ]),
#   array([1.26809113, 0.2685999 , 0.09      ])],
#  [array([0.02281797, 0.12474561, 0.37      ]),
#   array([0.76636609, 0.14252497, 0.04      ])],
#  [array([0.02346015, 0.10970563, 0.39      ]),
#   array([0.91533088, 0.12322399, 0.46      ])],
#  [array([0.0202671 , 0.14837003, 0.27      ]),
#   array([0.89084111, 0.17421889, 0.5       ])],
#  [array([0.2274552 , 0.55249817, 0.28      ]),
#   array([1.26995592, 0.55249817, 0.26      ])],
#  [array([0.14285176, 0.63604597, 0.31      ]),
#   array([0.99007435, 0.63604597, 0.26      ])],
#  [array([0.26968639, 1.32468774, 0.48      ]),
#   array([1.29346146, 1.32468774, 0.05      ])],
#  [array([0.05798897, 0.23804919, 0.69      ]),
#   array([0.86593699, 0.23804919, 0.12      ])],
#  [array([0.04556258, 0.12632389, 0.14      ]),
#   array([0.82141086, 0.12632389, 0.32      ])],
#  [array([0.03090852, 0.27246902, 0.8       ]),
#   array([0.80580483, 0.37451192, 0.43      ])],
#  [array([0.15982825, 0.3409761 , 0.43      ]),
#   array([1.20913881, 0.3409761 , 0.19      ])],
#  [array([0.04938518, 0.71813827, 0.12      ]),
#   array([1.07736791, 0.71813827, 0.11      ])],
#  [array([0.04526769, 1.62757605, 0.06      ]),
#   array([1.02157841, 1.62757605, 0.37      ])],
#  [array([0.06632627, 3.56937161, 0.46      ]),
#   array([0.88690062, 3.56937161, 0.23      ])],
#  [array([0.01470958, 0.39475659, 0.45      ]),
#   array([0.95350534, 0.65222783, 0.3       ])],
#  [array([0.11421091, 3.74764326, 0.28      ]),
#   array([1.14762992, 3.74764326, 0.26      ])],
#  [array([0.11740492, 0.24595589, 0.9       ]),
#   array([1.26513862, 0.24595589, 0.78      ])],
#  [array([0.17460926, 0.4952858 , 0.32      ]),
#   array([1.12944384, 0.4952858 , 0.88      ])],
#  [array([0.21854284, 0.15822539, 0.32      ]),
#   array([1.08572539, 0.18796645, 0.13      ])],
#  [array([0.08072185, 0.16408301, 0.42      ]),
#   array([1.10873326, 0.16408301, 0.22      ])],
#  [array([0.00750514, 0.10745169, 0.2       ]),
#   array([0.77944217, 0.12038754, 0.16      ])],
#  [array([0.13766229, 0.4624731 , 0.38      ]),
#   array([1.17534527, 0.4624731 , 0.11      ])],
#  [array([0.01502194, 0.10632212, 0.16      ]),
#   array([0.86728009, 0.11897141, 0.27      ])],
#  [array([0.18343977, 0.25166125, 0.47      ]),
#   array([0.91168617, 0.33629323, 0.19      ])],
#  [array([4.2529687e-02, 1.0000000e+04, 2.7000000e-01]),
#   array([1.15820582e+00, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.24402489, 0.16771717, 0.65      ]),
#   array([1.16621888, 0.16771717, 0.43      ])],
#  [array([0.27234605, 0.28898228, 0.06      ]),
#   array([1.16599024, 0.28898228, 0.58      ])],
#  [array([0.0175595 , 0.13700129, 0.08      ]),
#   array([0.80091539, 0.15875028, 0.22      ])],
#  [array([0.09001419, 0.3464141 , 0.35      ]),
#   array([1.11162514, 0.53002077, 0.1       ])],
#  [array([0.00465253, 0.61454787, 0.11      ]),
#   array([0.81304176, 0.61454787, 0.2       ])],
#  [array([4.66660553e-02, 1.00000000e+04, 4.20000000e-01]),
#   array([0.9010892, 2.5953968, 0.11     ])],
#  [array([0.22030861, 0.64878351, 0.49      ]),
#   array([1.10507075, 0.64878351, 0.06      ])],
#  [array([0.00967147, 0.37146158, 0.08      ]),
#   array([0.78050542, 0.59099264, 0.05      ])],
#  [array([0.03239797, 0.10166236, 0.04      ]),
#   array([0.96923074, 0.1131672 , 0.25      ])],
#  [array([0.23225332, 0.11238861, 0.07      ]),
#   array([1.01221327, 0.11238861, 0.27      ])],
#  [array([0.0601602 , 0.28883316, 0.64      ]),
#   array([1.05965112, 0.28883316, 0.56      ])],
#  [array([0.26779508, 0.11263674, 0.06      ]),
#   array([1.2277709 , 0.11263674, 0.4       ])],
#  [array([8.01042784e-03, 1.00000000e+04, 3.40000000e-01]),
#   array([7.93230677e-01, 1.00000000e+04, 4.00000000e-02])],
#  [array([0.00883144, 0.1565656 , 0.76      ]),
#   array([0.7924088 , 0.18562867, 0.26      ])],
#  [array([0.01300085, 0.15057081, 0.49      ]),
#   array([0.85888318, 0.15057081, 0.23      ])],
#  [array([0.05097326, 0.11783228, 0.46      ]),
#   array([0.96595281, 0.11783228, 0.47      ])],
#  [array([0.23185983, 0.13906103, 0.21      ]),
#   array([1.30444027, 0.13906103, 0.27      ])],
#  [array([0.14439135, 6.69945885, 0.17      ]),
#   array([0.90999978, 6.69945885, 0.1       ])],
#  [array([0.03023982, 0.49496299, 0.3       ]),
#   array([0.86328877, 0.49496299, 0.1       ])],
#  [array([0.16446902, 0.11697111, 0.43      ]),
#   array([1.25129877, 0.11697111, 0.43      ])],
#  [array([0.04156264, 1.06198436, 0.43      ]),
#   array([1.12092438, 1.06198436, 0.2       ])],
#  [array([0.0486163 , 0.29351816, 0.5       ]),
#   array([0.88648904, 0.41546456, 0.3       ])],
#  [array([0.02649448, 0.86254034, 0.45      ]),
#   array([0.77807723, 6.27486154, 0.37      ])],
#  [array([0.07673645, 0.2206746 , 0.36      ]),
#   array([0.92601939, 0.28316106, 1.        ])],
#  [array([0.07781661, 0.12490916, 0.42      ]),
#   array([0.96144913, 0.1427385 , 0.25      ])],
#  [array([ 0.21392563, 15.59551018,  0.1       ]),
#   array([ 1.17734747, 15.59551018,  0.37      ])],
#  [array([0.00239115, 0.25927281, 0.42      ]),
#   array([0.75080935, 0.25927281, 0.26      ])],
#  [array([0.03829114, 0.94902168, 0.17      ]),
#   array([0.95933637, 0.94902168, 0.3       ])],
#  [array([0.05438579, 0.28789257, 0.65      ]),
#   array([1.17884198, 0.28789257, 0.23      ])],
#  [array([0.16792461, 0.45339055, 0.18      ]),
#   array([1.25479243, 0.45339055, 0.04      ])],
#  [array([0.06597065, 0.13398557, 0.42      ]),
#   array([0.93362197, 0.15471517, 0.25      ])],
#  [array([0.27068873, 0.20587986, 0.06      ]),
#   array([1.21182886, 0.20587986, 0.58      ])],
#  [array([0.01263658, 0.23478511, 0.56      ]),
#   array([0.83620441, 0.30682245, 0.38      ])],
#  [array([1.56949382e-02, 1.75632513e+01, 2.50000000e-01]),
#   array([7.80627131e-01, 1.00000000e+04, 1.10000000e-01])],
#  [array([0.01852569, 0.30790798, 0.28      ]),
#   array([1.19883108, 0.30790798, 0.88      ])],
#  [array([0.00918335, 0.12186585, 0.16      ]),
#   array([0.78471288, 0.13877818, 0.32      ])],
#  [array([0.02825  , 0.1294662, 0.39     ]),
#   array([1.00364541, 0.14872048, 0.16      ])],
#  [array([0.05012913, 0.15409186, 0.24      ]),
#   array([1.0204272 , 0.15409186, 0.32      ])],
#  [array([0.0495734 , 0.81275349, 0.3       ]),
#   array([0.87622836, 0.81275349, 0.11      ])],
#  [array([0.19354884, 0.12158085, 0.15      ]),
#   array([1.22297811, 0.12158085, 0.43      ])],
#  [array([0.00169182, 0.11444585, 0.08      ]),
#   array([0.7643089 , 0.11444585, 0.46      ])],
#  [array([0.06815802, 0.55785168, 0.18      ]),
#   array([0.86883541, 1.26168448, 0.37      ])],
#  [array([0.10025878, 0.13208056, 0.05      ]),
#   array([1.03566172, 0.13208056, 0.32      ])],
#  [array([0.13611994, 0.15267164, 0.38      ]),
#   array([0.89645141, 0.15267164, 0.27      ])],
#  [array([0.13256669, 0.177921  , 0.72      ]),
#   array([0.93253077, 0.2164281 , 0.56      ])],
#  [array([0.17444315, 0.24930476, 0.76      ]),
#   array([1.27428379, 0.24930476, 0.47      ])],
#  [array([0.00530621, 0.11595435, 0.04      ]),
#   array([0.76730407, 0.11595435, 0.23      ])],
#  [array([0.11068256, 0.20400306, 0.65      ]),
#   array([1.10738825, 0.20400306, 0.43      ])],
#  [array([0.00995759, 0.50708665, 0.25      ]),
#   array([0.7732989 , 0.50708665, 0.26      ])],
#  [array([0.1493324 , 0.76458192, 0.34      ]),
#   array([0.91697551, 0.76458192, 0.1       ])],
#  [array([0.00623044, 0.19097755, 0.22      ]),
#   array([0.75322648, 0.19097755, 0.78      ])],
#  [array([0.04788824, 0.57231181, 0.34      ]),
#   array([0.99291586, 0.57231181, 0.28      ])],
#  [array([0.01426097, 0.232859  , 0.46      ]),
#   array([0.82179602, 0.232859  , 0.56      ])],
#  [array([0.03386024, 1.32708493, 0.47      ]),
#   array([0.86729883, 1.32708493, 0.36      ])],
#  [array([0.03030549, 0.6366546 , 0.02      ]),
#   array([1.17293194, 0.6366546 , 0.36      ])],
#  [array([0.33372055, 0.22851732, 0.69      ]),
#   array([1.04742508, 0.22851732, 0.47      ])],
#  [array([0.16702487, 0.29259394, 0.59      ]),
#   array([0.89576088, 0.29259394, 0.23      ])],
#  [array([0.01300074, 0.1376558 , 0.25      ]),
#   array([0.78677235, 0.1376558 , 0.13      ])],
#  [array([0.02463407, 0.1624877 , 0.27      ]),
#   array([0.84489884, 0.1624877 , 0.13      ])],
#  [array([7.72923332e-03, 1.00000000e+04, 1.30000000e-01]),
#   array([8.19218777e-01, 1.00000000e+04, 1.70000000e-01])],
#  [array([0.06087146, 0.16032558, 0.14      ]),
#   array([1.08553961, 0.16032558, 0.4       ])],
#  [array([0.02202105, 0.11926086, 0.17      ]),
#   array([1.01481319, 0.11926086, 0.16      ])],
#  [array([2.24748641e-01, 1.00000000e+04, 4.80000000e-01]),
#   array([1.32852093e+00, 1.00000000e+04, 5.00000000e-02])],
#  [array([8.95273534e-03, 1.00000000e+04, 2.50000000e-01]),
#   array([8.2254366e-01, 1.0000000e+04, 4.9000000e-01])],
#  [array([0.02437888, 0.27616412, 0.51      ]),
#   array([1.05473553, 0.27616412, 0.76      ])],
#  [array([5.37267942e-02, 1.00000000e+04, 5.00000000e-01]),
#   array([1.27538928e+00, 1.00000000e+04, 4.00000000e-01])],
#  [array([0.11211438, 2.86516588, 0.25      ]),
#   array([1.07417943, 2.86516588, 0.36      ])],
#  [array([0.14817326, 6.9733805 , 0.04      ]),
#   array([1.24029104, 6.9733805 , 0.16      ])],
#  [array([0.01492544, 0.26390798, 0.53      ]),
#   array([0.76996571, 0.26390798, 0.26      ])],
#  [array([0.26228651, 0.13165385, 0.11      ]),
#   array([1.18340641, 0.13165385, 0.1       ])],
#  [array([0.01130773, 0.24590508, 0.73      ]),
#   array([0.76942487, 0.326093  , 0.47      ])],
#  [array([0.07581138, 0.25090894, 0.96      ]),
#   array([1.13839204, 0.25090894, 0.43      ])],
#  [array([0.02541953, 0.30190763, 0.32      ]),
#   array([0.95271489, 0.30190763, 0.88      ])],
#  [array([0.05799285, 0.14336736, 0.32      ]),
#   array([1.34485967, 0.14336736, 0.49      ])],
#  [array([0.04301312, 0.18425356, 0.47      ]),
#   array([1.14436541, 0.18425356, 0.04      ])],
#  [array([0.0281415 , 0.22868867, 0.56      ]),
#   array([0.95497985, 0.22868867, 0.38      ])],
#  [array([0.06903985, 1.02357373, 0.44      ]),
#   array([0.88025828, 1.02357373, 0.11      ])],
#  [array([1.24916992e-01, 1.00000000e+04, 4.90000000e-01]),
#   array([1.00884225e+00, 1.00000000e+04, 5.00000000e-02])],
#  [array([0.01465491, 0.17612042, 0.73      ]),
#   array([0.80760564, 0.21376961, 0.43      ])],
#  [array([0.00377272, 0.28598638, 0.47      ]),
#   array([0.83133626, 0.40053352, 0.88      ])],
#  [array([0.09549873, 0.18698686, 0.34      ]),
#   array([1.03692911, 0.18698686, 0.13      ])],
#  [array([0.13977094, 0.82651002, 0.48      ]),
#   array([1.01023335, 0.82651002, 0.23      ])],
#  [array([0.0850892 , 6.25846303, 0.4       ]),
#   array([1.08906009e+00, 1.00000000e+04, 3.00000000e-01])],
#  [array([0.10332724, 0.25955447, 0.56      ]),
#   array([0.83865701, 0.35053823, 0.38      ])],
#  [array([0.08596094, 0.11024908, 0.39      ]),
#   array([0.89908297, 0.12391005, 0.02      ])],
#  [array([0.12861476, 0.12566093, 0.42      ]),
#   array([1.09598064, 0.12566093, 0.16      ])],
#  [array([0.09747581, 0.59826664, 0.01      ]),
#   array([1.37534111, 0.59826664, 0.04      ])],
#  [array([0.08275375, 0.30246538, 0.9       ]),
#   array([1.02713944, 0.30246538, 0.5       ])],
#  [array([0.00696597, 0.53860678, 0.34      ]),
#   array([0.7913576, 1.1673487, 0.05     ])],
#  [array([7.50896685e-02, 1.00000000e+04, 4.90000000e-01]),
#   array([1.01832497e+00, 1.00000000e+04, 5.00000000e-02])],
#  [array([0.02722157, 0.17560337, 0.44      ]),
#   array([0.98498064, 0.17560337, 0.13      ])],
#  [array([0.04478829, 0.41734341, 0.28      ]),
#   array([0.9939698 , 0.71627681, 0.28      ])],
#  [array([0.00927029, 0.31313902, 0.38      ]),
#   array([0.94357133, 0.45589869, 0.88      ])],
#  [array([0.04689419, 0.1243816 , 0.16      ]),
#   array([1.06636574, 0.1243816 , 0.25      ])],
#  [array([0.00697044, 0.20133634, 0.55      ]),
#   array([1.07991173, 0.20133634, 0.5       ])],
#  [array([3.1271834e-02, 1.0000000e+04, 9.0000000e-02]),
#   array([8.12680006e-01, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.01626373, 0.22545593, 0.21      ]),
#   array([0.94652882, 0.29108212, 0.56      ])],
#  [array([0.01229017, 0.2131576 , 0.53      ]),
#   array([0.80852412, 0.2131576 , 1.        ])],
#  [array([0.03293371, 0.12762785, 0.45      ]),
#   array([1.05984935, 0.12762785, 0.13      ])],
#  [array([0.06920217, 0.60689402, 0.26      ]),
#   array([0.87529135, 1.54384324, 0.19      ])],
#  [array([0.04553271, 1.36278126, 0.17      ]),
#   array([0.89771477, 1.36278126, 0.17      ])],
#  [array([0.01182488, 2.67154249, 0.35      ]),
#   array([0.77125889, 2.67154249, 0.49      ])],
#  [array([0.00909511, 0.10604264, 0.39      ]),
#   array([0.78771467, 0.11862159, 0.46      ])],
#  [array([0.04982089, 0.93398059, 0.43      ]),
#   array([ 0.86575036, 14.14705989,  0.04      ])],
#  [array([0.09152864, 0.26503014, 0.67      ]),
#   array([1.02556345, 0.26503014, 0.56      ])],
#  [array([0.00086226, 0.48738708, 0.03      ]),
#   array([0.76191716, 0.48738708, 0.35      ])],
#  [array([0.03844115, 0.69722634, 0.05      ]),
#   array([0.96065002, 2.30279718, 0.37      ])],
#  [array([0.19676647, 0.16944385, 0.8       ]),
#   array([1.24874347, 0.16944385, 0.78      ])],
#  [array([0.01277202, 0.12525049, 0.21      ]),
#   array([1.07636777, 0.12525049, 0.46      ])],
#  [array([1.98071445e-02, 1.00000000e+04, 3.50000000e-01]),
#   array([9.54737893e-01, 1.00000000e+04, 5.00000000e-02])],
#  [array([5.67823994e-02, 1.00000000e+04, 1.40000000e-01]),
#   array([9.1027212e-01, 1.0000000e+04, 5.0000000e-02])],
#  [array([0.02084683, 0.87564121, 0.47      ]),
#   array([0.83416375, 7.04124893, 0.1       ])],
#  [array([9.20919629e-03, 1.00000000e+04, 1.00000000e-01]),
#   array([1.07534753e+00, 1.00000000e+04, 1.70000000e-01])],
#  [array([0.006729  , 0.16347593, 0.03      ]),
#   array([0.78412151, 0.16347593, 0.22      ])],
#  [array([1.11763258e-01, 1.00000000e+04, 7.00000000e-02]),
#   array([1.06422178e+00, 1.00000000e+04, 1.90000000e-01])],
#  [array([0.07840845, 0.11093822, 0.09      ]),
#   array([0.90278974, 0.12478122, 0.16      ])],
#  [array([0.20565693, 1.83812767, 0.49      ]),
#   array([1.15955999, 1.83812767, 0.06      ])],
#  [array([0.01871665, 0.73026206, 0.33      ]),
#   array([0.76537265, 0.73026206, 0.16      ])],
#  [array([0.02683955, 0.18934986, 0.77      ]),
#   array([0.89748936, 0.23357778, 0.69      ])],
#  [array([0.05000559, 0.280522  , 0.69      ]),
#   array([0.88341979, 0.280522  , 0.12      ])],
#  [array([0.06103598, 0.12850661, 0.21      ]),
#   array([1.13499963, 0.12850661, 0.46      ])],
#  [array([0.0994096 , 0.14699022, 0.46      ]),
#   array([1.36171449, 0.14699022, 0.49      ])],
#  [array([3.04376274e-02, 1.00000000e+04, 1.10000000e-01]),
#   array([9.91466121e-01, 1.00000000e+04, 3.50000000e-01])],
#  [array([0.02831971, 0.19292855, 0.37      ]),
#   array([1.10840207, 0.19292855, 0.5       ])],
#  [array([0.06322052, 0.21607229, 0.75      ]),
#   array([0.92287855, 0.21607229, 0.43      ])],
#  [array([0.10545306, 0.26659375, 0.7       ]),
#   array([1.13666499, 0.26659375, 0.88      ])],
#  [array([0.00443942, 0.63659958, 0.09      ]),
#   array([0.77973977, 0.63659958, 0.1       ])],
#  [array([0.0683044 , 0.20723336, 0.84      ]),
#   array([0.81755427, 0.26140524, 0.01      ])],
#  [array([0.05589253, 0.11314265, 0.45      ]),
#   array([0.89473687, 0.12757705, 0.16      ])],
#  [array([1.45657675e-01, 1.00000000e+04, 4.50000000e-01]),
#   array([8.76700435e-01, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.06167809, 0.11445006, 0.28      ]),
#   array([1.09013132, 0.11445006, 0.25      ])],
#  [array([1.86432751e-01, 1.00000000e+04, 4.80000000e-01]),
#   array([1.31315223e+00, 1.00000000e+04, 5.00000000e-02])],
#  [array([0.23275111, 0.13026656, 0.38      ]),
#   array([1.00488743, 0.13026656, 0.46      ])],
#  [array([0.03616093, 0.24099574, 0.83      ]),
#   array([1.01781149, 0.24099574, 0.01      ])],
#  [array([0.1603195 , 0.26349562, 0.39      ]),
#   array([1.17593949, 0.26349562, 0.12      ])],
#  [array([ 0.01186078, 10.85000452,  0.06      ]),
#   array([ 0.78509149, 10.85000452,  0.17      ])],
#  [array([0.03985831, 0.14962571, 0.37      ]),
#   array([0.95622871, 0.17595277, 0.47      ])],
#  [array([0.02128767, 0.14644726, 0.29      ]),
#   array([0.78471907, 0.17157376, 0.76      ])],
#  [array([0.18281476, 5.72328721, 0.31      ]),
#   array([0.97212494, 5.72328721, 0.26      ])],
#  [array([0.03329001, 0.24596751, 0.22      ]),
#   array([1.00161743, 0.32620281, 0.5       ])],
#  [array([0.06003794, 0.19599965, 0.91      ]),
#   array([1.22353388, 0.19599965, 0.25      ])],
#  [array([0.03004906, 0.76976732, 0.35      ]),
#   array([0.94898245, 3.34343206, 0.19      ])],
#  [array([0.03263578, 1.92598228, 0.44      ]),
#   array([9.11404158e-01, 1.00000000e+04, 1.70000000e-01])],
#  [array([0.04308078, 0.26341033, 0.9       ]),
#   array([0.99245393, 0.26341033, 0.23      ])],
#  [array([0.0690479 , 0.17862016, 0.63      ]),
#   array([1.2732091 , 0.17862016, 0.12      ])],
#  [array([8.09938026e-02, 1.00000000e+04, 4.30000000e-01]),
#   array([1.05356092e+00, 1.00000000e+04, 1.10000000e-01])],
#  [array([0.00689079, 0.18959319, 0.21      ]),
#   array([0.81566812, 0.23394816, 0.38      ])],
#  [array([1.62126205e-02, 1.00000000e+04, 3.70000000e-01]),
#   array([7.95422886e-01, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.00309889, 0.11154736, 0.04      ]),
#   array([0.83974751, 0.11154736, 0.46      ])],
#  [array([0.11381605, 0.10061202, 0.07      ]),
#   array([1.09015654, 0.11186721, 0.22      ])],
#  [array([0.06170888, 0.40950823, 0.23      ]),
#   array([1.09903251, 0.40950823, 0.28      ])],
#  [array([0.02245425, 0.11468335, 0.02      ]),
#   array([0.77634375, 0.12953936, 0.02      ])],
#  [array([0.15096033, 0.12385582, 0.42      ]),
#   array([1.10534142, 0.14136465, 0.25      ])],
#  [array([0.16251495, 0.15761987, 0.16      ]),
#   array([1.24071605, 0.15761987, 0.02      ])],
#  [array([0.0391935 , 0.71406771, 0.12      ]),
# ...
#  [array([0.03707598, 0.2659201 , 0.04      ]),
#   array([0.81774642, 0.2659201 , 0.58      ])],
#  [array([0.01895192, 0.58729255, 0.14      ]),
#   array([0.88611702, 1.42302386, 0.49      ])],
#  [array([0.17618937, 0.56632356, 0.31      ]),
#   array([0.97746741, 0.56632356, 0.26      ])],
#  [array([0.01788211, 0.16083793, 0.24      ]),
#   array([0.84061814, 0.19166492, 0.23      ])],
#  [array([0.07835303, 0.10921885, 0.41      ]),
#   array([1.10550259, 0.12261019, 0.32      ])],
#  [array([0.0099347 , 0.72721332, 0.22      ]),
#   array([0.93225291, 0.72721332, 0.23      ])],
#  [array([0.09972892, 0.27542214, 0.9       ]),
#   array([1.02825645, 0.27542214, 0.12      ])],
#  [array([0.13923855, 2.93649392, 0.04      ]),
#   array([1.26334234, 2.93649392, 0.16      ])],
#  [array([0.19641574, 0.25401454, 0.47      ]),
#   array([1.09395523, 0.3405087 , 0.19      ])],
#  [array([0.21116226, 0.16350669, 0.03      ]),
#   array([1.30819875, 0.16350669, 0.4       ])],
#  [array([0.26371658, 1.30153823, 0.32      ]),
#   array([1.03376614, 1.30153823, 0.04      ])],
#  [array([0.05565508, 0.3043303 , 0.89      ]),
#   array([1.01136917, 0.3043303 , 0.23      ])],
#  [array([0.02949485, 0.21899858, 0.23      ]),
#   array([0.80965924, 0.21899858, 0.12      ])],
#  [array([0.18362352, 0.22854608, 0.11      ]),
#   array([1.27414388, 0.22854608, 0.76      ])],
#  [array([0.1840317 , 0.76494173, 0.32      ]),
#   array([1.0911132 , 0.76494173, 0.19      ])],
#  [array([0.02579228, 0.81301019, 0.2       ]),
#   array([1.03156379, 4.34788495, 0.05      ])],
#  [array([0.09030079, 0.11539882, 0.03      ]),
#   array([1.16282352, 0.11539882, 0.4       ])],
#  [array([0.09062993, 0.14728351, 0.06      ]),
#   array([1.23638169, 0.14728351, 0.4       ])],
#  [array([0.09732637, 0.13550314, 0.41      ]),
#   array([1.14332018, 0.13550314, 0.46      ])],
#  [array([0.02994834, 0.11822444, 0.1       ]),
#   array([0.85890189, 0.11822444, 0.32      ])],
#  [array([0.01992597, 0.17551309, 0.55      ]),
#   array([1.01238612, 0.17551309, 0.56      ])],
#  [array([7.92235739e-02, 1.00000000e+04, 8.00000000e-02]),
#   array([9.53723235e-01, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.00200178, 0.72588727, 0.12      ]),
#   array([0.93153695, 0.72588727, 0.1       ])],
#  [array([0.01090088, 2.24736644, 0.04      ]),
#   array([0.77861253, 2.24736644, 0.2       ])],
#  [array([0.36323174, 0.15183007, 0.32      ]),
#   array([1.11428648, 0.17900902, 0.13      ])],
#  [array([0.11673914, 0.1935592 , 0.75      ]),
#   array([1.33111312, 0.1935592 , 0.01      ])],
#  [array([0.03037967, 0.165673  , 0.19      ]),
#   array([0.85335269, 0.165673  , 0.13      ])],
#  [array([0.25457537, 0.43270804, 0.1       ]),
#   array([1.2886651 , 0.43270804, 0.3       ])],
#  [array([0.1641006 , 0.16486626, 0.23      ]),
#   array([1.32767741, 0.16486626, 0.29      ])],
#  [array([0.09162893, 0.20676429, 0.12      ]),
#   array([1.2173275 , 0.20676429, 0.69      ])],
#  [array([0.0576657 , 0.20638822, 0.37      ]),
#   array([1.14151375, 0.20638822, 0.5       ])],
#  [array([0.07361017, 0.16726265, 0.23      ]),
#   array([0.98222051, 0.16726265, 0.09      ])],
#  [array([0.00261857, 0.17237889, 0.74      ]),
#   array([0.80301408, 0.17237889, 0.26      ])],
#  [array([0.02570994, 0.21837875, 0.89      ]),
#   array([0.77026261, 0.27939203, 0.43      ])],
#  [array([0.02807445, 0.16651274, 0.23      ]),
#   array([1.03693543, 0.16651274, 0.46      ])],
#  [array([0.0202901 , 0.11399394, 0.46      ]),
#   array([0.99449997, 0.11399394, 0.25      ])],
#  [array([7.72957193e-03, 1.08264485e+01, 5.00000000e-01]),
#   array([8.07250182e-01, 1.00000000e+04, 2.60000000e-01])],
#  [array([0.03797618, 0.21060237, 0.43      ]),
#   array([0.90018187, 0.21060237, 0.26      ])],
#  [array([0.05157224, 0.41787994, 0.06      ]),
#   array([1.02826266, 0.71785867, 0.28      ])],
#  [array([0.01527466, 0.32217883, 0.32      ]),
#   array([0.76984863, 0.47531538, 0.37      ])],
#  [array([0.27272133, 0.17513997, 0.56      ]),
#   array([1.38581879, 0.17513997, 0.78      ])],
#  [array([0.17916336, 0.13197975, 0.11      ]),
#   array([1.22123356, 0.13197975, 0.16      ])],
#  [array([0.1240899 , 0.10722749, 0.07      ]),
#   array([1.09210449, 0.12010617, 0.22      ])],
#  [array([0.01462561, 0.27659823, 0.6       ]),
#   array([0.77087005, 0.27659823, 0.56      ])],
#  [array([0.10058043, 0.19909186, 0.28      ]),
#   array([0.84799383, 0.24858264, 0.12      ])],
#  [array([0.01079479, 0.12989644, 0.23      ]),
#   array([0.93403447, 0.14928848, 0.16      ])],
#  [array([0.02330481, 0.16913416, 0.75      ]),
#   array([0.98130577, 0.20356374, 0.69      ])],
#  [array([0.0517148 , 0.25163548, 0.03      ]),
#   array([0.80740593, 0.33624721, 0.19      ])],
#  [array([0.01274546, 0.14140378, 0.03      ]),
#   array([0.79330409, 0.14140378, 0.22      ])],
#  [array([0.04702661, 0.85555559, 0.1       ]),
#   array([0.91302698, 0.85555559, 0.05      ])],
#  [array([0.05314343, 0.17974706, 0.63      ]),
#   array([1.27365249, 0.17974706, 0.12      ])],
#  [array([0.00639915, 0.1852833 , 0.08      ]),
#   array([0.9433764 , 0.22742052, 0.25      ])],
#  [array([0.01278616, 0.21150736, 0.73      ]),
#   array([0.78181089, 0.26824266, 0.47      ])],
#  [array([1.99334815e-01, 1.00000000e+04, 1.00000000e-01]),
#   array([1.14263734e+00, 1.00000000e+04, 3.70000000e-01])],
#  [array([9.92066357e-04, 1.00000000e+04, 4.90000000e-01]),
#   array([8.25374113e-01, 1.00000000e+04, 1.70000000e-01])],
#  [array([0.00855946, 0.10397509, 0.03      ]),
#   array([0.8069708, 0.1160404, 0.43     ])],
#  [array([0.07919826, 0.19965039, 0.81      ]),
#   array([1.05799803, 0.19965039, 0.23      ])],
#  [array([0.01588775, 0.14957772, 0.45      ]),
#   array([0.95178744, 0.14957772, 0.29      ])],
#  [array([3.08291668e-02, 1.00000000e+04, 3.90000000e-01]),
#   array([8.19201477e-01, 1.00000000e+04, 1.90000000e-01])],
#  [array([0.14609351, 0.43532377, 0.3       ]),
#   array([0.87836888, 0.43532377, 0.11      ])],
#  [array([0.03343018, 0.3777996 , 0.49      ]),
#   array([0.90821645, 0.60719922, 0.49      ])],
#  [array([0.00353323, 0.85971822, 0.45      ]),
#   array([0.78390896, 6.1285095 , 0.37      ])],
#  [array([0.12799114, 0.20448644, 0.13      ]),
#   array([0.9227212 , 0.20448644, 0.76      ])],
#  [array([0.13887768, 1.09176193, 0.27      ]),
#   array([0.98012743, 1.09176193, 0.16      ])],
#  [array([0.01115348, 0.22628178, 0.23      ]),
#   array([0.7563798, 0.2924602, 1.       ])],
#  [array([0.05779625, 0.61639031, 0.5       ]),
#   array([0.89593224, 1.60681633, 0.3       ])],
#  [array([0.0614696 , 0.34886424, 0.33      ]),
#   array([1.37582659, 0.34886424, 0.4       ])],
#  [array([0.02404689, 0.1652697 , 0.35      ]),
#   array([0.81082923, 0.1652697 , 0.22      ])],
#  [array([0.22004167, 0.1453842 , 0.43      ]),
#   array([1.29063969, 0.1453842 , 0.43      ])],
#  [array([0.01882818, 0.11160625, 0.11      ]),
#   array([1.05313662, 0.11160625, 0.1       ])],
#  [array([0.00937344, 0.10592364, 0.43      ]),
#   array([0.77473525, 0.1184727 , 0.46      ])],
#  [array([0.04998883, 0.48938597, 0.04      ]),
#   array([1.18628232, 0.48938597, 0.11      ])],
#  [array([0.17180042, 0.21528332, 0.97      ]),
#   array([1.31310634, 0.21528332, 0.23      ])],
#  [array([0.13534994, 0.65714619, 0.1       ]),
#   array([1.22097241, 0.65714619, 0.3       ])],
#  [array([5.33293169e-02, 1.00000000e+04, 4.80000000e-01]),
#   array([1.07833022e+00, 1.00000000e+04, 2.30000000e-01])],
#  [array([0.01575352, 0.17782635, 0.05      ]),
#   array([0.81302724, 0.17782635, 0.13      ])],
#  [array([0.00386169, 0.15234034, 0.56      ]),
#   array([0.78305637, 0.17971875, 0.01      ])],
#  [array([0.00618964, 0.21884188, 0.88      ]),
#   array([1.03520828, 0.21884188, 0.01      ])],
#  [array([0.13488283, 0.32706545, 0.56      ]),
#   array([0.99722316, 0.32706545, 1.        ])],
#  [array([0.05477315, 1.34126681, 0.48      ]),
#   array([1.00951086, 1.34126681, 0.1       ])],
#  [array([0.08578018, 0.15768038, 0.48      ]),
#   array([1.14621803, 0.15768038, 0.29      ])],
#  [array([0.1665752 , 0.49250823, 0.28      ]),
#   array([1.0431206 , 0.97047532, 0.28      ])],
#  [array([0.09407559, 0.11842056, 0.07      ]),
#   array([0.99496386, 0.11842056, 0.27      ])],
#  [array([0.02676507, 0.3850302 , 0.24      ]),
#   array([0.95632633, 0.62609611, 0.11      ])],
#  [array([0.0405705 , 0.13445166, 0.24      ]),
#   array([0.87471536, 0.15533698, 0.23      ])],
#  [array([0.02348837, 0.13702878, 0.24      ]),
#   array([0.89061121, 0.1587872 , 0.23      ])],
#  [array([0.07484368, 0.15708712, 0.32      ]),
#   array([1.04532103, 0.18636222, 0.13      ])],
#  [array([0.29695721, 3.31325534, 0.36      ]),
#   array([1.06214814e+00, 1.00000000e+04, 1.60000000e-01])],
#  [array([0.03883033, 0.36974267, 0.34      ]),
#   array([0.94728811, 0.36974267, 0.28      ])],
#  [array([0.24405568, 0.1094268 , 0.07      ]),
#   array([1.18703416, 0.12287233, 0.16      ])],
#  [array([0.02819117, 0.24381065, 0.63      ]),
#   array([0.98390165, 0.24381065, 0.01      ])],
#  [array([0.0547686 , 0.12175767, 0.31      ]),
#   array([0.86973615, 0.1386379 , 0.27      ])],
#  [array([0.00207586, 0.18948709, 0.23      ]),
#   array([0.87301188, 0.23378664, 0.56      ])],
#  [array([0.03156365, 0.7433373 , 0.08      ]),
#   array([0.77761781, 0.7433373 , 0.3       ])],
#  [array([0.01918957, 0.32713678, 0.56      ]),
#   array([0.935369  , 0.32713678, 0.38      ])],
#  [array([0.02742398, 0.16282263, 0.29      ]),
#   array([0.85356437, 0.16282263, 0.13      ])],
#  [array([0.01618685, 0.61891621, 0.03      ]),
#   array([0.78826356, 0.61891621, 0.05      ])],
#  [array([0.0073374 , 0.15217873, 0.03      ]),
#   array([0.79883415, 0.17949389, 0.13      ])],
#  [array([0.15402533, 0.16644031, 0.35      ]),
#   array([1.28158153, 0.16644031, 0.22      ])],
#  [array([0.01082111, 0.31119658, 0.36      ]),
#   array([0.7751454 , 0.45179302, 0.2       ])],
#  [array([0.11859667, 0.16676547, 0.68      ]),
#   array([1.14481857, 0.2001423 , 1.        ])],
#  [array([0.13786945, 0.14577921, 0.22      ]),
#   array([1.08656036, 0.14577921, 0.04      ])],
#  [array([0.06336906, 0.3738826 , 0.3       ]),
#   array([0.95236932, 0.59714457, 0.37      ])],
#  [array([0.04038029, 0.12684774, 0.11      ]),
#   array([0.97165345, 0.14527563, 0.47      ])],
#  [array([0.03817904, 0.12567462, 0.41      ]),
#   array([1.32884512, 0.12567462, 0.46      ])],
#  [array([0.07151101, 0.13895417, 0.15      ]),
#   array([1.3021688 , 0.13895417, 0.16      ])],
#  [array([0.29399047, 3.361991  , 0.17      ]),
#   array([1.2304617, 3.361991 , 0.1      ])],
#  [array([0.00980082, 0.1378788 , 0.1       ]),
#   array([0.80298601, 0.1378788 , 0.49      ])],
#  [array([0.1812456 , 0.12167592, 0.49      ]),
#   array([0.89687187, 0.13853192, 0.02      ])],
#  [array([0.01042821, 0.41703662, 0.16      ]),
#   array([0.80718086, 0.71537362, 0.1       ])],
#  [array([0.02582178, 0.43512577, 0.08      ]),
#   array([0.8175082 , 0.77030559, 0.19      ])],
#  [array([0.0414565 , 0.12290886, 0.16      ]),
#   array([0.86977983, 0.14013237, 0.25      ])],
#  [array([0.00852638, 0.11079652, 0.08      ]),
#   array([0.80810428, 0.12460199, 0.46      ])],
#  [array([0.06581317, 0.12915831, 0.21      ]),
#   array([1.05783282, 0.12915831, 0.27      ])],
#  [array([0.00867939, 0.14622629, 0.1       ]),
#   array([0.76629999, 0.14622629, 0.27      ])],
#  [array([2.65879722e-02, 1.00000000e+04, 8.00000000e-02]),
#   array([9.04398837e-01, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.06683373, 0.28086052, 0.26      ]),
#   array([0.87740285, 0.39055082, 0.19      ])],
#  [array([0.10013427, 0.50017122, 0.07      ]),
#   array([0.85239215, 0.50017122, 0.06      ])],
#  [array([0.02311295, 0.12966108, 0.35      ]),
#   array([0.76967909, 0.14897769, 0.1       ])],
#  [array([0.12373639, 0.4302776 , 0.18      ]),
#   array([1.20915967, 0.4302776 , 0.04      ])],
#  [array([0.12525607, 0.18093324, 0.91      ]),
#   array([1.25859319, 0.18093324, 0.09      ])],
#  [array([0.00848555, 0.20397221, 0.33      ]),
#   array([0.75817335, 0.20397221, 0.58      ])],
#  [array([0.02850235, 0.11087622, 0.12      ]),
#   array([0.96026998, 0.12470279, 0.02      ])],
#  [array([0.13594893, 0.12269396, 0.41      ]),
#   array([1.30052297, 0.12269396, 0.23      ])],
#  [array([0.2078334 , 0.12936272, 0.1       ]),
#   array([1.04785492, 0.12936272, 0.1       ])],
#  [array([0.0801236, 0.1399191, 0.34     ]),
#   array([0.8390177 , 0.16268133, 0.16      ])],
#  [array([0.04106359, 0.14168436, 0.3       ]),
#   array([1.01509492, 0.14168436, 0.04      ])],
#  [array([0.01775706, 0.26134669, 0.43      ]),
#   array([0.80375402, 0.3538151 , 0.06      ])],
#  [array([0.15205409, 0.13426935, 0.38      ]),
#   array([1.23776363, 0.13426935, 0.46      ])],
#  [array([0.02993905, 0.18004096, 0.2       ]),
#   array([0.87980507, 0.18004096, 0.78      ])],
#  [array([2.06645014e-01, 1.00000000e+04, 8.00000000e-02]),
#   array([1.25891029e+00, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.03158891, 3.77470298, 0.48      ]),
#   array([0.86091807, 3.77470298, 0.3       ])],
#  [array([0.08807541, 0.66323397, 0.23      ]),
#   array([1.35227215, 0.66323397, 0.1       ])],
#  [array([0.15751168, 0.13751465, 0.27      ]),
#   array([1.2195169 , 0.13751465, 0.29      ])],
#  [array([0.23155318, 0.77738434, 0.48      ]),
#   array([1.15037197, 0.77738434, 0.04      ])],
#  [array([0.10293085, 0.11434457, 0.32      ]),
#   array([1.07840096, 0.12910729, 0.13      ])],
#  [array([3.02378908e-01, 1.00000000e+04, 3.80000000e-01]),
#   array([1.05575499e+00, 1.00000000e+04, 1.10000000e-01])],
#  [array([0.07770311, 0.1168616 , 0.03      ]),
#   array([1.11103666, 0.1168616 , 0.4       ])],
#  [array([1.25176498e-01, 1.00000000e+04, 4.00000000e-01]),
#   array([1.32075156e+00, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.08561073, 0.30814348, 0.65      ]),
#   array([0.99230584, 0.30814348, 0.47      ])],
#  [array([0.06291822, 1.93523787, 0.48      ]),
#   array([1.02396642, 1.93523787, 0.05      ])],
#  [array([0.0138247, 0.1441283, 0.17     ]),
#   array([0.81504895, 0.1441283 , 0.27      ])],
#  [array([0.02148343, 0.1559252 , 0.43      ]),
#   array([0.78657132, 0.1559252 , 0.29      ])],
#  [array([0.01273409, 0.12317867, 0.02      ]),
#   array([0.77903763, 0.14048321, 0.13      ])],
#  [array([0.04259079, 0.213947  , 0.19      ]),
#   array([0.89128486, 0.27217885, 0.26      ])],
#  [array([0.00629922, 0.15883936, 0.38      ]),
#   array([0.77882792, 0.15883936, 0.13      ])],
#  [array([0.01140992, 1.51126562, 0.15      ]),
#   array([0.81395787, 1.51126562, 0.17      ])],
#  [array([0.10088543, 0.12328875, 0.41      ]),
#   array([1.18103151, 0.12328875, 0.37      ])],
#  [array([0.03136388, 0.24227937, 0.83      ]),
#   array([0.82082308, 0.24227937, 0.01      ])],
#  [array([0.16340917, 0.10236407, 0.42      ]),
#   array([1.12059931, 0.11403741, 0.25      ])],
#  [array([0.30003451, 1.03744006, 0.38      ]),
#   array([1.24597166e+00, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.04207946, 0.49455071, 0.44      ]),
#   array([1.03860578, 0.97843782, 0.26      ])],
#  [array([0.02244678, 0.32356594, 0.38      ]),
#   array([0.99284994, 0.47834069, 0.2       ])],
#  [array([0.0445835 , 0.11448005, 0.13      ]),
#   array([1.00388809, 0.11448005, 0.4       ])],
#  [array([0.0536903 , 0.22563952, 0.65      ]),
#   array([0.83410744, 0.22563952, 0.01      ])],
#  [array([7.09533789e-02, 1.00000000e+04, 4.00000000e-02]),
#   array([1.23563134e+00, 1.00000000e+04, 4.00000000e-01])],
#  [array([0.10085651, 0.2267503 , 0.56      ]),
#   array([0.92809391, 0.2267503 , 0.38      ])],
#  [array([ 0.06547994, 14.94740725,  0.04      ]),
#   array([ 1.15566905, 14.94740725,  0.06      ])],
#  [array([0.10505258, 0.32550069, 0.27      ]),
#   array([0.9038998 , 0.32550069, 0.43      ])],
#  [array([0.06880689, 0.19918987, 0.9       ]),
#   array([1.25119148, 0.19918987, 0.13      ])],
#  [array([0.02514583, 0.21937564, 0.9       ]),
#   array([0.81801467, 0.21937564, 0.01      ])],
#  [array([0.01820403, 0.11341364, 0.26      ]),
#   array([1.31228675, 0.11341364, 0.37      ])],
#  [array([0.0085456 , 0.17105086, 0.85      ]),
#   array([0.79556846, 0.20634663, 1.        ])],
#  [array([0.18458211, 0.2102497 , 0.25      ]),
#   array([1.2537321, 0.2102497, 0.01     ])],
#  [array([0.04049186, 0.10396011, 0.42      ]),
#   array([0.93975629, 0.11602175, 0.25      ])],
#  ...]

# %%
X = np.reshape(np.array(vect), (-1, 3))

# %%
y = np.reshape(np.array([[0, 1] for _ in range(8192)]), (8192*2))

# %%
y = np.reshape(y, 8192*2)

# %%
from skopt import BayesSearchCV
from sklearn.datasets import load_digits
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, test_size=.25, random_state=0)

# log-uniform: understand as search over p = exp(x) by varying x
opt = BayesSearchCV(
    SVC(),
    {
        'C': (1e-6, 1e+6, 'log-uniform'),
        'gamma': (1e-6, 1e+1, 'log-uniform'),
        'degree': (1, 8),  # integer valued parameter
        'kernel': ['linear', 'poly', 'rbf'],  # categorical parameter
    },
    n_iter=32,
    cv=3
)

opt.fit(X_train, y_train)

print("val. score: %s" % opt.best_score_)
print("test score: %s" % opt.score(X_test, y_test))
