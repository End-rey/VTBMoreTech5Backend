# %%
import json
import pandas as pd
import numpy as np

# %%
from scipy.spatial.distance import cdist

# %%
with open('offices.json', encoding='utf-8') as f:
    offices = json.load(f)

# %%
kremlin_lat = 55.752
kremlin_lon = 37.618
degree_to_meter = 111319
moscow_rad = 70000 / degree_to_meter
office_latitudes = []
office_longitudes = []
max_people = []
opening_times = [[] for _ in range(7)]
closing_times = [[] for _ in range(7)]
business_morning = [[] for _ in range(7)]
business_day = [[] for _ in range(7)]
business_evening = [[] for _ in range(7)]

# %%
ord_to_day = {0: 'mn', 1: 'ts', 2: 'wd', 3: 'th', 4: 'fr', 5: 'st', 6: 'sn'}
day_to_ord = {'пн': 0, 'вт': 1, 'ср': 2, 'чт': 3, 'пт': 4, 'сб': 5, 'вс': 6}
ans = []
for obj in offices:
    if  'Не' in obj['openHours'][0]['days']:
        continue

    if len(obj['openHours']) == 7:
        ans.append((obj['openHours'] + [float(obj['latitude']), float(obj['longitude'])]).copy())
        continue

    new_dict_list = list()
    for l in obj['openHours']:
        if l["days"] == 'перерыв':
            for i in range(len(new_dict_list)):
                new_dict_list[i]['hours'] = new_dict_list[i]['hours'][:5] + '-' + l['hours'][:5] + ', ' + l['hours'][6:] + '-' + new_dict_list[i]['hours'][6:]
        elif len(l["days"]) > 2:
            s_front = l["days"][:2]
            s_back = l["days"][3:]

            for i in range(day_to_ord[s_front], day_to_ord[s_back] + 1):
                if i + 1 <= len(new_dict_list):
                    continue
                new_dict_list.append({'days': ord_to_day[i], "hours": l["hours"]})
        else:
            new_dict_list.append({"days": l["days"], "hours": l["hours"]})
    ans.append((new_dict_list + [float(obj['latitude']), float(obj['longitude'])]).copy())

# %%
ans
# Out:
# [[{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.184479,
#   36.984314],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   56.183239,
#   36.9757],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.012386,
#   37.482059],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.010849,
#   37.854359],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.008335,
#   37.851467],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.000401,
#   37.208775],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.979717,
#   37.162693],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.947811,
#   37.499382],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.939659,
#   37.516071],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.921768,
#   37.844116],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.918736,
#   37.761627],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.917068,
#   37.995396],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.915436,
#   37.996597],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.915363,
#   36.859612],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.912254,
#   37.868309],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.910648,
#   37.867706],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.904148,
#   37.72485],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.903538,
#   37.71344],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.901184,
#   37.407536],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.900169,
#   37.588306],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.892334,
#   37.440552],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.890957,
#   37.407825],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.888763,
#   37.433525],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.888107,
#   37.66246],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.885498,
#   37.604683],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.868855,
#   37.667446],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.865288,
#   37.661438],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.863358,
#   37.43351],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.862343,
#   37.608948],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.859764,
#   37.121326],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.855362,
#   37.562981],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.854996,
#   37.653389],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.851986,
#   37.443012],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.848015,
#   37.355202],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.847076,
#   37.362152],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.835659,
#   37.490498],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.833855,
#   37.298939],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.833855,
#   37.298939],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.829266,
#   37.451313],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.827133,
#   37.312019],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.818714,
#   37.573502],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.818684,
#   37.497196],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.809105,
#   37.636337],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.807396,
#   37.406281],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.805214,
#   37.508186],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.803135,
#   37.934631],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.802914,
#   37.51889],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.801319,
#   37.634335],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'fr', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:45'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.797817,
#   37.946049],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.797306,
#   37.718723],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.797077,
#   37.725388],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.796345,
#   37.80584],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.796009,
#   37.583389],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.794807,
#   37.967934],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.792191,
#   37.496796],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.79071,
#   37.635178],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.789921,
#   37.677895],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.788677,
#   37.589157],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.788631,
#   37.466789],
#  [{'days': 'mn', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'th', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-14:15, 15:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.787449,
#   37.681145],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.787273,
#   37.600353],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.785767,
#   37.568821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.783611,
#   37.721302],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.783394,
#   37.596867],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.781616,
#   37.632637],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.779068,
#   37.586929],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.778736,
#   37.602024],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.777794,
#   37.465748],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.77433,
#   37.604584],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.773155,
#   37.625908],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.773033,
#   37.675766],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.771809,
#   37.636669],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.770432,
#   37.599194],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.76997,
#   37.669083],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.768871,
#   37.651806],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.766045,
#   37.638081],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.764393,
#   37.556145],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.764275,
#   37.620392],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762936,
#   37.628845],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762936,
#   37.628845],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762119,
#   37.609638],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.761307,
#   37.656288],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.761307,
#   37.656288],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.760258,
#   37.611446],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.759033,
#   37.658295],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.757092,
#   37.595619],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.754257,
#   37.715244],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.754158,
#   37.859192],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.753666,
#   37.577129],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.75259,
#   37.604752],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.750858,
#   37.815983],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749634,
#   37.537434],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749546,
#   38.007694],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749359,
#   37.786266],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.748947,
#   37.65514],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.747784,
#   37.586689],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.746796,
#   37.421307],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.746483,
#   37.682617],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.743633,
#   38.012463],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.740589,
#   37.501286],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737984,
#   37.244133],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737507,
#   37.518379],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737446,
#   37.617958],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737183,
#   37.663952],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.736599,
#   37.5881],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.735596,
#   37.519539],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.734203,
#   37.618866],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.733501,
#   36.853474],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.733055,
#   37.664951],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.731953,
#   37.637085],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.723206,
#   37.603947],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.721241,
#   37.576824],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.721203,
#   37.823063],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.718632,
#   37.788269],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.715729,
#   37.797684],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.714561,
#   37.623833],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.70945,
#   37.661041],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.707363,
#   37.577751],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.692474,
#   37.551727],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'fr', 'hours': '09:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.690491,
#   37.863586],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.690372,
#   37.550655],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.686108,
#   37.303127],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.686005,
#   37.575829],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.685436,
#   37.570122],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.684502,
#   37.621948],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.681713,
#   37.516449],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.681534,
#   37.849888],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.679031,
#   37.283516],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.678787,
#   37.894928],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.677097,
#   37.256618],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.676552,
#   37.891171],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.674576,
#   37.760235],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.663513,
#   37.6054],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:45'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.66169,
#   37.747414],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.660671,
#   37.91338],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.650631,
#   37.394447],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.650505,
#   37.745926],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.629959,
#   37.850281],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.61813,
#   37.507484],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.617748,
#   37.505722],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.612274,
#   37.722126],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.611511,
#   37.71962],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.610489,
#   37.360321],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.608814,
#   37.535412],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.596458,
#   37.599823],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.589993,
#   38.123306],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.573448,
#   38.23138],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.568867,
#   38.226074],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.555126,
#   37.708778],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.547852,
#   37.543255],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.545261,
#   37.708141],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.478329,
#   37.298706],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.43874,
#   37.767536],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.432919,
#   37.550838],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.427883,
#   37.55011],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.421104,
#   38.260525]]

# %%
for elem in ans:
    office_latitudes.append(elem[7])
    office_longitudes.append(elem[8])
    max_people.append(np.random.randint(1000, 3000))
    for i in range(7):
        opening_times[i].append(elem[i]['hours'][:5] if elem[i]['hours'] != 'выходной' else None)
        closing_times[i].append(elem[i]['hours'][-5:] if elem[i]['hours'] != 'выходной' else None)
        business_morning[i].append(round(np.random.uniform(0.01, 0.5), 2))
        business_day[i].append(round(np.random.uniform(0.01, 1), 2))
        business_evening[i].append(round(np.random.uniform(0.01, 0.5), 2))

# %%
len(office_latitudes)
# Out:
# 160

# %%
len(office_longitudes)
# Out:
# 160

# %%
len(max_people)
# Out:
# 160

# %%
for i in range(7):
    print(len(opening_times[i]))
    print(len(closing_times[i]))
    print(len(business_morning[i]))
    print(len(business_day[i]))
    print(len(business_evening[i]))
# Out:
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160

# %%
db = pd.DataFrame()
db['Latitude'] = pd.Series(office_latitudes)

# %%
db
# Out:
#       Latitude
# 0    56.184479
# 1    56.183239
# 2    56.012386
# 3    56.010849
# 4    56.008335
# ..         ...
# 155  55.478329
# 156  55.438740
# 157  55.432919
# 158  55.427883
# 159  55.421104
#
# [160 rows x 1 columns]

# %%
db['Longitude'] = pd.Series(office_longitudes)
db['Max_People'] = pd.Series(max_people)
for i in range(7):
    db[f'opening_{ord_to_day[i]}'] = pd.Series(opening_times[i]).str[:2].fillna(0).astype(int)
    db[f'closing_{ord_to_day[i]}'] = pd.Series(closing_times[i]).str[:2].fillna(0).astype(int)
    db[f'morning_{ord_to_day[i]}'] = pd.Series(business_morning[i])
    db[f'day_{ord_to_day[i]}'] = pd.Series(business_day[i])
    db[f'evening_{ord_to_day[i]}'] = pd.Series(business_evening[i])

# %%
db
# Out:
#       Latitude  Longitude  Max_People  opening_mn  closing_mn  morning_mn  \
# 0    56.184479  36.984314        1119           9          18        0.30
# 1    56.183239  36.975700        1527           9          18        0.26
# 2    56.012386  37.482059        2388          10          19        0.34
# 3    56.010849  37.854359        1402           9          18        0.08
# 4    56.008335  37.851467        2963           9          18        0.48
# ..         ...        ...         ...         ...         ...         ...
# 155  55.478329  37.298706        1258           9          18        0.15
# 156  55.438740  37.767536        1596           9          18        0.45
# 157  55.432919  37.550838        2805           9          18        0.06
# 158  55.427883  37.550110        2825           9          18        0.03
# 159  55.421104  38.260525        1727           9          18        0.35
#
#      day_mn  evening_mn  opening_ts  closing_ts  ...  opening_st  closing_st  \
# 0      0.58        0.32           9          18  ...           0           0
# 1      0.56        0.06           9          18  ...           0           0
# 2      0.01        0.06          10          19  ...           0           0
# 3      0.97        0.14           9          18  ...           0           0
# 4      0.32        0.05           9          18  ...           0           0
# ..      ...         ...         ...         ...  ...         ...         ...
# 155    0.73        0.15           9          18  ...           0           0
# 156    0.87        0.26           9          18  ...           0           0
# 157    0.35        0.32           9          18  ...           0           0
# 158    0.39        0.06           9          18  ...           0           0
# 159    0.91        0.28           9          18  ...           0           0
#
#      morning_st  day_st  evening_st  opening_sn  closing_sn  morning_sn  \
# 0          0.35    0.08        0.35           0           0        0.04
# 1          0.45    0.95        0.27           0           0        0.39
# 2          0.05    0.24        0.17           0           0        0.17
# 3          0.46    0.56        0.01           0           0        0.22
# 4          0.46    0.19        0.05           0           0        0.15
# ..          ...     ...         ...         ...         ...         ...
# 155        0.03    0.34        0.25           0           0        0.49
# 156        0.44    0.22        0.44           0           0        0.38
# 157        0.11    0.45        0.22           0           0        0.48
# 158        0.17    0.79        0.30           0           0        0.35
# 159        0.43    1.00        0.47           0           0        0.30
#
#      day_sn  evening_sn
# 0      0.61        0.37
# 1      0.38        0.43
# 2      0.24        0.37
# 3      0.41        0.26
# 4      0.08        0.25
# ..      ...         ...
# 155    0.11        0.07
# 156    0.19        0.35
# 157    0.66        0.09
# 158    0.22        0.46
# 159    0.86        0.02
#
# [160 rows x 38 columns]

# %%
examples_quantity = 8192
examples = pd.DataFrame()
usr_lat = []
usr_lon = []
days = [np.random.randint(0, 5) for i in range(examples_quantity)]
time = [np.random.uniform(9, 19) for i in range(examples_quantity)]
for i in range(examples_quantity):
    rho = np.random.uniform(0, moscow_rad)
    phi = np.random.uniform(0, 2 * np.pi)
    usr_lat.append(kremlin_lat + rho * np.sin(phi))
    usr_lon.append(kremlin_lon + rho * np.cos(phi))

# %%
examples['Latitude'] = usr_lat
examples['Longitude'] = usr_lon
examples['day'] = days
examples['time'] = time

# %%
examples
# Out:
#        Latitude  Longitude  day       time
# 0     55.732761  37.585269    0  10.150501
# 1     55.135852  37.620822    4  11.112689
# 2     55.694201  37.713336    3  11.992098
# 3     55.818635  37.763285    0  17.870403
# 4     55.615080  37.563649    2  11.058764
# ...         ...        ...  ...        ...
# 8187  55.820093  37.702651    2  15.053596
# 8188  55.211948  37.368396    2  17.873015
# 8189  55.763741  37.589529    4  16.355091
# 8190  55.415649  37.842683    2  13.254130
# 8191  55.792898  37.660248    2  12.441835
#
# [8192 rows x 4 columns]

# %%
db
# Out:
#       Latitude  Longitude  Max_People  opening_mn  closing_mn  morning_mn  \
# 0    56.184479  36.984314        1119           9          18        0.30
# 1    56.183239  36.975700        1527           9          18        0.26
# 2    56.012386  37.482059        2388          10          19        0.34
# 3    56.010849  37.854359        1402           9          18        0.08
# 4    56.008335  37.851467        2963           9          18        0.48
# ..         ...        ...         ...         ...         ...         ...
# 155  55.478329  37.298706        1258           9          18        0.15
# 156  55.438740  37.767536        1596           9          18        0.45
# 157  55.432919  37.550838        2805           9          18        0.06
# 158  55.427883  37.550110        2825           9          18        0.03
# 159  55.421104  38.260525        1727           9          18        0.35
#
#      day_mn  evening_mn  opening_ts  closing_ts  ...  opening_st  closing_st  \
# 0      0.58        0.32           9          18  ...           0           0
# 1      0.56        0.06           9          18  ...           0           0
# 2      0.01        0.06          10          19  ...           0           0
# 3      0.97        0.14           9          18  ...           0           0
# 4      0.32        0.05           9          18  ...           0           0
# ..      ...         ...         ...         ...  ...         ...         ...
# 155    0.73        0.15           9          18  ...           0           0
# 156    0.87        0.26           9          18  ...           0           0
# 157    0.35        0.32           9          18  ...           0           0
# 158    0.39        0.06           9          18  ...           0           0
# 159    0.91        0.28           9          18  ...           0           0
#
#      morning_st  day_st  evening_st  opening_sn  closing_sn  morning_sn  \
# 0          0.35    0.08        0.35           0           0        0.04
# 1          0.45    0.95        0.27           0           0        0.39
# 2          0.05    0.24        0.17           0           0        0.17
# 3          0.46    0.56        0.01           0           0        0.22
# 4          0.46    0.19        0.05           0           0        0.15
# ..          ...     ...         ...         ...         ...         ...
# 155        0.03    0.34        0.25           0           0        0.49
# 156        0.44    0.22        0.44           0           0        0.38
# 157        0.11    0.45        0.22           0           0        0.48
# 158        0.17    0.79        0.30           0           0        0.35
# 159        0.43    1.00        0.47           0           0        0.30
#
#      day_sn  evening_sn
# 0      0.61        0.37
# 1      0.38        0.43
# 2      0.24        0.37
# 3      0.41        0.26
# 4      0.08        0.25
# ..      ...         ...
# 155    0.11        0.07
# 156    0.19        0.35
# 157    0.66        0.09
# 158    0.22        0.46
# 159    0.86        0.02
#
# [160 rows x 38 columns]

# %%
points1 = db.loc[:, ['Latitude', 'Longitude']].values

# %%
points2 = examples.loc[:, ['Latitude', 'Longitude']].values

# %%
distances = cdist(points1, points2)
distances_df = pd.DataFrame(distances, index=db.index, columns=['dist' + str(idx) for idx in examples.index])
distances_df
# Out:
#         dist0     dist1     dist2     dist3     dist4     dist5     dist6  \
# 0    0.751795  1.226687  0.878548  0.860603  0.812308  0.640636  0.511909
# 1    0.757960  1.230123  0.885023  0.867886  0.817612  0.644616  0.515404
# 2    0.298064  0.887450  0.393359  0.341508  0.405597  0.375399  0.351237
# 3    0.386965  0.905627  0.346632  0.212699  0.491066  0.612400  0.658062
# 4    0.383148  0.902454  0.343163  0.209194  0.487328  0.608590  0.654407
# ..        ...       ...       ...       ...       ...       ...       ...
# 155  0.383215  0.470159  0.467460  0.575883  0.298154  0.189529  0.273484
# 156  0.345933  0.336551  0.261147  0.379918  0.269566  0.470516  0.601675
# 157  0.301813  0.305199  0.307691  0.440352  0.182611  0.301684  0.434548
# 158  0.306899  0.300470  0.312359  0.445118  0.187686  0.305022  0.437712
# 159  0.743708  0.700421  0.611553  0.636615  0.723369  0.939100  1.060818
#
#         dist7     dist8     dist9  ...  dist8182  dist8183  dist8184  \
# 0    1.001189  0.820446  0.358940  ...  0.955861  1.099234  0.659578
# 1    1.007780  0.826232  0.362373  ...  0.964221  1.107220  0.668066
# 2    0.505023  0.381201  0.342322  ...  0.450431  0.574747  0.198927
# 3    0.368915  0.433574  0.699430  ...  0.086411  0.223113  0.244254
# 4    0.366199  0.429867  0.696110  ...  0.090145  0.224292  0.243000
# ..        ...       ...       ...  ...       ...       ...       ...
# 155  0.552823  0.356490  0.418703  ...  0.853017  0.853885  0.737357
# 156  0.212575  0.266358  0.742097  ...  0.633755  0.533011  0.703641
# 157  0.346533  0.227832  0.585635  ...  0.725627  0.675599  0.704014
# 158  0.350183  0.232886  0.588982  ...  0.730302  0.679576  0.709102
# 159  0.487511  0.691198  1.183463  ...  0.711053  0.520021  0.941768
#
#      dist8185  dist8186  dist8187  dist8188  dist8189  dist8190  dist8191
# 0    0.745020  0.572579  0.805473  1.045627  0.737093  1.152344  0.781167
# 1    0.748869  0.576880  0.812609  1.047672  0.743481  1.157952  0.788018
# 2    0.451563  0.319804  0.292639  0.808468  0.270877  0.697241  0.282712
# 3    0.632771  0.592879  0.243728  0.935095  0.362212  0.595314  0.291859
# 4    0.628946  0.589142  0.239961  0.931445  0.358383  0.592751  0.288059
# ..        ...       ...       ...       ...       ...       ...       ...
# 155  0.137084  0.253709  0.529126  0.275346  0.407477  0.547576  0.479235
# 156  0.387218  0.523567  0.386833  0.459072  0.370556  0.078614  0.370052
# 157  0.200559  0.368626  0.415873  0.286554  0.333077  0.292355  0.376239
# 158  0.203454  0.372268  0.420829  0.282220  0.338163  0.292828  0.381269
# 159  0.870500  0.978184  0.685868  0.916319  0.753416  0.417878  0.706090
#
# [160 rows x 8192 columns]

# %%
examples['day'].values
# Out:
# array([0, 4, 3, ..., 4, 2, 2], dtype=int64)

# %%
diff_matrix = [[0] * 8192 for _ in range(160)]
days = examples['day'].values
coming = examples['time'].values
for i in range(160):
    for j in range(8192):
        closing_hours = db[f'closing_{ord_to_day[days[j]]}'].values
        diff_matrix[i][j] = 1 / max(closing_hours[i] - coming[j], 0.0001)

# %%
diff_df = pd.DataFrame(diff_matrix, index=db.index, columns=['diff' + str(idx) for idx in examples.index])

# %%
diff_df
# Out:
#         diff0     diff1     diff2     diff3     diff4         diff5     diff6  \
# 0    0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
# 1    0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
# 2    0.113001  0.145195  0.142696  0.885272  0.125925      4.242311  0.197919
# 3    0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
# 4    0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
# ..        ...       ...       ...       ...       ...           ...       ...
# 155  0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
# 156  0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
# 157  0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
# 158  0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
# 159  0.127397  0.169857  0.166447  7.716238  0.144067  10000.000000  0.246758
#
#         diff7     diff8     diff9  ...      diff8182      diff8183  diff8184  \
# 0    1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
# 1    1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
# 2    0.611074  0.234431  0.104373  ...      3.185313      7.767311  0.101217
# 3    1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
# 4    1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
# ..        ...       ...       ...  ...           ...           ...       ...
# 155  1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
# 156  1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
# 157  1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
# 158  1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
# 159  1.571186  0.306219  0.116536  ...  10000.000000  10000.000000  0.112616
#
#      diff8185  diff8186  diff8187  diff8188  diff8189  diff8190  diff8191
# 0    0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
# 1    0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
# 2    0.407274  0.191073  0.253395  0.887323  0.607937  0.174038  0.152482
# 3    0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
# 4    0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
# ..        ...       ...       ...       ...       ...       ...       ...
# 155  0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
# 156  0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
# 157  0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
# 158  0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
# 159  0.687121  0.236206  0.339397  7.874932  1.550608  0.210710  0.179915
#
# [160 rows x 8192 columns]

# %%
busy_matrix = [[0] * 8192 for _ in range(160)]
days = examples['day'].values
time = examples['time'].values
for i in range(160):
    for j in range(8192):
        if time[j] < 12:
            business = db[f'morning_{ord_to_day[days[j]]}'].values
        elif time[j] > 15:
            business = db[f'evening_{ord_to_day[days[j]]}'].values
        else:
            business = db[f'day_{ord_to_day[days[j]]}'].values
        busy_matrix[i][j] = business[i]

# %%
busy_df = pd.DataFrame(busy_matrix, index=db.index, columns=['busy' + str(idx) for idx in examples.index])

# %%
busy_df
# Out:
#      busy0  busy1  busy2  busy3  busy4  busy5  busy6  busy7  busy8  busy9  \
# 0     0.30   0.23   0.48   0.32   0.24   0.32   0.83   0.32   0.77   0.24
# 1     0.26   0.23   0.24   0.06   0.19   0.06   1.00   0.06   0.18   0.19
# 2     0.34   0.44   0.04   0.06   0.09   0.06   0.84   0.06   0.87   0.09
# 3     0.08   0.03   0.04   0.14   0.04   0.14   0.37   0.14   0.30   0.04
# 4     0.48   0.42   0.21   0.05   0.18   0.05   0.21   0.05   0.70   0.18
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 155   0.15   0.25   0.20   0.15   0.05   0.15   0.99   0.15   0.23   0.05
# 156   0.45   0.41   0.35   0.26   0.03   0.26   0.91   0.26   0.13   0.03
# 157   0.06   0.29   0.26   0.32   0.27   0.32   0.33   0.32   0.82   0.27
# 158   0.03   0.34   0.17   0.06   0.26   0.06   0.81   0.06   0.75   0.26
# 159   0.35   0.05   0.37   0.28   0.20   0.28   0.24   0.28   0.77   0.20
#
#      ...  busy8182  busy8183  busy8184  busy8185  busy8186  busy8187  \
# 0    ...      0.38      0.32      0.15      0.32      0.52      0.42
# 1    ...      0.33      0.06      0.31      0.06      0.17      0.03
# 2    ...      0.38      0.06      0.43      0.06      0.18      0.49
# 3    ...      0.16      0.14      0.30      0.14      0.92      0.43
# 4    ...      0.43      0.05      0.28      0.05      0.41      0.48
# ..   ...       ...       ...       ...       ...       ...       ...
# 155  ...      0.33      0.15      0.20      0.15      0.94      0.26
# 156  ...      0.26      0.26      0.30      0.26      0.59      0.23
# 157  ...      0.22      0.32      0.33      0.32      0.87      0.49
# 158  ...      0.18      0.06      0.04      0.06      0.19      0.38
# 159  ...      0.02      0.28      0.43      0.28      0.08      0.33
#
#      busy8188  busy8189  busy8190  busy8191
# 0        0.42      0.21      0.83      0.83
# 1        0.03      0.31      1.00      1.00
# 2        0.49      0.01      0.84      0.84
# 3        0.43      0.43      0.37      0.37
# 4        0.48      0.48      0.21      0.21
# ..        ...       ...       ...       ...
# 155      0.26      0.31      0.99      0.99
# 156      0.23      0.20      0.91      0.91
# 157      0.49      0.27      0.33      0.33
# 158      0.38      0.30      0.81      0.81
# 159      0.33      0.49      0.24      0.24
#
# [160 rows x 8192 columns]

# %%
vect = []
for i in range(8192):
    dist = distances_df.loc[:, f'dist{i}']
    diff = diff_df.loc[:, f'diff{i}']
    busy = busy_df.loc[:, f'busy{i}']
    result = pd.concat([dist, diff, busy], axis=1, join="outer")
    result = result.sort_values(by=[f'dist{i}', f'diff{i}', f'busy{i}'])
    vect.append(list(result.loc[[result.index[0], result.index[-1]]].values))

# %%
vect
# Out:
# [[array([0.00476898, 0.12739666, 0.21      ]),
#   array([0.75796046, 0.12739666, 0.26      ])],
#  [array([0.30047019, 0.16985683, 0.34      ]),
#   array([1.23012271, 0.16985683, 0.23      ])],
#  [array([0.04709827, 0.16644745, 0.49      ]),
#   array([0.88502287, 0.16644745, 0.24      ])],
#  [array([0.04359933, 0.8852716 , 0.37      ]),
#   array([0.91378526, 7.7162377 , 0.06      ])],
#  [array([0.02892396, 0.14406655, 0.17      ]),
#   array([0.81761178, 0.14406655, 0.19      ])],
#  [array([4.31524591e-02, 1.00000000e+04, 2.30000000e-01]),
#   array([9.39099721e-01, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.01199263, 0.2467575 , 0.54      ]),
#   array([1.06081768, 0.2467575 , 0.24      ])],
#  [array([0.02717356, 0.61107449, 0.12      ]),
#   array([1.00777975, 1.57118644, 0.06      ])],
#  [array([0.01117123, 0.23443143, 0.53      ]),
#   array([0.82623181, 0.30621871, 0.18      ])],
#  [array([0.04948284, 0.11653615, 0.18      ]),
#   array([1.18346345, 0.11653615, 0.2       ])],
#  [array([0.18443553, 0.11794   , 0.08      ]),
#   array([1.03418371, 0.11794   , 0.25      ])],
#  [array([0.06171361, 0.11418097, 0.13      ]),
#   array([0.81044662, 0.12889875, 0.37      ])],
#  [array([0.01093943, 0.34558451, 0.23      ]),
#   array([0.826314  , 0.52808119, 0.03      ])],
#  [array([0.08596814, 1.76866649, 0.05      ]),
#   array([1.00236783e+00, 1.00000000e+04, 1.40000000e-01])],
#  [array([0.09982184, 2.29602524, 0.07      ]),
#   array([8.41920312e-01, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.05710802, 0.79759443, 0.34      ]),
#   array([1.12011274, 0.79759443, 0.14      ])],
#  [array([0.02964116, 0.15777393, 0.15      ]),
#   array([0.78253484, 0.18732966, 0.51      ])],
#  [array([0.00996843, 0.12084364, 0.36      ]),
#   array([0.77537944, 0.13745409, 0.31      ])],
#  [array([0.07001793, 0.8373119 , 0.12      ]),
#   array([1.00564559, 0.8373119 , 0.31      ])],
#  [array([0.17166754, 0.11115641, 0.46      ]),
#   array([1.16466193, 0.11115641, 0.35      ])],
#  [array([0.04533603, 0.14552941, 0.89      ]),
#   array([0.90700496, 0.17031529, 0.51      ])],
#  [array([0.0059835 , 0.45346088, 0.43      ]),
#   array([0.96444339, 0.8296952 , 0.26      ])],
#  [array([0.01665552, 0.13919248, 0.3       ]),
#   array([0.79243083, 0.16169989, 0.2       ])],
#  [array([0.010068 , 0.1178898, 0.34     ]),
#   array([1.12444794, 0.1178898 , 0.25      ])],
#  [array([0.00843337, 0.40570254, 0.07      ]),
#   array([0.79026801, 0.40570254, 0.02      ])],
#  [array([0.03740475, 0.6801658 , 0.39      ]),
#   array([1.00807201, 0.6801658 , 0.06      ])],
#  [array([0.08256036, 0.20677728, 0.62      ]),
#   array([1.29302135, 0.20677728, 0.57      ])],
#  [array([0.01744683, 0.88030249, 0.45      ]),
#   array([0.91600797, 7.35439257, 0.49      ])],
#  [array([0.1500552 , 0.39975415, 0.15      ]),
#   array([1.10216313, 0.39975415, 0.28      ])],
#  [array([0.23643555, 0.19797133, 0.86      ]),
#   array([1.37585711, 0.19797133, 0.51      ])],
#  [array([0.01968334, 0.66136792, 0.11      ]),
#   array([0.89103057, 1.95305752, 0.14      ])],
#  [array([0.13751602, 1.42284532, 0.07      ]),
#   array([1.01336679, 1.42284532, 0.14      ])],
#  [array([0.10447471, 0.23854591, 0.76      ]),
#   array([1.33595177, 0.23854591, 0.77      ])],
#  [array([0.01142421, 0.87018417, 0.03      ]),
#   array([0.77744369, 0.87018417, 0.11      ])],
#  [array([0.09210906, 0.32943973, 0.94      ]),
#   array([1.05473388, 0.32943973, 0.08      ])],
#  [array([0.03873891, 0.11266816, 0.46      ]),
#   array([0.89455774, 0.11266816, 0.26      ])],
#  [array([0.03713295, 0.16493629, 0.39      ]),
#   array([0.82344217, 0.16493629, 0.23      ])],
#  [array([0.01957984, 0.34084081, 0.05      ]),
#   array([0.93540687, 0.51708421, 0.26      ])],
#  [array([0.01616524, 0.19034965, 0.44      ]),
#   array([0.80805845, 0.23510106, 0.51      ])],
#  [array([5.09452303e-04, 1.73979391e+00, 1.80000000e-01]),
#   array([0.75774828, 1.73979391, 0.31      ])],
#  [array([9.75425006e-02, 1.00000000e+04, 4.90000000e-01]),
#   array([8.56794748e-01, 1.00000000e+04, 3.00000000e-02])],
#  [array([1.7686968e-01, 1.0000000e+04, 2.0000000e-02]),
#   array([1.36190228e+00, 1.00000000e+04, 3.30000000e-01])],
#  [array([0.023578  , 2.50319713, 0.21      ]),
#   array([1.01463655, 2.50319713, 0.33      ])],
#  [array([0.18213596, 0.27109286, 0.97      ]),
#   array([0.98093302, 0.27109286, 0.51      ])],
#  [array([0.05104026, 0.12921952, 0.13      ]),
#   array([1.01171272, 0.12921952, 0.19      ])],
#  [array([0.05215232, 0.23189856, 0.13      ]),
#   array([1.04031441, 0.23189856, 0.18      ])],
#  [array([5.61085055e-02, 1.00000000e+04, 1.20000000e-01]),
#   array([1.01012849e+00, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.19522866, 0.40017985, 0.2       ]),
#   array([1.34314579, 0.40017985, 0.04      ])],
#  [array([0.08620651, 0.28359384, 0.88      ]),
#   array([1.14611829, 0.28359384, 1.        ])],
#  [array([0.02724074, 0.27524923, 0.87      ]),
#   array([0.79333283, 0.37978467, 0.04      ])],
#  [array([0.05403126, 0.13234949, 0.47      ]),
#   array([0.89730191, 0.15253779, 0.19      ])],
#  [array([0.23091313, 0.12886119, 0.49      ]),
#   array([1.23552988, 0.12886119, 0.37      ])],
#  [array([2.88808356e-02, 1.00000000e+04, 3.00000000e-01]),
#   array([1.13285979e+00, 1.00000000e+04, 3.80000000e-01])],
#  [array([0.00708424, 0.11078493, 0.38      ]),
#   array([0.77064674, 0.12458732, 0.16      ])],
#  [array([0.18135504, 0.28064712, 0.99      ]),
#   array([0.88913173, 0.28064712, 0.08      ])],
#  [array([1.57378739e-02, 1.00000000e+04, 1.10000000e-01]),
#   array([8.74820193e-01, 1.00000000e+04, 3.20000000e-01])],
#  [array([0.01854892, 0.16285196, 0.63      ]),
#   array([0.80508041, 0.19453186, 0.67      ])],
#  [array([0.26192678, 0.35103888, 0.18      ]),
#   array([1.17771491, 0.35103888, 0.33      ])],
#  [array([9.20922671e-02, 1.00000000e+04, 1.90000000e-01]),
#   array([1.22762372e+00, 1.00000000e+04, 3.20000000e-01])],
#  [array([4.78287646e-02, 1.00000000e+04, 3.80000000e-01]),
#   array([8.90035476e-01, 1.00000000e+04, 2.60000000e-01])],
#  [array([0.08857597, 0.1267386 , 0.09      ]),
#   array([0.99610194, 0.1267386 , 0.23      ])],
#  [array([0.04799958, 0.23658667, 0.87      ]),
#   array([1.06992285, 0.23658667, 0.76      ])],
#  [array([0.04774763, 0.14533371, 0.24      ]),
#   array([0.9866161 , 0.14533371, 0.49      ])],
#  [array([0.09231899, 0.23284418, 0.13      ]),
#   array([1.06251982, 0.23284418, 0.18      ])],
#  [array([0.0222205 , 0.20386083, 0.9       ]),
#   array([0.8309492 , 0.20386083, 1.        ])],
#  [array([0.0504938 , 0.15033939, 0.33      ]),
#   array([1.0852094 , 0.17694052, 0.18      ])],
#  [array([0.06679802, 0.11221536, 0.3       ]),
#   array([1.27666263, 0.11221536, 0.37      ])],
#  [array([0.00158592, 1.31968118, 0.05      ]),
#   array([0.78176255, 1.31968118, 0.33      ])],
#  [array([0.01410081, 0.20256752, 0.29      ]),
#   array([0.80025197, 0.25402466, 0.56      ])],
#  [array([0.20270157, 0.21482473, 0.37      ]),
#   array([1.1648    , 0.21482473, 0.76      ])],
#  [array([0.00231172, 0.13094219, 0.4       ]),
#   array([0.89942756, 0.15067144, 0.37      ])],
#  [array([0.15469871, 0.18766038, 0.13      ]),
#   array([1.22713818, 0.18766038, 0.18      ])],
#  [array([0.29326984, 0.12875482, 0.03      ]),
#   array([1.37793532, 0.12875482, 0.19      ])],
#  [array([0.01631467, 0.11181855, 0.25      ]),
#   array([0.80155865, 0.12589606, 0.43      ])],
#  [array([0.00749048, 0.1183559 , 0.3       ]),
#   array([0.82254977, 0.1183559 , 0.31      ])],
#  [array([0.09174005, 0.42547454, 0.04      ]),
#   array([1.1281382 , 0.42547454, 0.33      ])],
#  [array([0.04129323, 0.133371  , 0.46      ]),
#   array([0.88404281, 0.15389631, 0.37      ])],
#  [array([0.11566041, 0.31491721, 0.96      ]),
#   array([0.84849969, 0.31491721, 0.57      ])],
#  [array([0.00112803, 0.21338392, 0.38      ]),
#   array([0.74961553, 0.27126819, 0.9       ])],
#  [array([0.11647246, 0.25591119, 0.84      ]),
#   array([1.19945244, 0.25591119, 0.91      ])],
#  [array([0.03956696, 0.95896324, 0.05      ]),
#   array([0.97315939, 0.95896324, 0.33      ])],
#  [array([5.25193948e-02, 1.00000000e+04, 2.30000000e-01]),
#   array([1.04820769e+00, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.02846844, 0.27792059, 0.86      ]),
#   array([0.77048205, 0.27792059, 0.18      ])],
#  [array([0.03488288, 0.36375857, 0.27      ]),
#   array([1.05602258, 0.36375857, 0.08      ])],
#  [array([0.04444259, 1.14415447, 0.05      ]),
#   array([0.92202271, 1.14415447, 0.33      ])],
#  [array([0.02748576, 0.13560203, 0.31      ]),
#   array([0.81277515, 0.13560203, 0.24      ])],
#  [array([0.05517763, 0.20982741, 0.91      ]),
#   array([1.08287832, 0.20982741, 1.        ])],
#  [array([0.24729076, 0.17946511, 0.87      ]),
#   array([1.3301664 , 0.17946511, 0.56      ])],
#  [array([0.04440179, 0.59481741, 0.15      ]),
#   array([0.99750028, 0.59481741, 0.28      ])],
#  [array([0.02718336, 0.1222873 , 0.08      ]),
#   array([0.84167523, 0.13932498, 0.23      ])],
#  [array([0.03557563, 0.12056697, 0.38      ]),
#   array([0.83465409, 0.13709625, 0.49      ])],
#  [array([0.00411447, 0.80122413, 0.49      ]),
#   array([0.79692018, 4.03079172, 0.31      ])],
#  [array([0.01359395, 2.46351799, 0.37      ]),
#   array([1.02709866e+00, 1.00000000e+04, 2.60000000e-01])],
#  [array([1.24709184e-02, 1.00000000e+04, 1.90000000e-01]),
#   array([8.13148381e-01, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.10756347, 0.17802292, 0.12      ]),
#   array([0.88872989, 0.21657893, 0.77      ])],
#  [array([0.11029944, 0.22622831, 0.99      ]),
#   array([0.92157053, 0.22622831, 0.24      ])],
#  [array([0.25016933, 0.15105435, 0.04      ]),
#   array([1.1371637 , 0.15105435, 0.49      ])],
#  [array([8.6882383e-03, 1.0000000e+04, 3.0000000e-01]),
#   array([8.95876059e-01, 1.00000000e+04, 2.10000000e-01])],
#  [array([0.05555683, 0.67796236, 0.33      ]),
#   array([1.01710944, 0.67796236, 0.02      ])],
#  [array([0.21415312, 0.51812367, 0.49      ]),
#   array([1.14569042, 1.07522124, 0.33      ])],
#  [array([0.06469798, 0.29612999, 0.74      ]),
#   array([0.87436334, 0.42071687, 0.08      ])],
#  [array([5.87898487e-02, 1.00000000e+04, 4.30000000e-01]),
#   array([1.06779321e+00, 1.00000000e+04, 3.20000000e-01])],
#  [array([0.0420505 , 0.21256772, 0.37      ]),
#   array([0.96883253, 0.21256772, 0.32      ])],
#  [array([0.01547879, 0.77826401, 0.31      ]),
#   array([0.81333784, 3.50986779, 0.32      ])],
#  [array([9.91714446e-02, 1.00000000e+04, 3.00000000e-01]),
#   array([1.23477074e+00, 1.00000000e+04, 1.60000000e-01])],
#  [array([0.11016956, 0.17758089, 0.01      ]),
#   array([0.93394836, 0.21592505, 0.91      ])],
#  [array([0.01817287, 0.10916193, 0.43      ]),
#   array([0.78924795, 0.12253847, 0.37      ])],
#  [array([0.01323355, 5.70805006, 0.16      ]),
#   array([0.7633357 , 5.70805006, 0.49      ])],
#  [array([0.03364603, 0.35575545, 0.46      ]),
#   array([0.81197883, 0.55220561, 0.33      ])],
#  [array([0.08425967, 0.21743882, 0.72      ]),
#   array([1.1245567 , 0.21743882, 0.77      ])],
#  [array([0.09335474, 0.27788873, 0.23      ]),
#   array([1.15764775, 0.27788873, 0.57      ])],
#  [array([0.00768854, 0.11661002, 0.45      ]),
#   array([0.78059966, 0.11661002, 0.46      ])],
#  [array([9.66814917e-02, 1.00000000e+04, 3.80000000e-01]),
#   array([1.13271797e+00, 1.00000000e+04, 2.00000000e-02])],
#  [array([0.02229174, 0.30239943, 0.75      ]),
#   array([0.79694549, 0.30239943, 0.08      ])],
#  [array([0.04465759, 0.35428497, 0.12      ]),
#   array([0.87504417, 0.54867077, 0.28      ])],
#  [array([0.08422997, 0.1270316 , 0.3       ]),
#   array([1.31138989, 0.1270316 , 0.37      ])],
#  [array([0.14765181, 0.12444731, 0.2       ]),
#   array([1.10260556, 0.12444731, 0.43      ])],
#  [array([0.00321753, 0.19145354, 0.88      ]),
#   array([0.80869833, 0.19145354, 0.49      ])],
#  [array([ 0.07642245, 57.26635162,  0.06      ]),
#   array([9.79886937e-01, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.00570226, 0.20276424, 0.16      ]),
#   array([0.81565062, 0.20276424, 0.16      ])],
#  [array([0.11514636, 0.14419837, 0.05      ]),
#   array([1.24632483, 0.14419837, 0.31      ])],
#  [array([0.20434347, 0.11805208, 0.45      ]),
#   array([1.28421685, 0.11805208, 0.26      ])],
#  [array([0.10373114, 0.17594887, 0.92      ]),
#   array([0.85759136, 0.21351693, 0.24      ])],
#  [array([0.05975094, 0.41765628, 0.12      ]),
#   array([1.30159855, 0.41765628, 0.11      ])],
#  [array([0.00839656, 0.17416853, 0.45      ]),
#   array([0.7969693 , 0.21090082, 0.16      ])],
#  [array([0.05328547, 0.21290057, 0.97      ]),
#   array([1.02747227, 0.27048752, 0.57      ])],
#  [array([0.10163544, 3.34991798, 0.06      ]),
#   array([1.26079178, 3.34991798, 0.11      ])],
#  [array([0.15747075, 0.12428478, 0.04      ]),
#   array([1.10077764, 0.12428478, 0.31      ])],
#  [array([0.01565122, 0.52584327, 0.5       ]),
#   array([0.80077761, 1.10900727, 0.33      ])],
#  [array([0.15952284, 0.34109676, 0.12      ]),
#   array([1.31835909, 0.34109676, 0.33      ])],
#  [array([0.02933854, 6.69303058, 0.26      ]),
#   array([0.94663444, 6.69303058, 0.33      ])],
#  [array([0.03942095, 0.11024026, 0.4       ]),
#   array([0.90424961, 0.1238989 , 0.31      ])],
#  [array([0.03310222, 0.20887318, 0.33      ]),
#   array([1.05690677, 0.26401984, 0.18      ])],
#  [array([0.01127137, 0.14484257, 0.26      ]),
#   array([0.78536966, 0.14484257, 0.16      ])],
#  [array([0.01678725, 1.64020321, 0.21      ]),
#   array([0.87687357, 1.64020321, 0.28      ])],
#  [array([0.09479547, 0.38713314, 0.33      ]),
#   array([0.84634662, 0.63167577, 0.14      ])],
#  [array([0.06412817, 0.14323788, 0.45      ]),
#   array([1.08777114, 0.14323788, 0.26      ])],
#  [array([0.11172054, 0.13983265, 0.37      ]),
#   array([1.09143233, 0.13983265, 0.05      ])],
#  [array([0.07824801, 0.12053063, 0.3       ]),
#   array([0.87626519, 0.12053063, 0.25      ])],
#  [array([0.03858547, 0.58725965, 0.38      ]),
#   array([0.85810563, 0.58725965, 0.49      ])],
#  [array([0.02924133, 0.34330913, 0.77      ]),
#   array([1.02702558, 0.34330913, 0.08      ])],
#  [array([0.02186659, 0.17534436, 0.97      ]),
#   array([0.89598149, 0.17534436, 0.77      ])],
#  [array([0.0369815 , 0.35499755, 0.26      ]),
#   array([1.08058294, 0.35499755, 0.33      ])],
#  [array([3.72128276e-03, 1.00000000e+04, 2.80000000e-01]),
#   array([7.86851819e-01, 1.00000000e+04, 2.60000000e-01])],
#  [array([0.05440503, 0.99695128, 0.26      ]),
#   array([0.9248359 , 0.99695128, 0.33      ])],
#  [array([0.06048945, 1.71551865, 0.24      ]),
#   array([8.91953958e-01, 1.00000000e+04, 2.00000000e-02])],
#  [array([0.0108103 , 0.20999262, 0.17      ]),
#   array([0.77602905, 0.26581096, 0.71      ])],
#  [array([0.12921505, 0.13129086, 0.04      ]),
#   array([1.07770395, 0.13129086, 0.31      ])],
#  [array([0.05934653, 0.3076306 , 0.04      ]),
#   array([1.18154097, 0.3076306 , 0.08      ])],
#  [array([0.01856605, 0.95187205, 0.26      ]),
#   array([0.9583698 , 0.95187205, 0.33      ])],
#  [array([0.30689703, 0.36684341, 0.49      ]),
#   array([1.20926353, 0.57938813, 0.33      ])],
#  [array([0.04372874, 0.15547921, 0.86      ]),
#   array([0.90007742, 0.18410347, 0.18      ])],
#  [array([0.24475162, 0.25218143, 0.06      ]),
#   array([1.01574653, 0.33722274, 0.28      ])],
#  [array([0.20515607, 0.23738536, 0.47      ]),
#   array([1.14636768, 0.23738536, 0.32      ])],
#  [array([0.02688812, 0.18816796, 0.12      ]),
#   array([0.89362644, 0.23178189, 0.71      ])],
#  [array([4.08682449e-03, 1.00000000e+04, 7.00000000e-02]),
#   array([7.54618126e-01, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.10798547, 0.19518222, 0.91      ]),
#   array([1.14743608, 0.19518222, 1.        ])],
#  [array([0.04560713, 0.16078312, 0.45      ]),
#   array([1.1136471 , 0.16078312, 0.25      ])],
#  [array([0.09780042, 0.11844745, 0.04      ]),
#   array([1.06827533, 0.13436232, 0.37      ])],
#  [array([0.03088604, 0.10553855, 0.24      ]),
#   array([0.8325327 , 0.11799117, 0.2       ])],
#  [array([0.04114107, 0.43416451, 0.23      ]),
#   array([1.12040756, 0.43416451, 0.03      ])],
#  [array([0.0259961 , 2.01152598, 0.21      ]),
#   array([1.22379194, 2.01152598, 0.28      ])],
#  [array([0.08599895, 0.36953901, 0.11      ]),
#   array([1.24174884, 0.36953901, 0.28      ])],
#  [array([0.0432242 , 0.43186423, 0.27      ]),
#   array([0.89984398, 0.76014264, 0.03      ])],
#  [array([0.17716051, 0.19952957, 0.34      ]),
#   array([1.05711643, 0.19952957, 0.23      ])],
#  [array([0.08510484, 0.42416618, 0.16      ]),
#   array([1.06583798, 0.42416618, 0.31      ])],
#  [array([0.02728391, 0.1912219 , 0.72      ]),
#   array([0.92022074, 0.1912219 , 0.5       ])],
#  [array([0.01764141, 0.16563519, 0.12      ]),
#   array([0.85480398, 0.19851651, 0.71      ])],
#  [array([0.09469983, 0.14082246, 0.04      ]),
#   array([1.10542212, 0.14082246, 0.2       ])],
#  [array([0.00525199, 0.19098867, 0.87      ]),
#   array([0.80162884, 0.23607664, 0.08      ])],
#  [array([0.08597519, 0.82973455, 0.23      ]),
#   array([1.13537561, 0.82973455, 0.33      ])],
#  [array([0.04054151, 0.3145066 , 0.3       ]),
#   array([1.14942434, 0.3145066 , 0.51      ])],
#  [array([0.02533681, 0.1952643 , 0.34      ]),
#   array([0.79362972, 0.24264402, 1.        ])],
#  [array([0.09702544, 0.28425174, 0.66      ]),
#   array([1.09856865, 0.28425174, 0.24      ])],
#  [array([0.10389576, 0.18097955, 0.64      ]),
#   array([1.15442402, 0.18097955, 0.56      ])],
#  [array([0.02412958, 0.13692206, 0.34      ]),
#   array([0.99274404, 0.13692206, 0.37      ])],
#  [array([0.01249044, 0.12301355, 0.14      ]),
#   array([0.7761721 , 0.12301355, 0.35      ])],
#  [array([0.1058921, 0.2286801, 0.86     ]),
#   array([1.1798505, 0.2286801, 0.42     ])],
#  [array([0.14643338, 0.21082777, 0.99      ]),
#   array([1.0464803 , 0.21082777, 0.24      ])],
#  [array([0.03696313, 0.56355171, 0.05      ]),
#   array([0.92235029, 1.29122216, 0.28      ])],
#  [array([0.14486142, 0.97967185, 0.12      ]),
#   array([1.2752667 , 0.97967185, 0.03      ])],
#  [array([0.04000311, 0.12242464, 0.41      ]),
#   array([1.01103417, 0.12242464, 0.35      ])],
#  [array([0.01069625, 0.44267419, 0.07      ]),
#   array([0.77544119, 0.79428259, 0.38      ])],
#  [array([0.07331906, 1.10881566, 0.32      ]),
#   array([0.93838455, 1.10881566, 0.06      ])],
#  [array([0.04749864, 0.12891336, 0.39      ]),
#   array([0.86380658, 0.14799144, 0.05      ])],
#  [array([0.0105041 , 0.28531051, 0.19      ]),
#   array([0.82425094, 0.39920905, 0.02      ])],
#  [array([0.02437881, 0.81830574, 0.4       ]),
#   array([0.97246076, 0.81830574, 0.31      ])],
#  [array([0.34939207, 0.15446555, 0.04      ]),
#   array([1.06017373, 0.15446555, 0.25      ])],
#  [array([0.00366353, 0.14600909, 0.45      ]),
#   array([0.77914494, 0.14600909, 0.26      ])],
#  [array([0.21038899, 0.7022257 , 0.18      ]),
#   array([1.08622921, 0.7022257 , 0.33      ])],
#  [array([0.03916684, 0.25235821, 0.59      ]),
#   array([1.05212079, 0.25235821, 0.17      ])],
#  [array([0.06145367, 0.11916886, 0.45      ]),
#   array([0.91131532, 0.11916886, 0.26      ])],
#  [array([0.08761492, 0.26243752, 0.39      ]),
#   array([1.01562656, 0.26243752, 0.56      ])],
#  [array([9.15505674e-02, 1.00000000e+04, 1.20000000e-01]),
#   array([8.77886079e-01, 1.00000000e+04, 6.00000000e-02])],
#  [array([0.1359878 , 0.20232174, 0.86      ]),
#   array([1.26631904, 0.20232174, 0.51      ])],
#  [array([0.10934433, 0.22554944, 0.45      ]),
#   array([1.16802464, 0.22554944, 0.18      ])],
#  [array([0.12581803, 0.40323819, 0.2       ]),
#   array([1.1074387 , 0.40323819, 0.14      ])],
#  [array([0.05546752, 0.16118802, 0.03      ]),
#   array([1.00017954, 0.16118802, 0.26      ])],
#  [array([0.04885938, 0.29313013, 0.73      ]),
#   array([0.98412419, 0.29313013, 0.18      ])],
#  [array([3.33288906e-02, 1.00000000e+04, 4.50000000e-01]),
#   array([8.19987109e-01, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.02071113, 0.36822877, 0.2       ]),
#   array([1.21932357, 0.36822877, 0.14      ])],
#  [array([2.17553218e-01, 1.00000000e+04, 4.30000000e-01]),
#   array([9.90887652e-01, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.0649397 , 0.26988922, 0.48      ]),
#   array([1.04232017, 0.36965516, 0.33      ])],
#  [array([0.0569571 , 3.00970323, 0.44      ]),
#   array([0.84711918, 3.00970323, 0.31      ])],
#  [array([0.01255456, 0.25662487, 0.62      ]),
#   array([0.8618024 , 0.34521584, 0.04      ])],
#  [array([0.1580213 , 0.18384048, 0.14      ]),
#   array([1.04362714, 0.22525067, 0.57      ])],
#  [array([0.01637287, 0.27239641, 0.37      ]),
#   array([0.82003693, 0.37437474, 0.02      ])],
#  [array([0.02302752, 8.25013941, 0.08      ]),
#   array([0.9944432 , 8.25013941, 0.33      ])],
#  [array([0.10964596, 0.31366369, 0.92      ]),
#   array([1.0881434 , 0.31366369, 0.04      ])],
#  [array([0.05641579, 0.4628713 , 0.38      ]),
#   array([0.96021091, 0.4628713 , 0.03      ])],
#  [array([0.10434918, 0.218597  , 0.87      ]),
#   array([1.18350342, 0.218597  , 0.56      ])],
#  [array([0.01017054, 0.66987288, 0.41      ]),
#   array([0.80977642, 0.66987288, 0.31      ])],
#  [array([0.05091227, 0.11146204, 0.2       ]),
#   array([0.87885472, 0.11146204, 0.26      ])],
#  [array([0.04393634, 0.34009875, 0.26      ]),
#   array([0.94216488, 0.34009875, 0.33      ])],
#  [array([0.02168406, 0.10443442, 0.08      ]),
#   array([0.93165572, 0.11661281, 0.31      ])],
#  [array([0.14947693, 1.64093862, 0.01      ]),
#   array([8.92828273e-01, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.06841476, 0.22606696, 0.91      ]),
#   array([1.06243476, 0.22606696, 1.        ])],
#  [array([0.12613057, 3.62205255, 0.01      ]),
#   array([8.9828726e-01, 1.0000000e+04, 4.9000000e-01])],
#  [array([0.06912727, 0.15153936, 0.12      ]),
#   array([0.88126172, 0.17860506, 0.77      ])],
#  [array([0.01034145, 0.19169842, 0.39      ]),
#   array([0.8010793 , 0.19169842, 0.9       ])],
#  [array([0.2094961 , 0.48098599, 0.14      ]),
#   array([1.02771869, 0.48098599, 0.06      ])],
#  [array([0.0370588 , 0.24368891, 0.13      ]),
#   array([1.08421577, 0.24368891, 0.18      ])],
#  [array([0.06919179, 0.19491142, 0.87      ]),
#   array([1.13924505, 0.19491142, 0.56      ])],
#  [array([0.24341397, 0.46792585, 0.26      ]),
#   array([1.27529124, 0.46792585, 0.06      ])],
#  [array([0.04326503, 0.13789941, 0.35      ]),
#   array([0.818209  , 0.15995745, 0.05      ])],
#  [array([0.09270856, 0.12834645, 0.37      ]),
#   array([1.00260909, 0.12834645, 0.24      ])],
#  [array([0.12604778, 0.13854649, 0.31      ]),
#   array([0.84930857, 0.16082874, 0.37      ])],
#  [array([0.01635157, 0.17012709, 0.03      ]),
#   array([0.96102448, 0.20500379, 0.67      ])],
#  [array([0.15202816, 1.42660323, 0.16      ]),
#   array([1.11296837, 1.42660323, 0.31      ])],
#  [array([0.02350445, 0.1297591 , 0.18      ]),
#   array([1.05179826, 0.1297591 , 0.2       ])],
#  [array([0.3578864 , 1.10698804, 0.16      ]),
#   array([1.07218259, 1.10698804, 0.02      ])],
#  [array([5.24604232e-02, 1.00000000e+04, 4.80000000e-01]),
#   array([1.0117014e+00, 1.0000000e+04, 2.1000000e-01])],
#  [array([0.00614798, 0.40680394, 0.17      ]),
#   array([0.80011959, 0.68578329, 0.33      ])],
#  [array([8.31179459e-03, 1.00000000e+04, 4.10000000e-01]),
#   array([8.76033857e-01, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.01290981, 0.37860594, 0.49      ]),
#   array([0.8660639 , 0.60928477, 0.06      ])],
#  [array([0.03244523, 1.5598126 , 0.03      ]),
#   array([8.45842119e-01, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.07419298, 0.50597025, 0.4       ]),
#   array([1.0049271 , 0.50597025, 0.31      ])],
#  [array([0.07817314, 0.17627811, 0.82      ]),
#   array([0.98388341, 0.17627811, 0.18      ])],
#  [array([0.00486199, 0.14724321, 0.24      ]),
#   array([0.78508367, 0.14724321, 0.2       ])],
#  [array([0.04745197, 0.18827111, 0.36      ]),
#   array([1.15402807, 0.18827111, 0.24      ])],
#  [array([0.01412715, 0.10782875, 0.28      ]),
#   array([0.7986811 , 0.12086105, 0.16      ])],
#  [array([0.00982214, 1.26062101, 0.14      ]),
#   array([7.9325297e-01, 1.0000000e+04, 2.0000000e-02])],
#  [array([0.30410843, 0.27961979, 0.39      ]),
#   array([1.08544934, 0.27961979, 0.56      ])],
#  [array([0.02553532, 1.35344578, 0.46      ]),
#   array([8.66005089e-01, 1.00000000e+04, 2.00000000e-02])],
#  [array([0.01678619, 0.13713467, 0.43      ]),
#   array([0.93976531, 0.15892939, 0.25      ])],
#  [array([0.01556281, 0.12254946, 0.49      ]),
#   array([0.9333598 , 0.13966538, 0.35      ])],
#  [array([0.01667766, 0.34706711, 0.04      ]),
#   array([1.21736902, 0.34706711, 0.33      ])],
#  [array([0.24123765, 0.15782137, 0.04      ]),
#   array([1.00471877, 0.15782137, 0.49      ])],
#  [array([0.01545214, 0.25363427, 0.45      ]),
#   array([1.40042582, 0.25363427, 0.49      ])],
#  [array([0.01489606, 0.30063012, 0.37      ]),
#   array([0.8884882 , 0.42985855, 0.06      ])],
#  [array([0.0250624 , 0.11135488, 0.31      ]),
#   array([0.82515726, 0.11135488, 0.31      ])],
#  [array([0.01106118, 0.22565406, 0.11      ]),
#   array([0.77971919, 0.22565406, 0.71      ])],
#  [array([0.0094535 , 0.11406229, 0.14      ]),
#   array([0.79839471, 0.12874752, 0.24      ])],
#  [array([0.02837401, 0.13615354, 0.14      ]),
#   array([0.76828055, 0.13615354, 0.35      ])],
#  [array([0.03442567, 0.78374023, 0.49      ]),
#   array([0.92971625, 0.78374023, 0.02      ])],
#  [array([0.00813758, 0.13277191, 0.07      ]),
#   array([0.79278481, 0.15309918, 0.23      ])],
#  [array([0.07351255, 0.11441497, 0.13      ]),
#   array([1.14280808, 0.11441497, 0.37      ])],
#  [array([0.03288416, 0.11347796, 0.32      ]),
#   array([0.89958394, 0.11347796, 0.19      ])],
#  [array([0.08282207, 0.14844274, 0.34      ]),
#   array([0.93639725, 0.14844274, 0.23      ])],
#  [array([0.09555351, 5.55025672, 0.06      ]),
#   array([1.05503976e+00, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.0784893 , 0.11598146, 0.3       ]),
#   array([1.09922833, 0.11598146, 0.31      ])],
#  [array([1.34328131e-01, 1.00000000e+04, 4.00000000e-02]),
#   array([1.09578987e+00, 1.00000000e+04, 3.30000000e-01])],
#  [array([0.03855418, 0.23999805, 0.3       ]),
#   array([0.87867926, 0.31578609, 0.91      ])],
#  [array([0.01448443, 0.11447523, 0.49      ]),
#   array([0.77723614, 0.12927388, 0.35      ])],
#  [array([0.03613285, 0.15388101, 0.59      ]),
#   array([0.88733994, 0.18186687, 1.        ])],
#  [array([0.25393545, 0.30863599, 0.96      ]),
#   array([1.01737293, 0.30863599, 0.9       ])],
#  [array([0.09300161, 0.1720074 , 0.84      ]),
#   array([1.06063259, 0.20774027, 0.24      ])],
#  [array([0.00570278, 0.1127768 , 0.43      ]),
#   array([0.82880113, 0.1127768 , 0.16      ])],
#  [array([0.02734614, 0.24444112, 0.86      ]),
#   array([0.92130966, 0.32352358, 0.18      ])],
#  [array([0.10587438, 0.16587217, 0.08      ]),
#   array([1.08866947, 0.16587217, 0.25      ])],
#  [array([0.05316336, 0.24626246, 0.22      ]),
#   array([0.85199748, 0.24626246, 0.57      ])],
#  [array([0.15043551, 0.17935405, 0.62      ]),
#   array([1.22700445, 0.17935405, 0.57      ])],
#  [array([0.09347744, 0.20744608, 0.12      ]),
#   array([1.25150349, 0.20744608, 0.71      ])],
#  [array([0.08489456, 0.12343446, 0.2       ]),
#   array([1.04086752, 0.140816  , 0.26      ])],
#  [array([0.01251706, 0.39055682, 0.27      ]),
#   array([0.86496911, 0.64084206, 0.03      ])],
#  [array([0.08677892, 2.81524425, 0.29      ]),
#   array([1.17738663, 2.81524425, 0.32      ])],
#  [array([0.23465828, 0.16944455, 0.12      ]),
#   array([1.38310034, 0.16944455, 0.07      ])],
#  [array([0.12983113, 0.13378441, 0.2       ]),
#   array([1.08285378, 0.13378441, 0.37      ])],
#  [array([0.04958942, 0.20881937, 0.59      ]),
#   array([1.09944902, 0.20881937, 0.17      ])],
#  [array([0.2029774, 0.8695497, 0.16     ]),
#   array([1.28327844, 0.8695497 , 0.31      ])],
#  [array([0.0101548 , 0.35226962, 0.27      ]),
#   array([0.77380512, 0.35226962, 0.33      ])],
#  [array([0.05928763, 0.13020612, 0.09      ]),
#   array([0.98800712, 0.13020612, 0.23      ])],
#  [array([0.04948944, 0.38952934, 0.37      ]),
#   array([0.82288655, 0.63808036, 0.21      ])],
#  [array([0.17872791, 2.09873431, 0.43      ]),
#   array([1.20300504, 2.09873431, 0.28      ])],
#  [array([0.05870015, 0.10808969, 0.3       ]),
#   array([0.87489579, 0.12118896, 0.31      ])],
#  [array([0.02151364, 0.2588776 , 0.81      ]),
#   array([0.97031989, 0.2588776 , 1.        ])],
#  [array([0.22205965, 0.71956963, 0.04      ]),
#   array([1.30663509, 0.71956963, 0.33      ])],
#  [array([0.03134059, 0.20761307, 0.79      ]),
#   array([0.80694599, 0.26200971, 0.24      ])],
#  [array([0.0207784 , 0.10592933, 0.32      ]),
#   array([0.9149611 , 0.11847982, 0.35      ])],
#  [array([0.03418765, 0.27798152, 0.01      ]),
#   array([0.93770311, 0.27798152, 0.17      ])],
#  [array([0.17576215, 0.14682841, 0.2       ]),
#   array([1.36364065, 0.14682841, 0.16      ])],
#  [array([0.00942964, 0.15018578, 0.24      ]),
#   array([0.79419242, 0.17672778, 0.05      ])],
#  [array([0.00500562, 0.15622623, 0.11      ]),
#   array([0.75814102, 0.15622623, 0.37      ])],
#  [array([2.25485738e-01, 1.00000000e+04, 3.80000000e-01]),
#   array([1.37798037e+00, 1.00000000e+04, 2.10000000e-01])],
#  [array([0.02300123, 2.96826322, 0.44      ]),
#   array([0.83150347, 2.96826322, 0.31      ])],
#  [array([0.09205915, 0.16063389, 0.3       ]),
#   array([1.14459291, 0.16063389, 0.31      ])],
#  [array([0.03060253, 0.14995184, 0.06      ]),
#   array([1.20124636, 0.14995184, 0.43      ])],
#  [array([0.18297672, 0.52518017, 0.26      ]),
#   array([1.21666835, 0.52518017, 0.33      ])],
#  [array([0.02121073, 1.05340377, 0.42      ]),
#   array([7.94498564e-01, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.00911315, 0.47187566, 0.21      ]),
#   array([0.80044858, 0.8934935 , 0.32      ])],
#  [array([0.01824867, 0.15367815, 0.68      ]),
#   array([0.8003413 , 0.18158357, 0.18      ])],
#  [array([0.02028232, 0.3684811 , 0.38      ]),
#   array([0.88756513, 0.3684811 , 0.08      ])],
#  [array([0.18657573, 1.56805741, 0.43      ]),
#   array([1.0118991 , 1.56805741, 0.21      ])],
#  [array([0.05958347, 0.11579506, 0.13      ]),
#   array([1.00013901, 0.13095953, 0.25      ])],
#  [array([0.33877347, 0.25816745, 0.47      ]),
#   array([1.05432245, 0.25816745, 0.57      ])],
#  [array([0.24069418, 0.12700072, 0.34      ]),
#   array([1.08898913, 0.12700072, 0.23      ])],
#  [array([0.06825762, 0.13313776, 0.33      ]),
#   array([1.02665131, 0.15358584, 0.19      ])],
#  [array([0.00762005, 0.11762098, 0.1       ]),
#   array([0.87878199, 0.13329984, 0.25      ])],
#  [array([0.15659788, 0.34866466, 0.26      ]),
#   array([1.24003429, 0.34866466, 0.33      ])],
#  [array([0.05178307, 0.13406969, 0.13      ]),
#   array([0.87324953, 0.13406969, 0.2       ])],
#  [array([0.31869094, 0.36656899, 0.38      ]),
#   array([1.18048693, 0.57870389, 0.02      ])],
#  [array([0.05657695, 0.14061028, 0.45      ]),
#   array([1.03657785, 0.14061028, 0.26      ])],
#  [array([0.10805401, 0.17328966, 0.91      ]),
#   array([1.16798056, 0.17328966, 1.        ])],
#  [array([0.00842346, 0.40452539, 0.44      ]),
#   array([0.77076332, 0.40452539, 0.03      ])],
#  [array([0.00719326, 0.19990613, 0.8       ]),
#   array([0.93179561, 0.24985335, 1.        ])],
#  [array([0.04026054, 0.11837648, 0.35      ]),
#   array([1.12465886, 0.11837648, 0.24      ])],
#  [array([0.00896617, 0.16447481, 0.13      ]),
#   array([0.76837854, 0.16447481, 0.2       ])],
#  [array([0.23189752, 0.20784001, 0.08      ]),
#   array([1.39422899, 0.20784001, 0.17      ])],
#  [array([0.0508442 , 0.13634586, 0.16      ]),
#   array([0.89067308, 0.13634586, 0.35      ])],
#  [array([0.13981384, 0.19279951, 0.47      ]),
#   array([1.10268936, 0.19279951, 0.57      ])],
#  [array([0.00994228, 0.11607537, 0.3       ]),
#   array([0.78809709, 0.13131818, 0.31      ])],
#  [array([0.01929781, 1.68086926, 0.09      ]),
#   array([9.25836371e-01, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.10739526, 0.35484758, 0.22      ]),
#   array([1.0161748 , 0.35484758, 0.33      ])],
#  [array([0.01646522, 1.02622615, 0.01      ]),
#   array([0.85477618, 1.02622615, 0.06      ])],
#  [array([0.18757804, 0.43228588, 0.92      ]),
#   array([1.1026662 , 0.43228588, 0.04      ])],
#  [array([0.32502964, 0.16006428, 0.87      ]),
#   array([1.18419468, 0.19056729, 0.77      ])],
#  [array([0.12514802, 0.18038414, 0.12      ]),
#   array([1.19917778, 0.18038414, 0.07      ])],
#  [array([0.0229682, 0.1118231, 0.45     ]),
#   array([0.96510955, 0.12590183, 0.33      ])],
#  [array([1.05102306e-01, 1.00000000e+04, 4.00000000e-01]),
#   array([1.04692939e+00, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.02028874, 0.57779153, 0.45      ]),
#   array([1.02151689, 0.57779153, 0.21      ])],
#  [array([0.02693201, 0.19493116, 0.7       ]),
#   array([0.86701216, 0.24212981, 0.56      ])],
#  [array([0.38827689, 0.13672242, 0.09      ]),
#   array([1.13596941, 0.15837597, 0.2       ])],
#  [array([0.01759093, 4.89410129, 0.49      ]),
#   array([0.82229421, 4.89410129, 0.33      ])],
#  [array([0.18336401, 0.564485  , 0.2       ]),
#   array([1.32537411, 0.564485  , 0.14      ])],
#  [array([0.02443403, 1.16590188, 0.48      ]),
#   array([0.81957542, 1.16590188, 0.33      ])],
#  [array([0.04811317, 0.48746679, 0.44      ]),
#   array([1.20151878, 0.48746679, 0.38      ])],
#  [array([0.04397029, 0.52032914, 0.16      ]),
#   array([1.12494438, 0.52032914, 0.31      ])],
#  [array([0.14956341, 0.12947344, 0.34      ]),
#   array([0.909798  , 0.14873003, 0.35      ])],
#  [array([0.06461217, 1.43606442, 0.17      ]),
#   array([1.16880517, 1.43606442, 0.16      ])],
#  [array([0.10859202, 0.13456037, 0.19      ]),
#   array([0.86158078, 0.1554821 , 0.37      ])],
#  [array([0.13032724, 4.03404184, 0.05      ]),
#   array([1.10665813e+00, 1.00000000e+04, 1.40000000e-01])],
#  [array([0.01317056, 1.74078791, 0.37      ]),
#   array([8.05355631e-01, 1.00000000e+04, 6.00000000e-02])],
#  [array([0.0522118 , 0.17607345, 0.43      ]),
#   array([1.1076849 , 0.21370042, 0.08      ])],
#  [array([0.05974494, 0.16277831, 0.41      ]),
#   array([1.13902812, 0.16277831, 0.23      ])],
#  [array([0.00435503, 0.14150949, 0.2       ]),
#   array([1.03063361, 0.16483524, 0.23      ])],
#  [array([0.02558026, 0.30553255, 0.32      ]),
#   array([0.83474708, 0.4399523 , 0.04      ])],
#  [array([0.02312654, 0.19313341, 0.38      ]),
#   array([0.91439925, 0.23936226, 0.24      ])],
#  [array([1.1194748e-02, 1.0000000e+04, 6.0000000e-02]),
#   array([7.95910229e-01, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.02951805, 0.5560644 , 0.13      ]),
#   array([0.89208342, 0.5560644 , 0.14      ])],
#  [array([0.14928088, 3.99434614, 0.01      ]),
#   array([8.94267849e-01, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.16815844, 0.14354629, 0.29      ]),
#   array([1.38900045, 0.14354629, 0.46      ])],
#  [array([0.21231942, 0.13113289, 0.15      ]),
#   array([0.98748707, 0.13113289, 0.26      ])],
#  [array([0.12733081, 0.14269584, 0.03      ]),
#   array([1.11793881, 0.14269584, 0.19      ])],
#  [array([0.17154457, 0.18255575, 0.14      ]),
#   array([1.06173363, 0.22332502, 0.57      ])],
#  [array([0.04322341, 0.18076405, 0.1       ]),
#   array([0.86521366, 0.22064956, 0.67      ])],
#  [array([0.00993314, 0.15092185, 0.24      ]),
#   array([0.78171307, 0.15092185, 0.33      ])],
#  [array([0.19617676, 0.5538642 , 0.01      ]),
#   array([0.97424753, 1.24146999, 0.49      ])],
#  [array([0.04562482, 0.73165928, 0.39      ]),
#   array([1.18657777, 0.73165928, 0.49      ])],
#  [array([0.0754632 , 0.21075619, 0.87      ]),
#   array([1.15002621, 0.21075619, 0.56      ])],
#  [array([1.48527683e-02, 1.00000000e+04, 4.70000000e-01]),
#   array([7.63250963e-01, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.07223024, 0.14165715, 0.36      ]),
#   array([1.24409847, 0.14165715, 0.33      ])],
#  [array([0.21460746, 0.59644884, 0.35      ]),
#   array([1.25062665, 0.59644884, 0.21      ])],
#  [array([0.04951243, 0.13295776, 0.11      ]),
#   array([1.04349457, 0.13295776, 0.43      ])],
#  [array([0.03051012, 0.30398487, 0.41      ]),
#   array([0.9753694 , 0.43675038, 0.04      ])],
#  [array([0.01414881, 0.25826057, 0.41      ]),
#   array([0.82062801, 0.34818234, 0.31      ])],
#  [array([0.19783532, 0.13790934, 0.32      ]),
#   array([1.31269553, 0.13790934, 0.25      ])],
#  [array([0.06976901, 0.15265537, 0.11      ]),
#   array([1.01035362, 0.15265537, 0.19      ])],
#  [array([0.03319944, 0.18209056, 0.04      ]),
#   array([0.81900012, 0.18209056, 0.05      ])],
#  [array([0.03690897, 0.34057334, 0.64      ]),
#   array([0.79742956, 0.34057334, 0.17      ])],
#  [array([0.01101799, 1.1247922 , 0.49      ]),
#   array([0.76608632, 1.1247922 , 0.28      ])],
#  [array([0.02220594, 0.50241043, 0.16      ]),
#   array([1.22252907, 0.50241043, 0.49      ])],
#  [array([0.08463469, 0.33034638, 0.13      ]),
#   array([1.31123492, 0.33034638, 1.        ])],
#  [array([0.00721774, 0.11254711, 0.16      ]),
#   array([0.79573431, 0.12682038, 0.34      ])],
#  [array([0.23799497, 0.12094089, 0.35      ]),
#   array([1.3245242 , 0.12094089, 0.24      ])],
#  [array([0.09305315, 0.19444867, 0.15      ]),
#   array([1.24477909, 0.19444867, 0.16      ])],
#  [array([0.03689635, 0.12508485, 0.49      ]),
#   array([0.96353707, 0.12508485, 0.07      ])],
#  [array([0.18064866, 0.34471401, 0.18      ]),
#   array([1.05618168, 0.34471401, 0.33      ])],
#  [array([5.24494623e-02, 1.00000000e+04, 1.30000000e-01]),
#   array([1.1775825e+00, 1.0000000e+04, 2.1000000e-01])],
#  [array([0.18544435, 0.78088125, 0.15      ]),
#   array([1.01680639, 0.78088125, 0.01      ])],
#  [array([0.23110079, 0.23234914, 0.13      ]),
#   array([1.29347406, 0.23234914, 1.        ])],
#  [array([0.28551181, 0.64023306, 0.38      ]),
#   array([1.06314848, 1.77957723, 0.02      ])],
#  [array([0.00348993, 0.18212574, 0.96      ]),
#   array([1.03222131, 0.22268184, 0.17      ])],
#  [array([0.04481923, 0.19917826, 0.37      ]),
#   array([1.08318279, 0.19917826, 0.76      ])],
#  [array([0.02156902, 0.16739831, 0.04      ]),
#   array([0.79008777, 0.20105449, 0.18      ])],
#  [array([0.01597724, 0.12354299, 0.36      ]),
#   array([0.93543464, 0.14095727, 0.2       ])],
#  [array([0.01076591, 0.70857365, 0.36      ]),
#   array([0.75438875, 2.43139874, 0.49      ])],
#  [array([0.02028832, 0.17769935, 0.07      ]),
#   array([0.89663144, 0.21610022, 0.57      ])],
#  [array([0.00273544, 0.11172987, 0.45      ]),
#   array([0.78074887, 0.11172987, 0.26      ])],
#  [array([0.2958773 , 0.33292628, 0.91      ]),
#   array([1.25487076, 0.33292628, 1.        ])],
#  [array([0.30472298, 0.15727836, 0.14      ]),
#   array([1.20931528, 0.18663145, 0.57      ])],
#  [array([2.10080812e-02, 1.00000000e+04, 1.90000000e-01]),
#   array([9.36510044e-01, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.05626288, 0.69791272, 0.44      ]),
#   array([0.88462847, 0.69791272, 0.31      ])],
#  [array([0.06090139, 0.15580776, 0.03      ]),
#   array([0.99680028, 0.18456432, 0.67      ])],
#  [array([0.03048299, 0.14560561, 0.08      ]),
#   array([0.89049439, 0.17041968, 0.76      ])],
#  [array([0.09863526, 0.14976252, 0.05      ]),
#   array([1.24791957, 0.14976252, 0.25      ])],
#  [array([5.56750905e-03, 1.00000000e+04, 4.30000000e-01]),
#   array([8.33333097e-01, 1.00000000e+04, 3.60000000e-01])],
#  [array([0.08689905, 2.67173991, 0.38      ]),
#   array([1.04280671e+00, 1.00000000e+04, 2.00000000e-02])],
#  [array([0.01571897, 0.32573476, 0.78      ]),
#   array([0.90359556, 0.32573476, 0.32      ])],
#  [array([0.00840079, 0.19513744, 0.19      ]),
#   array([0.92437198, 0.24244815, 0.24      ])],
#  [array([0.04556475, 0.5346002 , 0.2       ]),
#   array([1.13153863, 0.5346002 , 0.31      ])],
#  [array([0.01070067, 0.24876577, 0.81      ]),
#   array([0.77437938, 0.24876577, 0.42      ])],
#  [array([0.08404865, 0.73045434, 0.05      ]),
#   array([1.06160089, 2.70994653, 0.14      ])],
#  [array([0.1478227 , 0.14667425, 0.44      ]),
#   array([0.9882936 , 0.17188542, 0.05      ])],
#  [array([0.02557262, 0.11206538, 0.48      ]),
#   array([1.01534629, 0.12620905, 0.33      ])],
#  [array([0.11697758, 1.41807695, 0.2       ]),
#   array([1.10928406, 1.41807695, 0.31      ])],
#  [array([0.0066279, 0.200557 , 0.92     ]),
#   array([0.7873389, 0.200557 , 0.24     ])],
#  [array([0.3036131 , 0.79134315, 0.43      ]),
#   array([1.01965982, 0.79134315, 0.33      ])],
#  [array([0.03096931, 0.13025867, 0.14      ]),
#   array([0.88631225, 0.14976714, 0.05      ])],
#  [array([0.0049613 , 0.15243788, 0.68      ]),
#   array([0.77632164, 0.17985452, 0.16      ])],
#  [array([0.02505644, 0.19568497, 0.98      ]),
#   array([0.79122484, 0.24329393, 0.51      ])],
#  [array([0.05945062, 1.64957805, 0.48      ]),
#   array([0.99924426, 1.64957805, 0.03      ])],
#  [array([0.17098094, 0.30569107, 0.75      ]),
#   array([1.03259313, 0.30569107, 0.18      ])],
#  [array([0.04868579, 0.16436398, 0.09      ]),
#   array([0.9954571 , 0.16436398, 0.23      ])],
#  [array([0.10873061, 0.20730251, 0.87      ]),
#   array([1.10108302, 0.20730251, 0.56      ])],
#  [array([0.00516894, 0.22489118, 0.15      ]),
#   array([0.78751802, 0.29014143, 0.5       ])],
#  [array([7.97768262e-02, 1.00000000e+04, 3.30000000e-01]),
#   array([1.13871985e+00, 1.00000000e+04, 6.00000000e-02])],
#  [array([0.13741899, 0.18740196, 0.07      ]),
#   array([0.87889293, 0.18740196, 0.32      ])],
#  [array([0.25895967, 0.11674296, 0.3       ]),
#   array([1.27259408, 0.11674296, 0.23      ])],
#  [array([0.0316317 , 0.41494068, 0.12      ]),
#   array([1.07740623, 0.41494068, 0.33      ])],
#  [array([0.15450773, 0.13889032, 0.44      ]),
#   array([1.23254168, 0.13889032, 0.26      ])],
#  [array([9.88229113e-02, 1.00000000e+04, 1.30000000e-01]),
#   array([1.31267177e+00, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.04865339, 1.4911683 , 0.08      ]),
#   array([1.07303094, 1.4911683 , 0.32      ])],
#  [array([0.24076457, 0.31969534, 0.39      ]),
#   array([1.09542764, 0.31969534, 0.56      ])],
#  [array([0.06109537, 0.21025287, 0.43      ]),
#   array([1.08504581, 0.2662281 , 0.08      ])],
#  [array([0.18035348, 0.13544106, 0.03      ]),
#   array([1.12537118, 0.13544106, 0.26      ])],
#  [array([0.152078  , 0.16915422, 0.3       ]),
#   array([1.16161574, 0.16915422, 0.67      ])],
#  [array([0.25845636, 0.1538758 , 0.01      ]),
#   array([1.22446837, 0.18185959, 0.91      ])],
#  [array([0.00127428, 0.31301742, 0.9       ]),
#   array([0.99247557, 0.31301742, 0.77      ])],
#  [array([0.16437328, 0.52577135, 0.24      ]),
#   array([1.32095024, 0.52577135, 0.06      ])],
#  [array([0.25174724, 0.2356541 , 0.84      ]),
#   array([1.14538587, 0.30830819, 0.24      ])],
#  [array([0.01060648, 0.10727731, 0.22      ]),
#   array([0.81549728, 0.12016868, 0.26      ])],
#  [array([0.01806626, 0.33157587, 0.24      ]),
#   array([0.80427051, 0.4960561 , 0.32      ])],
#  [array([0.26092581, 0.34970771, 0.92      ]),
#   array([1.00079734, 0.34970771, 0.04      ])],
#  [array([0.22489677, 0.14429245, 0.33      ]),
#   array([1.23070335, 0.14429245, 0.35      ])],
#  [array([0.02652848, 0.11518104, 0.11      ]),
#   array([1.06196872, 0.11518104, 0.43      ])],
#  [array([0.24144374, 0.47130529, 0.23      ]),
#   array([1.32826968, 0.47130529, 0.03      ])],
#  [array([0.00596967, 0.16725194, 0.74      ]),
#   array([0.7644817 , 0.20084338, 0.9       ])],
#  [array([0.0029338 , 0.17088495, 0.82      ]),
#   array([0.83766008, 0.17088495, 0.71      ])],
#  [array([0.14092679, 0.43100123, 0.08      ]),
#   array([1.29743878, 0.43100123, 0.02      ])],
#  [array([0.06817933, 0.11268272, 0.16      ]),
#   array([1.27855567, 0.11268272, 0.2       ])],
#  [array([0.04635375, 0.41080634, 0.25      ]),
#   array([0.87536611, 0.69723482, 0.02      ])],
#  [array([0.01233342, 0.14488311, 0.13      ]),
#   array([0.81677346, 0.16943076, 0.33      ])],
#  [array([0.0439008 , 0.12911846, 0.49      ]),
#   array([0.93721473, 0.12911846, 0.07      ])],
#  [array([5.25687893e-02, 1.00000000e+04, 1.30000000e-01]),
#   array([1.19090905e+00, 1.00000000e+04, 4.90000000e-01])],
#  [array([9.08669121e-02, 1.00000000e+04, 1.60000000e-01]),
#   array([1.12568457e+00, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.0047448 , 0.16024082, 0.08      ]),
#   array([0.75880955, 0.16024082, 0.23      ])],
#  [array([0.00810202, 0.13805041, 0.12      ]),
#   array([0.77384329, 0.13805041, 0.35      ])],
#  [array([0.02905598, 0.15219374, 0.25      ]),
#   array([1.06432044, 0.15219374, 0.2       ])],
#  [array([0.03707834, 0.14136432, 0.12      ]),
#   array([0.86912033, 0.14136432, 0.43      ])],
#  [array([4.84358484e-02, 1.00000000e+04, 4.30000000e-01]),
#   array([1.04327246e+00, 1.00000000e+04, 2.10000000e-01])],
#  [array([0.00316735, 0.28077051, 0.94      ]),
#   array([0.80215137, 0.28077051, 0.56      ])],
#  [array([0.05312689, 0.40894672, 0.3       ]),
#   array([1.19070338, 0.40894672, 0.16      ])],
#  [array([0.00124826, 0.14206066, 0.24      ]),
#   array([1.00884839, 0.14206066, 0.49      ])],
#  [array([0.05633313, 0.17162467, 0.22      ]),
#   array([1.08347986, 0.17162467, 0.16      ])],
#  [array([0.02766016, 0.14792072, 0.04      ]),
#   array([0.95631272, 0.14792072, 0.19      ])],
#  [array([0.02783293, 0.18065741, 0.45      ]),
#   array([1.11131338, 0.18065741, 0.5       ])],
#  [array([0.01895791, 0.28027064, 0.05      ]),
#   array([0.82072787, 0.38941116, 0.33      ])],
#  [array([0.00372583, 0.11140968, 0.06      ]),
#   array([1.01615159, 0.11140968, 0.31      ])],
#  [array([0.0179649 , 0.41763179, 0.18      ]),
#   array([0.82942517, 0.71712669, 0.14      ])],
#  [array([0.07622593, 2.71900524, 0.5       ]),
#   array([1.30136642, 2.71900524, 0.33      ])],
#  [array([0.02458608, 0.10620439, 0.38      ]),
#   array([0.89415872, 0.11882402, 0.37      ])],
#  [array([0.03332492, 0.25466785, 0.78      ]),
#   array([0.8843299 , 0.25466785, 0.32      ])],
#  [array([0.00434579, 0.74295442, 0.28      ]),
#   array([0.82936478, 0.74295442, 0.26      ])],
#  [array([0.04151955, 0.17972052, 0.03      ]),
#   array([1.02525225, 0.17972052, 0.67      ])],
#  [array([0.0402866 , 0.13931704, 0.16      ]),
#   array([0.96838242, 0.13931704, 0.07      ])],
#  [array([1.02408252e-01, 1.00000000e+04, 1.20000000e-01]),
#   array([1.00534021e+00, 1.00000000e+04, 3.10000000e-01])],
#  [array([ 0.14135528, 86.20836312,  0.26      ]),
#   array([ 1.15072523, 86.20836312,  0.14      ])],
#  [array([0.16143148, 0.10576395, 0.04      ]),
#   array([0.91440441, 0.11827296, 0.37      ])],
#  [array([0.01518414, 0.16402525, 0.27      ]),
#   array([1.03547742, 0.16402525, 0.46      ])],
#  [array([0.00855338, 0.18578882, 0.28      ]),
#   array([0.78737337, 0.18578882, 0.77      ])],
#  [array([0.10227475, 0.15971521, 0.16      ]),
#   array([1.31243624, 0.15971521, 0.2       ])],
#  [array([0.12798637, 0.51081887, 0.24      ]),
#   array([1.16109343, 0.51081887, 0.33      ])],
#  [array([0.08861799, 0.34219415, 0.14      ]),
#   array([1.1146233 , 0.34219415, 0.06      ])],
#  [array([0.01327208, 0.13248676, 0.23      ]),
#   array([0.7867512 , 0.15272016, 0.49      ])],
#  [array([0.11018254, 1.02997589, 0.07      ]),
#   array([1.06955959, 1.02997589, 0.14      ])],
#  [array([0.0907855 , 0.14987051, 0.05      ]),
#   array([1.04149815, 0.14987051, 0.2       ])],
#  [array([0.18804261, 1.83022473, 0.04      ]),
#   array([1.20443241, 1.83022473, 0.28      ])],
#  [array([0.05628309, 0.11867129, 0.42      ]),
#   array([0.98467037, 0.11867129, 0.37      ])],
#  [array([0.02287128, 1.07416157, 0.27      ]),
#   array([8.36185978e-01, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.02219091, 0.18519583, 0.41      ]),
#   array([0.94694095, 0.22728877, 0.42      ])],
#  [array([0.05342387, 0.13675875, 0.06      ]),
#   array([1.06569851, 0.13675875, 0.31      ])],
#  [array([0.06338816, 1.20855294, 0.1       ]),
#   array([1.14216603, 1.20855294, 0.26      ])],
#  [array([0.09549255, 0.38879847, 0.16      ]),
#   array([1.10263111, 0.38879847, 0.31      ])],
#  [array([0.01426247, 0.23371701, 0.32      ]),
#   array([0.84702204, 0.23371701, 0.9       ])],
#  [array([0.02430594, 0.2342919 , 0.79      ]),
#   array([0.92027472, 0.2342919 , 0.17      ])],
#  [array([0.1365677 , 0.16471407, 0.34      ]),
#   array([1.30209083, 0.16471407, 0.34      ])],
#  [array([0.01636678, 0.34892037, 0.04      ]),
#   array([1.21612995, 0.34892037, 0.33      ])],
#  [array([0.16484261, 0.53134167, 0.33      ]),
#   array([0.88490705, 1.1337506 , 0.14      ])],
#  [array([0.049388  , 0.24228207, 0.11      ]),
#   array([1.06179491, 0.24228207, 0.49      ])],
#  [array([0.07528533, 0.23591226, 0.18      ]),
#   array([1.23083258, 0.23591226, 0.67      ])],
#  [array([0.04367143, 3.63085928, 0.05      ]),
#   array([0.98757566, 3.63085928, 0.03      ])],
#  [array([0.04763018, 0.13771372, 0.02      ]),
#   array([0.99446514, 0.13771372, 0.2       ])],
#  [array([0.04074078, 0.20475696, 0.98      ]),
#   array([0.84983073, 0.25747721, 0.32      ])],
#  [array([0.05849144, 1.01829055, 0.12      ]),
#   array([1.24867976, 1.01829055, 0.11      ])],
# ...
#  [array([0.00279602, 0.26431861, 0.37      ]),
#   array([0.78175813, 0.35928408, 0.28      ])],
#  [array([0.27821604, 0.2765882 , 0.39      ]),
#   array([1.07702877, 0.2765882 , 0.56      ])],
#  [array([0.04360546, 0.26747255, 0.7       ]),
#   array([0.99181236, 0.26747255, 0.67      ])],
#  [array([1.33272575e-01, 1.00000000e+04, 3.10000000e-01]),
#   array([9.56652079e-01, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.03936362, 0.13238037, 0.4       ]),
#   array([0.97854786, 0.15257882, 0.24      ])],
#  [array([0.16197288, 0.12172351, 0.3       ]),
#   array([1.23447268, 0.12172351, 0.31      ])],
#  [array([0.02781586, 0.35538189, 0.28      ]),
#   array([0.88054248, 0.55130608, 0.14      ])],
#  [array([0.01768988, 0.56543849, 0.05      ]),
#   array([0.94938331, 0.56543849, 0.33      ])],
#  [array([0.13819126, 0.1349369 , 0.3       ]),
#   array([1.06545174, 0.1349369 , 0.23      ])],
#  [array([0.01639232, 0.13039077, 0.47      ]),
#   array([0.94921927, 0.13039077, 0.24      ])],
#  [array([0.03459756, 0.13809543, 0.34      ]),
#   array([1.16509999, 0.13809543, 0.34      ])],
#  [array([0.08391565, 1.00576328, 0.13      ]),
#   array([1.22474852, 1.00576328, 0.21      ])],
#  [array([7.67473038e-02, 1.00000000e+04, 1.80000000e-01]),
#   array([9.98855049e-01, 1.00000000e+04, 3.30000000e-01])],
#  [array([0.08172674, 0.19454517, 0.1       ]),
#   array([1.31282249, 0.19454517, 0.05      ])],
#  [array([0.0439141 , 0.85539035, 0.28      ]),
#   array([1.08479964, 0.85539035, 0.02      ])],
#  [array([0.10314717, 0.1366347 , 0.06      ]),
#   array([1.15294  , 0.1366347, 0.43     ])],
#  [array([0.04854692, 0.45067115, 0.34      ]),
#   array([0.8289147 , 0.82040321, 0.28      ])],
#  [array([0.03685955, 0.28579326, 0.13      ]),
#   array([0.91108596, 0.40015481, 0.32      ])],
#  [array([0.20462707, 0.17025286, 0.91      ]),
#   array([1.27462024, 0.17025286, 1.        ])],
#  [array([0.11599364, 0.13460394, 0.26      ]),
#   array([1.10654864, 0.15554027, 0.31      ])],
#  [array([0.09024879, 0.43948309, 0.29      ]),
#   array([1.11855583, 0.43948309, 0.32      ])],
#  [array([0.17109644, 4.3386034 , 0.26      ]),
#   array([1.09927134, 4.3386034 , 0.33      ])],
#  [array([0.01318219, 0.16470517, 0.42      ]),
#   array([0.78874147, 0.16470517, 0.43      ])],
#  [array([0.27137134, 0.56067181, 0.26      ]),
#   array([1.35425301, 0.56067181, 0.06      ])],
#  [array([0.02701294, 0.37385644, 0.48      ]),
#   array([0.96557983, 0.59707784, 0.33      ])],
#  [array([0.07168541, 2.45891534, 0.24      ]),
#   array([1.21931665, 2.45891534, 0.06      ])],
#  [array([0.03528197, 0.13110907, 0.35      ]),
#   array([0.97173525, 0.13110907, 0.31      ])],
#  [array([0.21787105, 0.19701491, 0.84      ]),
#   array([1.18796603, 0.24535313, 0.24      ])],
#  [array([0.19386286, 0.57484023, 0.04      ]),
#   array([1.17424334, 0.57484023, 0.28      ])],
#  [array([0.10682601, 0.55219165, 0.16      ]),
#   array([1.08811375, 0.55219165, 0.31      ])],
#  [array([0.12569795, 0.12482861, 0.22      ]),
#   array([0.86019681, 0.14263333, 0.35      ])],
#  [array([0.12112925, 0.17058466, 0.6       ]),
#   array([0.86517359, 0.17058466, 0.76      ])],
#  [array([0.11601594, 2.07753811, 0.29      ]),
#   array([1.23797214, 2.07753811, 0.28      ])],
#  [array([0.16275015, 0.4179914 , 0.85      ]),
#   array([1.31242066, 0.4179914 , 0.08      ])],
#  [array([0.06662407, 0.12340635, 0.33      ]),
#   array([0.95810702, 0.12340635, 0.31      ])],
#  [array([0.07766504, 0.20294532, 0.36      ]),
#   array([1.12923308, 0.20294532, 0.57      ])],
#  [array([0.06489998, 0.19935873, 0.47      ]),
#   array([1.03283696, 0.19935873, 0.57      ])],
#  [array([0.02325043, 1.84595043, 0.29      ]),
#   array([0.84215458, 1.84595043, 0.33      ])],
#  [array([0.01724384, 1.56411436, 0.14      ]),
#   array([0.76342466, 1.56411436, 0.38      ])],
#  [array([0.0191178 , 0.13942388, 0.07      ]),
#   array([0.88808049, 0.16201226, 0.05      ])],
#  [array([0.02332785, 0.19642842, 0.17      ]),
#   array([1.01188443, 0.24444421, 0.9       ])],
#  [array([0.25999638, 0.24655284, 0.92      ]),
#   array([1.16248127, 0.24655284, 0.04      ])],
#  [array([0.01594623, 0.22539251, 0.62      ]),
#   array([0.95512433, 0.29097641, 0.49      ])],
#  [array([0.03112657, 0.14539079, 0.12      ]),
#   array([0.88989099, 0.17012547, 0.24      ])],
#  [array([0.04258014, 0.11190601, 0.28      ]),
#   array([1.05521246, 0.11190601, 0.23      ])],
#  [array([0.0188368, 0.1347342, 0.02     ]),
#   array([0.84734382, 0.1347342 , 0.34      ])],
#  [array([1.284527e-01, 1.000000e+04, 3.100000e-01]),
#   array([1.07152106e+00, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.02205434, 0.11439027, 0.49      ]),
#   array([0.91209301, 0.11439027, 0.24      ])],
#  [array([0.00234156, 0.34484201, 0.32      ]),
#   array([0.78719451, 0.34484201, 0.28      ])],
#  [array([0.01084649, 3.97902523, 0.26      ]),
#   array([0.88131033, 3.97902523, 0.26      ])],
#  [array([1.62365633e-01, 1.00000000e+04, 2.60000000e-01]),
#   array([9.37386302e-01, 1.00000000e+04, 3.00000000e-02])],
#  [array([0.16479139, 0.13633397, 0.45      ]),
#   array([1.27138693, 0.13633397, 0.25      ])],
#  [array([0.00080632, 0.15839187, 0.35      ]),
#   array([0.75873858, 0.18820145, 0.71      ])],
#  [array([0.22786395, 0.14855438, 0.45      ]),
#   array([1.227449  , 0.14855438, 0.26      ])],
#  [array([0.05128778, 2.5957404 , 0.15      ]),
#   array([0.95946987, 2.5957404 , 0.21      ])],
#  [array([0.24124283, 0.17033786, 0.99      ]),
#   array([1.00232051, 0.17033786, 1.        ])],
#  [array([0.03385168, 0.20307389, 0.8       ]),
#   array([0.99935922, 0.20307389, 0.32      ])],
#  [array([0.03410363, 1.00526242, 0.16      ]),
#   array([1.10281713, 1.00526242, 0.31      ])],
#  [array([0.21020083, 0.80009838, 0.16      ]),
#   array([1.25930819, 0.80009838, 0.31      ])],
#  [array([0.02822853, 0.20108153, 0.6       ]),
#   array([0.87982765, 0.20108153, 0.56      ])],
#  [array([0.26908843, 2.30332159, 0.26      ]),
#   array([1.35316619, 2.30332159, 0.33      ])],
#  [array([0.20280574, 0.14442821, 0.03      ]),
#   array([1.1106531 , 0.14442821, 0.26      ])],
#  [array([0.26645416, 0.50355302, 0.05      ]),
#   array([1.23195804, 1.01431379, 0.14      ])],
#  [array([0.01254255, 6.12671078, 0.08      ]),
#   array([1.19774719, 6.12671078, 0.28      ])],
#  [array([0.16760033, 0.16199081, 0.04      ]),
#   array([1.01210091, 0.16199081, 0.49      ])],
#  [array([0.04793707, 0.13640173, 0.18      ]),
#   array([1.18806349, 0.13640173, 0.2       ])],
#  [array([0.0092431 , 0.13696297, 0.38      ]),
#   array([0.81459671, 0.13696297, 0.34      ])],
#  [array([0.2770269 , 0.14308817, 0.04      ]),
#   array([1.16258957, 0.14308817, 0.31      ])],
#  [array([0.03062264, 0.26824834, 0.88      ]),
#   array([0.87000474, 0.26824834, 0.24      ])],
#  [array([5.57373288e-02, 1.00000000e+04, 1.30000000e-01]),
#   array([1.22345159e+00, 1.00000000e+04, 4.90000000e-01])],
#  [array([0.04387239, 0.15371631, 0.28      ]),
#   array([1.01418944, 0.15371631, 0.25      ])],
#  [array([0.01520695, 0.37846528, 0.26      ]),
#   array([0.77780627, 0.60892057, 0.31      ])],
#  [array([0.11858587, 1.23200798, 0.25      ]),
#   array([1.16659613, 1.23200798, 0.31      ])],
#  [array([0.21820731, 0.17499702, 0.13      ]),
#   array([1.1857862 , 0.17499702, 0.18      ])],
#  [array([0.02958088, 0.11330357, 0.36      ]),
#   array([1.3801919 , 0.11330357, 0.16      ])],
#  [array([8.97443298e-02, 1.00000000e+04, 4.40000000e-01]),
#   array([8.33731586e-01, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.16077578, 0.32377082, 0.05      ]),
#   array([0.95582292, 0.47878859, 0.14      ])],
#  [array([0.02462292, 0.28834958, 0.24      ]),
#   array([0.89204324, 0.4051843 , 0.28      ])],
#  [array([0.05942455, 1.03641485, 0.28      ]),
#   array([1.12086184, 1.03641485, 0.11      ])],
#  [array([0.01947054, 0.38519636, 0.27      ]),
#   array([1.02798116, 0.38519636, 0.08      ])],
#  [array([0.05148478, 0.11862784, 0.47      ]),
#   array([1.11062025, 0.11862784, 0.49      ])],
#  [array([2.04455925e-02, 1.00000000e+04, 2.40000000e-01]),
#   array([8.0260381e-01, 1.0000000e+04, 4.9000000e-01])],
#  [array([0.00449748, 0.14594573, 0.21      ]),
#   array([0.76685411, 0.14594573, 0.34      ])],
#  [array([2.14118845e-01, 1.00000000e+04, 2.00000000e-01]),
#   array([1.17778466e+00, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.14815177, 0.53112535, 0.43      ]),
#   array([1.01450316, 0.53112535, 0.21      ])],
#  [array([0.21966638, 0.89532627, 0.48      ]),
#   array([0.94751886, 0.89532627, 0.21      ])],
#  [array([0.01428065, 0.14884378, 0.74      ]),
#   array([0.77922898, 0.17487246, 0.9       ])],
#  [array([0.04907904, 0.30395665, 0.96      ]),
#   array([0.98037983, 0.30395665, 0.57      ])],
#  [array([0.05708679, 0.56750558, 0.19      ]),
#   array([0.88469573, 1.31216855, 0.03      ])],
#  [array([0.02618271, 0.53120616, 0.09      ]),
#   array([0.84848525, 0.53120616, 0.14      ])],
#  [array([0.0068904 , 0.87743096, 0.24      ]),
#   array([0.82717948, 0.87743096, 0.02      ])],
#  [array([0.03908533, 0.61741436, 0.1       ]),
#   array([1.14441502, 0.61741436, 0.36      ])],
#  [array([0.01161759, 0.12551271, 0.14      ]),
#   array([0.7936488 , 0.12551271, 0.35      ])],
#  [array([6.44717517e-02, 1.00000000e+04, 2.60000000e-01]),
#   array([1.11741876e+00, 1.00000000e+04, 6.00000000e-02])],
#  [array([0.05553574, 0.1642157 , 0.28      ]),
#   array([1.09961998, 0.1642157 , 0.37      ])],
#  [array([0.00837382, 0.12909449, 0.43      ]),
#   array([0.78603957, 0.14823019, 0.37      ])],
#  [array([0.04057251, 0.18749406, 0.22      ]),
#   array([0.90862732, 0.18749406, 0.57      ])],
#  [array([0.17067145, 0.11277663, 0.05      ]),
#   array([1.30368061, 0.11277663, 0.31      ])],
#  [array([0.05654046, 0.35542198, 0.49      ]),
#   array([0.88898641, 0.35542198, 0.03      ])],
#  [array([0.31089856, 0.29597857, 0.05      ]),
#   array([1.10981859, 0.42041131, 0.14      ])],
#  [array([0.05248176, 0.7642153 , 0.38      ]),
#   array([0.88097021, 0.7642153 , 0.03      ])],
#  [array([0.03847895, 0.15026199, 0.5       ]),
#   array([0.89431612, 0.17683332, 0.9       ])],
#  [array([0.00564998, 1.25969092, 0.33      ]),
#   array([8.63438091e-01, 1.00000000e+04, 2.60000000e-01])],
#  [array([0.11588506, 0.14964889, 0.44      ]),
#   array([1.06784364, 0.17598482, 0.05      ])],
#  [array([0.00506818, 0.3426963 , 0.05      ]),
#   array([0.95948899, 0.52136675, 0.28      ])],
#  [array([0.02886132, 0.12737239, 0.37      ]),
#   array([0.8060516, 0.1459642, 0.2      ])],
#  [array([0.09559587, 0.67451472, 0.13      ]),
#   array([1.24170292, 0.67451472, 0.49      ])],
#  [array([0.02366961, 0.14121612, 0.03      ]),
#   array([1.07671539, 0.14121612, 0.19      ])],
#  [array([0.06945735, 0.14643272, 0.09      ]),
#   array([1.1315642 , 0.14643272, 0.2       ])],
#  [array([0.11818065, 0.16714343, 0.24      ]),
#   array([1.37826263, 0.16714343, 1.        ])],
#  [array([0.13623563, 0.14559087, 0.87      ]),
#   array([1.07724749, 0.17039948, 0.77      ])],
#  [array([0.03795503, 2.1725408 , 0.12      ]),
#   array([0.94344066, 2.1725408 , 0.31      ])],
#  [array([0.07014013, 0.29926109, 0.84      ]),
#   array([1.06709613, 0.29926109, 0.9       ])],
#  [array([0.02221068, 0.19344589, 0.6       ]),
#   array([0.82686106, 0.23984242, 0.9       ])],
#  [array([1.98874384e-01, 1.00000000e+04, 1.40000000e-01]),
#   array([1.20316827e+00, 1.00000000e+04, 6.00000000e-02])],
#  [array([0.04680623, 0.12966728, 0.37      ]),
#   array([0.9571036 , 0.12966728, 0.24      ])],
#  [array([4.6216831e-02, 1.0000000e+04, 4.9000000e-01]),
#   array([8.58268025e-01, 1.00000000e+04, 2.00000000e-02])],
#  [array([0.02218759, 0.15048073, 0.37      ]),
#   array([0.92361853, 0.17713634, 0.71      ])],
#  [array([0.0260948 , 0.15467401, 0.49      ]),
#   array([0.80071484, 0.15467401, 0.43      ])],
#  [array([2.21007577e-01, 1.00000000e+04, 4.30000000e-01]),
#   array([1.20200069e+00, 1.00000000e+04, 2.10000000e-01])],
#  [array([0.00986359, 0.25385552, 0.38      ]),
#   array([0.87989057, 0.25385552, 0.08      ])],
#  [array([0.00794631, 0.58247782, 0.49      ]),
#   array([0.82522148, 0.58247782, 0.33      ])],
#  [array([0.03010204, 0.12719695, 0.4       ]),
#   array([0.8476294 , 0.12719695, 0.35      ])],
#  [array([0.02778428, 0.23367223, 0.84      ]),
#   array([0.9317635 , 0.30492465, 0.71      ])],
#  [array([0.03441155, 0.11258423, 0.45      ]),
#   array([1.09234757, 0.11258423, 0.26      ])],
#  [array([0.04398307, 0.10204115, 0.49      ]),
#   array([0.88077062, 0.11363678, 0.26      ])],
#  [array([7.47684451e-02, 1.00000000e+04, 4.40000000e-01]),
#   array([9.21604469e-01, 1.00000000e+04, 3.10000000e-01])],
#  [array([0.03831823, 1.08510014, 0.05      ]),
#   array([0.92745858, 1.08510014, 0.33      ])],
#  [array([0.00406665, 0.20963984, 0.15      ]),
#   array([0.78679484, 0.20963984, 0.04      ])],
#  [array([0.15135839, 0.93393878, 0.06      ]),
#   array([ 0.93876221, 14.13747423,  0.28      ])],
#  [array([0.01280041, 0.11328278, 0.43      ]),
#   array([0.77979206, 0.12775525, 0.23      ])],
#  [array([0.0596532 , 0.39664553, 0.19      ]),
#   array([0.84008197, 0.39664553, 0.33      ])],
#  [array([0.27253192, 0.18235317, 0.03      ]),
#   array([0.98854416, 0.18235317, 0.05      ])],
#  [array([0.04288068, 0.13880543, 0.23      ]),
#   array([0.86719165, 0.16117779, 0.31      ])],
#  [array([0.13910664, 0.55968088, 0.05      ]),
#   array([0.94010436, 1.27108013, 0.14      ])],
#  [array([0.16551291, 0.19223165, 0.29      ]),
#   array([0.92336065, 0.19223165, 0.32      ])],
#  [array([0.04921015, 0.14189871, 0.09      ]),
#   array([1.09324773, 0.16536359, 0.05      ])],
#  [array([0.02284106, 0.14255752, 0.27      ]),
#   array([0.92385653, 0.14255752, 0.19      ])],
#  [array([0.05457368, 0.3486895 , 0.37      ]),
#   array([0.79636798, 0.535366  , 0.06      ])],
#  [array([0.04373395, 0.16410373, 0.06      ]),
#   array([0.90180424, 0.16410373, 0.26      ])],
#  [array([0.03242202, 0.65314746, 0.16      ]),
#   array([1.07166306, 0.65314746, 0.31      ])],
#  [array([0.04599975, 0.140651  , 0.15      ]),
#   array([0.85788763, 0.16367157, 0.05      ])],
#  [array([0.08028199, 0.23878132, 0.14      ]),
#   array([1.05677701, 0.31368295, 0.57      ])],
#  [array([0.04841485, 0.13068726, 0.05      ]),
#   array([0.99646322, 0.13068726, 0.43      ])],
#  [array([0.0951215 , 0.22461202, 0.97      ]),
#   array([1.12726737, 0.22461202, 0.51      ])],
#  [array([0.16465126, 0.34180607, 0.38      ]),
#   array([1.06446648, 0.51930906, 0.02      ])],
#  [array([0.0315951 , 0.25638943, 0.27      ]),
#   array([0.85055202, 0.25638943, 0.67      ])],
#  [array([0.03504342, 0.16980038, 0.21      ]),
#   array([0.88425165, 0.20452957, 0.24      ])],
#  [array([0.03658699, 0.13962942, 0.2       ]),
#   array([0.96598276, 0.13962942, 0.43      ])],
#  [array([0.07793006, 0.38674233, 0.07      ]),
#   array([1.024081  , 0.38674233, 0.14      ])],
#  [array([0.06712689, 0.10495629, 0.4       ]),
#   array([1.10199355, 0.11726387, 0.24      ])],
#  [array([0.10756324, 0.14957492, 0.2       ]),
#   array([0.85789216, 0.14957492, 0.37      ])],
#  [array([0.19982591, 0.2490287 , 0.94      ]),
#   array([1.15988946, 0.2490287 , 0.08      ])],
#  [array([0.03494737, 0.2027249 , 0.81      ]),
#   array([1.07685317, 0.2027249 , 0.49      ])],
#  [array([ 0.11100079, 12.52145982,  0.06      ]),
#   array([1.01727208e+00, 1.00000000e+04, 2.80000000e-01])],
#  [array([0.31189021, 0.45690949, 0.04      ]),
#   array([1.28285633, 0.45690949, 0.33      ])],
#  [array([0.09154474, 1.17450637, 0.14      ]),
#   array([1.11351221, 1.17450637, 0.06      ])],
#  [array([0.19433135, 0.16356033, 0.02      ]),
#   array([1.17536515, 0.16356033, 0.37      ])],
#  [array([0.04718511, 0.18953039, 0.87      ]),
#   array([1.07307454, 0.18953039, 0.56      ])],
#  [array([0.17969527, 0.1939958 , 0.7       ]),
#   array([0.9260674, 0.1939958, 0.67     ])],
#  [array([0.15571668, 0.29614373, 0.23      ]),
#   array([0.92990595, 0.29614373, 0.18      ])],
#  [array([0.05906809, 0.15288385, 0.87      ]),
#   array([1.01870666, 0.18047566, 0.77      ])],
#  [array([0.01224416, 0.23609397, 0.18      ]),
#   array([0.82777312, 0.30906153, 0.91      ])],
#  [array([0.02797788, 0.13863007, 0.34      ]),
#   array([1.18381542, 0.13863007, 0.49      ])],
#  [array([0.0196446 , 0.32841529, 0.21      ]),
#   array([1.03312025, 0.48901544, 0.38      ])],
#  ...]

# %%
X = np.reshape(np.array(vect), (-1, 3))

# %%
y = np.reshape(np.array([[0, 1] for _ in range(8192)]), (8192*2))

# %%
y = np.reshape(y, 8192*2)

# %%
from skopt import BayesSearchCV
from sklearn.datasets import load_digits
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
from torch.autograd import Variable
from torchvision import datasets
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data_utils
import torch
import matplotlib.pyplot as plt

import os
import pandas as pd
import skimage.io
from skimage.transform import resize

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# разные режимы датасета 
DATA_MODES = ['train', 'val', 'test']
# работаем на видеокарте
DEVICE = torch.device("cuda")

EPOCHS = 1000
BATCH_SIZE = 256

# %%
class JustSigmoid(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Sequential(
                nn.Linear(3, 1)
            )
    def forward(self, x):
        return self.layer(x)

# %%
lean = JustSigmoid().to(DEVICE)
print(lean)
# Out:
# JustSigmoid(
#   (layer): Sequential(
#     (0): Linear(in_features=3, out_features=1, bias=True)
#   )
# )

# %%
lean.load_state_dict(torch.load('Weights/lean'))
# Out:
# <All keys matched successfully>

# %%
from torch.utils.data import DataLoader, Dataset
criterion = F.mse_loss

optimizer = torch.optim.Adam(lean.parameters(), lr=0.001)
train_losses = []
val_losses = []
X = torch.Tensor(X)
y = torch.Tensor(y)
train_X, val_X, train_y, val_y = train_test_split(X, y, train_size=0.9)
# train_dataset = Dataset(train_X, train_y)
# val_dataset = Dataset(val_X, val_y)
train_loader = DataLoader(list(zip(train_X, train_y)), batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(list(zip(val_X, val_y)), batch_size=BATCH_SIZE, shuffle=True)

# %%
from tqdm import notebook

for epoch in notebook.tqdm(range(EPOCHS)):
    lean.train()
    train_losses_per_epoch = []
    for X_batch, y_batch in train_loader:
        torch.cuda.empty_cache()
        optimizer.zero_grad()
        calculated = torch.reshape(lean(torch.Tensor(X_batch).to(DEVICE)), (-1,))
        loss = criterion(calculated, torch.Tensor(y_batch).to(DEVICE))
        loss.backward()
        optimizer.step()
        train_losses_per_epoch.append(loss.item())

    train_losses.append(np.mean(train_losses_per_epoch))

    lean.eval()
    val_losses_per_epoch = []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            calculated = torch.reshape(lean(torch.Tensor(X_batch).to(DEVICE)), (-1,))
            loss = criterion(calculated, torch.Tensor(y_batch).to(DEVICE))
            val_losses_per_epoch.append(loss.item())

    val_losses.append(np.mean(val_losses_per_epoch))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
with torch.no_grad():
    calc = torch.reshape(lean(torch.Tensor([[0.03095769, 0.2211782 , 0.93], [0.9236934 , 0.19648128, 0.55]]).to(DEVICE)), (-1,))

# %%
calc
# Out:
# tensor([-0.0135,  0.8823], device='cuda:0')

# %%
torch.save(lean.state_dict(), 'weights/lean')

# %%
java = torch.jit.trace(lean, torch.Tensor(val_X).to(DEVICE))

# %%
java.save('./model1.zip')

# %%
lean
# Out:
# JustSigmoid(
#   (layer): Sequential(
#     (0): Linear(in_features=3, out_features=1, bias=True)
#   )
# )

# %%
import torch.onnx
import onnx

# %%
# !pip install onnx
# Out:
# Requirement already satisfied: onnx in c:\users\vadim_jfdr\anaconda3\envs\tf\lib\site-packages (1.14.1)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\vadim_jfdr\anaconda3\envs\tf\lib\site-packages (from onnx) (4.24.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\users\vadim_jfdr\anaconda3\envs\tf\lib\site-packages (from onnx) (4.8.0)
# Requirement already satisfied: numpy in c:\users\vadim_jfdr\anaconda3\envs\tf\lib\site-packages (from onnx) (1.24.2)

# %%
torch.onnx.export(lean, torch.Tensor(val_X).to(DEVICE), "Models/model.onnx")
# Out:
# ================ Diagnostic Run torch.onnx.export version 2.0.0 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
