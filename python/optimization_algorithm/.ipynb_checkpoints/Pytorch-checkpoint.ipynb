# %%
import json
import pandas as pd
import numpy as np

# %%
from scipy.spatial.distance import cdist

# %%
with open('offices.json', encoding='utf-8') as f:
    offices = json.load(f)

# %%
kremlin_lat = 55.752
kremlin_lon = 37.618
degree_to_meter = 111319
moscow_rad = 70000 / degree_to_meter
office_latitudes = []
office_longitudes = []
max_people = []
opening_times = [[] for _ in range(7)]
closing_times = [[] for _ in range(7)]
business_morning = [[] for _ in range(7)]
business_day = [[] for _ in range(7)]
business_evening = [[] for _ in range(7)]

# %%
ord_to_day = {0: 'mn', 1: 'ts', 2: 'wd', 3: 'th', 4: 'fr', 5: 'st', 6: 'sn'}
day_to_ord = {'пн': 0, 'вт': 1, 'ср': 2, 'чт': 3, 'пт': 4, 'сб': 5, 'вс': 6}
ans = []
for obj in offices:
    if  'Не' in obj['openHours'][0]['days']:
        continue

    if len(obj['openHours']) == 7:
        ans.append((obj['openHours'] + [float(obj['latitude']), float(obj['longitude'])]).copy())
        continue

    new_dict_list = list()
    for l in obj['openHours']:
        if l["days"] == 'перерыв':
            for i in range(len(new_dict_list)):
                new_dict_list[i]['hours'] = new_dict_list[i]['hours'][:5] + '-' + l['hours'][:5] + ', ' + l['hours'][6:] + '-' + new_dict_list[i]['hours'][6:]
        elif len(l["days"]) > 2:
            s_front = l["days"][:2]
            s_back = l["days"][3:]

            for i in range(day_to_ord[s_front], day_to_ord[s_back] + 1):
                if i + 1 <= len(new_dict_list):
                    continue
                new_dict_list.append({'days': ord_to_day[i], "hours": l["hours"]})
        else:
            new_dict_list.append({"days": l["days"], "hours": l["hours"]})
    ans.append((new_dict_list + [float(obj['latitude']), float(obj['longitude'])]).copy())

# %%
ans
# Out:
# [[{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.184479,
#   36.984314],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   56.183239,
#   36.9757],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.012386,
#   37.482059],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.010849,
#   37.854359],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.008335,
#   37.851467],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   56.000401,
#   37.208775],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.979717,
#   37.162693],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.947811,
#   37.499382],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.939659,
#   37.516071],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.921768,
#   37.844116],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.918736,
#   37.761627],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.917068,
#   37.995396],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.915436,
#   37.996597],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.915363,
#   36.859612],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.912254,
#   37.868309],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.910648,
#   37.867706],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.904148,
#   37.72485],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.903538,
#   37.71344],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.901184,
#   37.407536],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.900169,
#   37.588306],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.892334,
#   37.440552],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.890957,
#   37.407825],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.888763,
#   37.433525],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.888107,
#   37.66246],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.885498,
#   37.604683],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.868855,
#   37.667446],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.865288,
#   37.661438],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.863358,
#   37.43351],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.862343,
#   37.608948],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.859764,
#   37.121326],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.855362,
#   37.562981],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.854996,
#   37.653389],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.851986,
#   37.443012],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.848015,
#   37.355202],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.847076,
#   37.362152],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.835659,
#   37.490498],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.833855,
#   37.298939],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.833855,
#   37.298939],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.829266,
#   37.451313],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.827133,
#   37.312019],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.818714,
#   37.573502],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.818684,
#   37.497196],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.809105,
#   37.636337],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.807396,
#   37.406281],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.805214,
#   37.508186],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.803135,
#   37.934631],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.802914,
#   37.51889],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.801319,
#   37.634335],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'fr', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:45'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.797817,
#   37.946049],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.797306,
#   37.718723],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.797077,
#   37.725388],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.796345,
#   37.80584],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.796009,
#   37.583389],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.794807,
#   37.967934],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.792191,
#   37.496796],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.79071,
#   37.635178],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.789921,
#   37.677895],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.788677,
#   37.589157],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.788631,
#   37.466789],
#  [{'days': 'mn', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'th', 'hours': '09:00-14:15, 15:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-14:15, 15:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.787449,
#   37.681145],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.787273,
#   37.600353],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.785767,
#   37.568821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.783611,
#   37.721302],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.783394,
#   37.596867],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.781616,
#   37.632637],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.779068,
#   37.586929],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.778736,
#   37.602024],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.777794,
#   37.465748],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.77433,
#   37.604584],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.773155,
#   37.625908],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.773033,
#   37.675766],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.771809,
#   37.636669],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.770432,
#   37.599194],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.76997,
#   37.669083],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.768871,
#   37.651806],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.766045,
#   37.638081],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.764393,
#   37.556145],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.764275,
#   37.620392],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762936,
#   37.628845],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762936,
#   37.628845],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762272,
#   37.624821],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.762119,
#   37.609638],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.761307,
#   37.656288],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.761307,
#   37.656288],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.760258,
#   37.611446],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.759033,
#   37.658295],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.757092,
#   37.595619],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.754257,
#   37.715244],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.754158,
#   37.859192],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.753666,
#   37.577129],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.75259,
#   37.604752],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.750858,
#   37.815983],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749634,
#   37.537434],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749546,
#   38.007694],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.749359,
#   37.786266],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.748947,
#   37.65514],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.747784,
#   37.586689],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.746796,
#   37.421307],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.746483,
#   37.682617],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.743633,
#   38.012463],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.740589,
#   37.501286],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737984,
#   37.244133],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737507,
#   37.518379],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737446,
#   37.617958],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.737183,
#   37.663952],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.736599,
#   37.5881],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.735596,
#   37.519539],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.734203,
#   37.618866],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.733501,
#   36.853474],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.733055,
#   37.664951],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.731953,
#   37.637085],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.723206,
#   37.603947],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.721241,
#   37.576824],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.721203,
#   37.823063],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.718632,
#   37.788269],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.715729,
#   37.797684],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.714561,
#   37.623833],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.70945,
#   37.661041],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.707363,
#   37.577751],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.692474,
#   37.551727],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'fr', 'hours': '09:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.690491,
#   37.863586],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.690372,
#   37.550655],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.686108,
#   37.303127],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.686005,
#   37.575829],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.685436,
#   37.570122],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.684502,
#   37.621948],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.681713,
#   37.516449],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.681534,
#   37.849888],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.679031,
#   37.283516],
#  [{'days': 'mn', 'hours': '10:00-19:00'},
#   {'days': 'ts', 'hours': '10:00-19:00'},
#   {'days': 'wd', 'hours': '10:00-19:00'},
#   {'days': 'th', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.678787,
#   37.894928],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.677097,
#   37.256618],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.676552,
#   37.891171],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.674576,
#   37.760235],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.663513,
#   37.6054],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-16:45'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.66169,
#   37.747414],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.660671,
#   37.91338],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.650631,
#   37.394447],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.650505,
#   37.745926],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.629959,
#   37.850281],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.61813,
#   37.507484],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.617748,
#   37.505722],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.612274,
#   37.722126],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.611511,
#   37.71962],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.610489,
#   37.360321],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.608814,
#   37.535412],
#  [{'days': 'пн', 'hours': '10:00-19:00'},
#   {'days': 'вт', 'hours': '10:00-19:00'},
#   {'days': 'ср', 'hours': '10:00-19:00'},
#   {'days': 'чт', 'hours': '10:00-19:00'},
#   {'days': 'пт', 'hours': '10:00-18:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.596458,
#   37.599823],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.589993,
#   38.123306],
#  [{'days': 'mn', 'hours': '09:00-18:00'},
#   {'days': 'ts', 'hours': '09:00-18:00'},
#   {'days': 'wd', 'hours': '09:00-18:00'},
#   {'days': 'th', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'st', 'hours': 'выходной'},
#   {'days': 'sn', 'hours': 'выходной'},
#   55.573448,
#   38.23138],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.568867,
#   38.226074],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.555126,
#   37.708778],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.547852,
#   37.543255],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.545261,
#   37.708141],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.478329,
#   37.298706],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.43874,
#   37.767536],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.432919,
#   37.550838],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.427883,
#   37.55011],
#  [{'days': 'пн', 'hours': '09:00-18:00'},
#   {'days': 'вт', 'hours': '09:00-18:00'},
#   {'days': 'ср', 'hours': '09:00-18:00'},
#   {'days': 'чт', 'hours': '09:00-18:00'},
#   {'days': 'пт', 'hours': '09:00-17:00'},
#   {'days': 'сб', 'hours': 'выходной'},
#   {'days': 'вс', 'hours': 'выходной'},
#   55.421104,
#   38.260525]]

# %%
for elem in ans:
    office_latitudes.append(elem[7])
    office_longitudes.append(elem[8])
    max_people.append(np.random.randint(1000, 3000))
    for i in range(7):
        opening_times[i].append(elem[i]['hours'][:5] if elem[i]['hours'] != 'выходной' else None)
        closing_times[i].append(elem[i]['hours'][-5:] if elem[i]['hours'] != 'выходной' else None)
        business_morning[i].append(round(np.random.uniform(0.01, 0.5), 2))
        business_day[i].append(round(np.random.uniform(0.01, 1), 2))
        business_evening[i].append(round(np.random.uniform(0.01, 0.5), 2))

# %%
len(office_latitudes)
# Out:
# 160

# %%
len(office_longitudes)
# Out:
# 160

# %%
len(max_people)
# Out:
# 160

# %%
for i in range(7):
    print(len(opening_times[i]))
    print(len(closing_times[i]))
    print(len(business_morning[i]))
    print(len(business_day[i]))
    print(len(business_evening[i]))
# Out:
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160
# 160

# %%
db = pd.DataFrame()
db['Latitude'] = pd.Series(office_latitudes)

# %%
db
# Out:
#       Latitude
# 0    56.184479
# 1    56.183239
# 2    56.012386
# 3    56.010849
# 4    56.008335
# ..         ...
# 155  55.478329
# 156  55.438740
# 157  55.432919
# 158  55.427883
# 159  55.421104
#
# [160 rows x 1 columns]

# %%
db['Longitude'] = pd.Series(office_longitudes)
db['Max_People'] = pd.Series(max_people)
for i in range(7):
    db[f'opening_{ord_to_day[i]}'] = pd.Series(opening_times[i]).str[:2].fillna(0).astype(int)
    db[f'closing_{ord_to_day[i]}'] = pd.Series(closing_times[i]).str[:2].fillna(0).astype(int)
    db[f'morning_{ord_to_day[i]}'] = pd.Series(business_morning[i])
    db[f'day_{ord_to_day[i]}'] = pd.Series(business_day[i])
    db[f'evening_{ord_to_day[i]}'] = pd.Series(business_evening[i])

# %%
db
# Out:
#       Latitude  Longitude  Max_People  opening_mn  closing_mn  morning_mn  \
# 0    56.184479  36.984314        2879           9          18        0.24
# 1    56.183239  36.975700        2155           9          18        0.48
# 2    56.012386  37.482059        1423          10          19        0.13
# 3    56.010849  37.854359        1412           9          18        0.02
# 4    56.008335  37.851467        2390           9          18        0.41
# ..         ...        ...         ...         ...         ...         ...
# 155  55.478329  37.298706        1258           9          18        0.11
# 156  55.438740  37.767536        1928           9          18        0.19
# 157  55.432919  37.550838        1484           9          18        0.50
# 158  55.427883  37.550110        1259           9          18        0.19
# 159  55.421104  38.260525        2027           9          18        0.25
#
#      day_mn  evening_mn  opening_ts  closing_ts  ...  opening_st  closing_st  \
# 0      0.24        0.16           9          18  ...           0           0
# 1      0.24        0.13           9          18  ...           0           0
# 2      0.93        0.30          10          19  ...           0           0
# 3      0.15        0.32           9          18  ...           0           0
# 4      0.37        0.33           9          18  ...           0           0
# ..      ...         ...         ...         ...  ...         ...         ...
# 155    0.91        0.36           9          18  ...           0           0
# 156    0.75        0.17           9          18  ...           0           0
# 157    0.58        0.22           9          18  ...           0           0
# 158    0.90        0.05           9          18  ...           0           0
# 159    0.69        0.33           9          18  ...           0           0
#
#      morning_st  day_st  evening_st  opening_sn  closing_sn  morning_sn  \
# 0          0.20    0.88        0.09           0           0        0.13
# 1          0.27    0.03        0.40           0           0        0.17
# 2          0.13    0.45        0.38           0           0        0.31
# 3          0.06    0.02        0.18           0           0        0.11
# 4          0.21    0.61        0.21           0           0        0.34
# ..          ...     ...         ...         ...         ...         ...
# 155        0.04    0.55        0.35           0           0        0.47
# 156        0.19    0.49        0.38           0           0        0.14
# 157        0.48    0.16        0.03           0           0        0.17
# 158        0.38    0.96        0.15           0           0        0.18
# 159        0.07    0.10        0.23           0           0        0.03
#
#      day_sn  evening_sn
# 0      0.20        0.46
# 1      0.42        0.32
# 2      0.88        0.04
# 3      0.05        0.20
# 4      0.23        0.06
# ..      ...         ...
# 155    0.21        0.12
# 156    0.62        0.15
# 157    0.91        0.30
# 158    0.56        0.46
# 159    0.24        0.33
#
# [160 rows x 38 columns]

# %%
examples_quantity = 8192
examples = pd.DataFrame()
usr_lat = []
usr_lon = []
days = [np.random.randint(0, 5) for i in range(examples_quantity)]
time = [np.random.uniform(9, 19) for i in range(examples_quantity)]
for i in range(examples_quantity):
    rho = np.random.uniform(0, moscow_rad)
    phi = np.random.uniform(0, 2 * np.pi)
    usr_lat.append(kremlin_lat + rho * np.sin(phi))
    usr_lon.append(kremlin_lon + rho * np.cos(phi))

# %%
examples['Latitude'] = usr_lat
examples['Longitude'] = usr_lon
examples['day'] = days
examples['time'] = time

# %%
examples
# Out:
#        Latitude  Longitude  day       time
# 0     55.529277  37.404163    0  17.145107
# 1     55.737108  37.631739    2  12.323854
# 2     55.916487  38.074830    3  16.221863
# 3     56.044643  37.516204    4  10.518354
# 4     55.861014  37.635104    4  17.448565
# ...         ...        ...  ...        ...
# 8187  55.855223  37.182133    0  12.594759
# 8188  55.664094  37.826010    3  16.869592
# 8189  56.078248  37.943674    0   9.726419
# 8190  55.259491  37.525568    4  18.889654
# 8191  55.627050  37.711721    2  17.656886
#
# [8192 rows x 4 columns]

# %%
db
# Out:
#       Latitude  Longitude  Max_People  opening_mn  closing_mn  morning_mn  \
# 0    56.184479  36.984314        2879           9          18        0.24
# 1    56.183239  36.975700        2155           9          18        0.48
# 2    56.012386  37.482059        1423          10          19        0.13
# 3    56.010849  37.854359        1412           9          18        0.02
# 4    56.008335  37.851467        2390           9          18        0.41
# ..         ...        ...         ...         ...         ...         ...
# 155  55.478329  37.298706        1258           9          18        0.11
# 156  55.438740  37.767536        1928           9          18        0.19
# 157  55.432919  37.550838        1484           9          18        0.50
# 158  55.427883  37.550110        1259           9          18        0.19
# 159  55.421104  38.260525        2027           9          18        0.25
#
#      day_mn  evening_mn  opening_ts  closing_ts  ...  opening_st  closing_st  \
# 0      0.24        0.16           9          18  ...           0           0
# 1      0.24        0.13           9          18  ...           0           0
# 2      0.93        0.30          10          19  ...           0           0
# 3      0.15        0.32           9          18  ...           0           0
# 4      0.37        0.33           9          18  ...           0           0
# ..      ...         ...         ...         ...  ...         ...         ...
# 155    0.91        0.36           9          18  ...           0           0
# 156    0.75        0.17           9          18  ...           0           0
# 157    0.58        0.22           9          18  ...           0           0
# 158    0.90        0.05           9          18  ...           0           0
# 159    0.69        0.33           9          18  ...           0           0
#
#      morning_st  day_st  evening_st  opening_sn  closing_sn  morning_sn  \
# 0          0.20    0.88        0.09           0           0        0.13
# 1          0.27    0.03        0.40           0           0        0.17
# 2          0.13    0.45        0.38           0           0        0.31
# 3          0.06    0.02        0.18           0           0        0.11
# 4          0.21    0.61        0.21           0           0        0.34
# ..          ...     ...         ...         ...         ...         ...
# 155        0.04    0.55        0.35           0           0        0.47
# 156        0.19    0.49        0.38           0           0        0.14
# 157        0.48    0.16        0.03           0           0        0.17
# 158        0.38    0.96        0.15           0           0        0.18
# 159        0.07    0.10        0.23           0           0        0.03
#
#      day_sn  evening_sn
# 0      0.20        0.46
# 1      0.42        0.32
# 2      0.88        0.04
# 3      0.05        0.20
# 4      0.23        0.06
# ..      ...         ...
# 155    0.21        0.12
# 156    0.62        0.15
# 157    0.91        0.30
# 158    0.56        0.46
# 159    0.24        0.33
#
# [160 rows x 38 columns]

# %%
points1 = db.loc[:, ['Latitude', 'Longitude']].values

# %%
points2 = examples.loc[:, ['Latitude', 'Longitude']].values

# %%
distances = cdist(points1, points2)
distances_df = pd.DataFrame(distances, index=db.index, columns=['dist' + str(idx) for idx in examples.index])
distances_df
# Out:
#         dist0     dist1     dist2     dist3     dist4     dist5     dist6  \
# 0    0.778179  0.786956  1.122962  0.549965  0.726745  0.895984  0.669559
# 1    0.781823  0.793360  1.131036  0.557991  0.733923  0.903521  0.675242
# 2    0.489348  0.313340  0.600478  0.046973  0.215259  0.370942  0.270041
# 3    0.659233  0.352836  0.239816  0.339839  0.265562  0.166023  0.454854
# 4    0.655421  0.349062  0.241510  0.337223  0.261756  0.162915  0.451036
# ..        ...       ...       ...       ...       ...       ...       ...
# 155  0.117120  0.421756  0.891264  0.606645  0.509521  0.636114  0.324424
# 156  0.374482  0.327818  0.568042  0.655962  0.442553  0.413511  0.413289
# 157  0.175494  0.314764  0.713026  0.612704  0.436310  0.493430  0.315955
# 158  0.177711  0.319818  0.716983  0.617692  0.441392  0.498076  0.320745
# 159  0.863167  0.703726  0.529043  0.970986  0.764638  0.617833  0.837434
#
#         dist7     dist8     dist9  ...  dist8182  dist8183  dist8184  \
# 0    0.888853  0.702914  0.726085  ...  1.183028  0.284927  1.291589
# 1    0.896134  0.710768  0.732950  ...  1.189901  0.293188  1.298833
# 2    0.369456  0.177080  0.231316  ...  0.672675  0.248706  0.770612
# 3    0.214793  0.203015  0.306096  ...  0.442535  0.602323  0.484061
# 4    0.211525  0.199719  0.302269  ...  0.441224  0.600009  0.483846
# ..        ...       ...       ...  ...       ...       ...       ...
# 155  0.589658  0.609908  0.466030  ...  0.722299  0.655545  0.863681
# 156  0.368202  0.546494  0.413084  ...  0.290553  0.857304  0.425877
# 157  0.442746  0.550471  0.394098  ...  0.488725  0.756341  0.629352
# 158  0.447389  0.555554  0.399186  ...  0.491122  0.760731  0.631615
# 159  0.609100  0.819761  0.761202  ...  0.305159  1.224231  0.234069
#
#      dist8185  dist8186  dist8187  dist8188  dist8189  dist8190  dist8191
# 0    0.162997  0.718722  0.384112  0.989572  0.965223  1.071708  0.916433
# 1    0.168925  0.725530  0.387568  0.996262  0.973651  1.075018  0.922537
# 2    0.378892  0.228072  0.338608  0.489499  0.466289  0.754151  0.448585
# 3    0.748336  0.315852  0.690005  0.347912  0.111892  0.820147  0.409448
# 4    0.745693  0.312027  0.686623  0.345181  0.115715  0.816686  0.406088
# ..        ...       ...       ...       ...       ...       ...       ...
# 155  0.630556  0.457131  0.394510  0.559069  0.880844  0.315208  0.438975
# 156  0.918847  0.414401  0.718439  0.232816  0.663321  0.301129  0.196407
# 157  0.783207  0.389830  0.560610  0.359390  0.755493  0.175259  0.252131
# 158  0.786963  0.394918  0.563938  0.363203  0.760176  0.170171  0.256487
# 159  1.326402  0.768399  1.162492  0.497843  0.729543  0.752516  0.586173
#
# [160 rows x 8192 columns]

# %%
examples['day'].values
# Out:
# array([0, 2, 3, ..., 0, 4, 2], dtype=int64)

# %%
diff_matrix = [[0] * 8192 for _ in range(160)]
days = examples['day'].values
coming = examples['time'].values
for i in range(160):
    for j in range(8192):
        closing_hours = db[f'closing_{ord_to_day[days[j]]}'].values
        diff_matrix[i][j] = 1 / max(closing_hours[i] - coming[j], 0.0001)

# %%
diff_df = pd.DataFrame(diff_matrix, index=db.index, columns=['diff' + str(idx) for idx in examples.index])

# %%
diff_df
# Out:
#         diff0     diff1     diff2     diff3         diff4     diff5  \
# 0    1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
# 1    1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
# 2    0.539115  0.149787  0.359953  0.133660      1.813449  0.295669
# 3    1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
# 4    1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
# ..        ...       ...       ...       ...           ...       ...
# 155  1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
# 156  1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
# 157  1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
# 158  1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
# 159  1.169737  0.176176  0.562386  0.154282  10000.000000  0.419787
#
#             diff6     diff7     diff8     diff9  ...  diff8182  diff8183  \
# 0    10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
# 1    10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
# 2        6.679396  0.158355  0.140290  0.490784  ...  0.147256  0.113691
# 3    10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
# 4    10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
# ..            ...       ...       ...       ...  ...       ...       ...
# 155  10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
# 156  10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
# 157  10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
# 158  10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
# 159  10000.000000  0.188150  0.163183  0.963802  ...  0.172685  0.128274
#
#      diff8184  diff8185  diff8186  diff8187  diff8188  diff8189  diff8190  \
# 0     0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
# 1     0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
# 2     0.27068  0.139771  0.169654  0.156122  0.469394  0.107833   10000.0
# 3     0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
# 4     0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 155   0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
# 156   0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
# 157   0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
# 158   0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
# 159   0.37114  0.162481  0.204318  0.185006  0.884637  0.120867   10000.0
#
#      diff8191
# 0    2.914480
# 1    2.914480
# 2    0.744538
# 3    2.914480
# 4    2.914480
# ..        ...
# 155  2.914480
# 156  2.914480
# 157  2.914480
# 158  2.914480
# 159  2.914480
#
# [160 rows x 8192 columns]

# %%
busy_matrix = [[0] * 8192 for _ in range(160)]
days = examples['day'].values
time = examples['time'].values
for i in range(160):
    for j in range(8192):
        if time[j] < 12:
            business = db[f'morning_{ord_to_day[days[j]]}'].values
        elif time[j] > 15:
            business = db[f'evening_{ord_to_day[days[j]]}'].values
        else:
            business = db[f'day_{ord_to_day[days[j]]}'].values
        busy_matrix[i][j] = business[i]

# %%
busy_df = pd.DataFrame(busy_matrix, index=db.index, columns=['busy' + str(idx) for idx in examples.index])

# %%
busy_df
# Out:
#      busy0  busy1  busy2  busy3  busy4  busy5  busy6  busy7  busy8  busy9  \
# 0     0.16   0.50   0.41   0.01   0.07   0.46   0.46   0.24   0.01   0.07
# 1     0.13   0.16   0.37   0.30   0.18   0.29   0.29   0.24   0.13   0.18
# 2     0.30   0.30   0.35   0.43   0.36   0.05   0.05   0.93   0.08   0.36
# 3     0.32   0.08   0.09   0.22   0.46   0.16   0.16   0.15   0.21   0.46
# 4     0.33   0.75   0.35   0.17   0.06   0.06   0.06   0.37   0.39   0.06
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 155   0.36   0.83   0.21   0.33   0.35   0.26   0.26   0.91   0.40   0.35
# 156   0.17   0.12   0.24   0.20   0.04   0.48   0.48   0.75   0.26   0.04
# 157   0.22   0.87   0.19   0.26   0.22   0.23   0.23   0.58   0.21   0.22
# 158   0.05   0.89   0.12   0.26   0.38   0.38   0.38   0.90   0.47   0.38
# 159   0.33   0.85   0.22   0.20   0.13   0.10   0.10   0.69   0.23   0.13
#
#      ...  busy8182  busy8183  busy8184  busy8185  busy8186  busy8187  \
# 0    ...      0.01      0.01      0.46      0.01      0.24      0.24
# 1    ...      0.30      0.13      0.29      0.30      0.24      0.24
# 2    ...      0.43      0.08      0.05      0.43      0.93      0.93
# 3    ...      0.22      0.21      0.16      0.22      0.15      0.15
# 4    ...      0.17      0.39      0.06      0.17      0.37      0.37
# ..   ...       ...       ...       ...       ...       ...       ...
# 155  ...      0.33      0.40      0.26      0.33      0.91      0.91
# 156  ...      0.20      0.26      0.48      0.20      0.75      0.75
# 157  ...      0.26      0.21      0.23      0.26      0.58      0.58
# 158  ...      0.26      0.47      0.38      0.26      0.90      0.90
# 159  ...      0.20      0.23      0.10      0.20      0.69      0.69
#
#      busy8188  busy8189  busy8190  busy8191
# 0        0.41      0.24      0.07      0.27
# 1        0.37      0.48      0.18      0.46
# 2        0.35      0.13      0.36      0.17
# 3        0.09      0.02      0.46      0.02
# 4        0.35      0.41      0.06      0.06
# ..        ...       ...       ...       ...
# 155      0.21      0.11      0.35      0.02
# 156      0.24      0.19      0.04      0.47
# 157      0.19      0.50      0.22      0.22
# 158      0.12      0.19      0.38      0.07
# 159      0.22      0.25      0.13      0.48
#
# [160 rows x 8192 columns]

# %%
vect = []
for i in range(8192):
    dist = distances_df.loc[:, f'dist{i}']
    diff = diff_df.loc[:, f'diff{i}']
    busy = busy_df.loc[:, f'busy{i}']
    result = pd.concat([dist, diff, busy], axis=1, join="outer")
    result = result.sort_values(by=[f'dist{i}', f'diff{i}', f'busy{i}'])
    vect.append(list(result.loc[[result.index[0], result.index[-1]]].values))

# %%
vect
# Out:
# [[array([0.09229051, 0.53911467, 0.02      ]),
#   array([0.86316656, 1.1697371 , 0.33      ])],
#  [array([0.0074266 , 0.17617587, 0.02      ]),
#   array([0.79336001, 0.17617587, 0.16      ])],
#  [array([0.07823996, 0.56238629, 0.2       ]),
#   array([1.23498749, 0.56238629, 0.31      ])],
#  [array([0.04697293, 0.13366043, 0.43      ]),
#   array([0.97098638, 0.1542818 , 0.2       ])],
#  [array([0.0192495 , 1.81344877, 0.23      ]),
#   array([7.91963174e-01, 1.00000000e+04, 4.40000000e-01])],
#  [array([0.05397494, 0.29566916, 0.42      ]),
#   array([0.96880967, 0.41978732, 0.41      ])],
#  [array([1.42253e-02, 1.00000e+04, 8.00000e-02]),
#   array([8.37434304e-01, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.01982233, 0.15835511, 0.9       ]),
#   array([0.9380748 , 0.18814956, 0.49      ])],
#  [array([0.08571652, 0.14029032, 0.47      ]),
#   array([0.83650099, 0.16318337, 0.27      ])],
#  [array([0.02627201, 0.49078358, 0.1       ]),
#   array([0.7651165 , 0.96380157, 0.44      ])],
#  [array([0.02450419, 0.25451666, 0.07      ]),
#   array([0.83215016, 0.34141161, 0.37      ])],
#  [array([0.08476728, 0.19916762, 0.11      ]),
#   array([0.93314946, 0.19916762, 0.16      ])],
#  [array([0.00549002, 0.13549671, 0.2       ]),
#   array([0.82604591, 0.15673359, 0.13      ])],
#  [array([0.00468204, 0.16570218, 0.43      ]),
#   array([0.82038236, 0.19861275, 0.15      ])],
#  [array([0.1595888 , 0.63291463, 0.3       ]),
#   array([0.96242541, 1.72416198, 0.33      ])],
#  [array([0.28994533, 0.88741894, 0.17      ]),
#   array([1.27199017, 0.88741894, 0.13      ])],
#  [array([0.1923696 , 0.31072027, 0.14      ]),
#   array([1.13115621, 0.31072027, 0.35      ])],
#  [array([0.15422538, 0.34875188, 0.37      ]),
#   array([1.26763563, 0.34875188, 0.38      ])],
#  [array([0.02603174, 0.81870079, 0.28      ]),
#   array([0.85229397, 0.81870079, 0.13      ])],
#  [array([6.5982764e-02, 1.0000000e+04, 2.3000000e-01]),
#   array([8.86650127e-01, 1.00000000e+04, 2.90000000e-01])],
#  [array([0.02097949, 0.32784629, 0.4       ]),
#   array([0.79018271, 0.48775493, 0.33      ])],
#  [array([0.0391786 , 0.12859822, 0.36      ]),
#   array([0.97537516, 0.14757626, 0.06      ])],
#  [array([0.01065363, 1.03003473, 0.26      ]),
#   array([0.86141528, 1.03003473, 0.13      ])],
#  [array([3.64819014e-02, 1.00000000e+04, 2.10000000e-01]),
#   array([1.33902338e+00, 1.00000000e+04, 1.80000000e-01])],
#  [array([0.05862057, 0.13213392, 0.2       ]),
#   array([0.97608765, 0.1522515 , 0.39      ])],
#  [array([0.01398619, 0.11639376, 0.4       ]),
#   array([0.8082073 , 0.13172582, 0.06      ])],
#  [array([0.03843886, 0.18540607, 0.42      ]),
#   array([1.06775466, 0.18540607, 0.85      ])],
#  [array([0.00526233, 0.11122185, 0.06      ]),
#   array([0.77913369, 0.12514018, 0.23      ])],
#  [array([0.34272324, 0.1142539 , 0.38      ]),
#   array([1.06929653, 0.1142539 , 0.36      ])],
#  [array([0.00991457, 1.0128061 , 0.02      ]),
#   array([7.84434138e-01, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.02413316, 0.14379848, 0.03      ]),
#   array([0.81371596, 0.14379848, 0.23      ])],
#  [array([0.01311174, 0.30011886, 0.61      ]),
#   array([0.83641634, 0.30011886, 0.16      ])],
#  [array([0.16892429, 0.12842781, 0.02      ]),
#   array([1.20700491, 0.12842781, 0.25      ])],
#  [array([0.04839209, 7.25759617, 0.45      ]),
#   array([1.24633988, 7.25759617, 0.1       ])],
#  [array([0.05751173, 0.37357349, 0.74      ]),
#   array([0.91825492, 0.37357349, 0.89      ])],
#  [array([0.02262391, 0.16374033, 0.52      ]),
#   array([0.77189464, 0.19580081, 0.85      ])],
#  [array([0.007719  , 0.12102715, 0.48      ]),
#   array([0.82019772, 0.12102715, 0.22      ])],
#  [array([2.12735049e-02, 1.00000000e+04, 1.00000000e-01]),
#   array([1.20075054e+00, 1.00000000e+04, 2.20000000e-01])],
#  [array([0.27673786, 0.14025926, 0.47      ]),
#   array([1.20444186, 0.14025926, 0.13      ])],
#  [array([0.03986438, 0.11857532, 0.08      ]),
#   array([1.01653604, 0.13452689, 0.06      ])],
#  [array([6.30353236e-02, 1.00000000e+04, 4.00000000e-02]),
#   array([1.11395625e+00, 1.00000000e+04, 1.80000000e-01])],
#  [array([4.41747685e-03, 1.68685010e+01, 4.80000000e-01]),
#   array([7.56004392e-01, 1.00000000e+04, 1.80000000e-01])],
#  [array([0.04160158, 0.543246  , 0.34      ]),
#   array([0.96569966, 1.18936234, 0.13      ])],
#  [array([0.11519399, 0.17841935, 0.91      ]),
#   array([0.88463855, 0.21716596, 0.85      ])],
#  [array([0.00879498, 0.15750068, 0.18      ]),
#   array([0.78477223, 0.15750068, 0.13      ])],
#  [array([0.01543365, 0.11139771, 0.27      ]),
#   array([0.79036596, 0.11139771, 0.39      ])],
#  [array([0.19303056, 0.63397691, 0.06      ]),
#   array([0.90195671, 0.63397691, 0.38      ])],
#  [array([0.11993798, 3.02300349, 0.19      ]),
#   array([1.33740748, 3.02300349, 0.29      ])],
#  [array([4.99355934e-02, 1.00000000e+04, 4.60000000e-01]),
#   array([1.00229536e+00, 1.00000000e+04, 3.90000000e-01])],
#  [array([0.00808539, 0.4431396 , 0.44      ]),
#   array([0.77265983, 0.79578221, 0.47      ])],
#  [array([0.22063903, 0.28205314, 0.31      ]),
#   array([1.13613782, 0.28205314, 0.31      ])],
#  [array([0.02739157, 0.1501437 , 0.34      ]),
#   array([1.20598663, 0.1501437 , 0.23      ])],
#  [array([0.04050905, 7.02909396, 0.18      ]),
#   array([9.0248838e-01, 1.0000000e+04, 4.6000000e-01])],
#  [array([0.05819082, 0.88269372, 0.19      ]),
#   array([0.88998178, 0.88269372, 0.37      ])],
#  [array([0.02564817, 0.29919323, 0.37      ]),
#   array([0.82303415, 0.42692685, 0.41      ])],
#  [array([0.02319808, 0.34891097, 0.11      ]),
#   array([0.79529012, 0.53588827, 0.13      ])],
#  [array([0.22822102, 6.44163807, 0.38      ]),
#   array([1.23521431, 6.44163807, 0.48      ])],
#  [array([0.00396327, 2.30933853, 0.06      ]),
#   array([1.03120794, 2.30933853, 0.44      ])],
#  [array([0.01018069, 0.12314295, 0.31      ]),
#   array([0.79495324, 0.14043674, 0.48      ])],
#  [array([5.24659176e-03, 1.00000000e+04, 1.60000000e-01]),
#   array([7.49904491e-01, 1.00000000e+04, 1.30000000e-01])],
#  [array([0.28125567, 0.46804844, 0.24      ]),
#   array([1.36387172, 0.46804844, 0.37      ])],
#  [array([0.16158251, 0.67491126, 0.12      ]),
#   array([1.26130941, 0.67491126, 0.13      ])],
#  [array([0.02497639, 0.44737402, 0.39      ]),
#   array([0.94955501, 0.80954214, 0.48      ])],
#  [array([0.10528705, 0.18842509, 0.29      ]),
#   array([1.17397182, 0.18842509, 0.69      ])],
#  [array([0.01399611, 0.29419364, 0.61      ]),
#   array([0.83874087, 0.29419364, 0.16      ])],
#  [array([0.05654931, 0.3017891 , 0.74      ]),
#   array([1.26764869, 0.3017891 , 0.25      ])],
#  [array([0.15282451, 0.16851189, 0.89      ]),
#   array([1.01668597, 0.16851189, 0.16      ])],
#  [array([0.04867931, 0.28960403, 0.1       ]),
#   array([1.02656954, 0.40766564, 0.1       ])],
#  [array([0.00611281, 0.5799683 , 0.27      ]),
#   array([0.76605249, 0.5799683 , 0.29      ])],
#  [array([0.07999514, 2.8796155 , 0.38      ]),
#   array([1.01327383, 2.8796155 , 0.18      ])],
#  [array([0.05163398, 0.23696587, 0.31      ]),
#   array([0.99526672, 0.23696587, 0.31      ])],
#  [array([0.15563229, 0.33935634, 0.47      ]),
#   array([1.21435005, 0.33935634, 0.46      ])],
#  [array([0.00687801, 0.60577389, 0.06      ]),
#   array([0.78169985, 0.60577389, 0.47      ])],
#  [array([0.03301994, 0.17551425, 0.79      ]),
#   array([0.86865918, 0.21287724, 0.2       ])],
#  [array([0.01160101, 0.14498987, 0.38      ]),
#   array([0.77726492, 0.16957679, 0.13      ])],
#  [array([0.02580955, 1.30694612, 0.16      ]),
#   array([0.85704709, 1.30694612, 0.38      ])],
#  [array([0.01331214, 0.15662549, 0.19      ]),
#   array([0.85345593, 0.15662549, 0.03      ])],
#  [array([0.2114313 , 0.15720795, 0.43      ]),
#   array([1.14699372, 0.18653232, 0.2       ])],
#  [array([0.01959708, 0.14491579, 0.54      ]),
#   array([0.8337167 , 0.16947546, 0.35      ])],
#  [array([0.0381022, 1.8528266, 0.27     ]),
#   array([0.77481585, 1.8528266 , 0.29      ])],
#  [array([0.024507  , 0.16414528, 0.08      ]),
#   array([0.95038487, 0.16414528, 0.36      ])],
#  [array([0.01775557, 0.26987109, 0.38      ]),
#   array([0.86046613, 0.26987109, 0.2       ])],
#  [array([0.01703449, 0.15598118, 0.39      ]),
#   array([0.83972277, 0.15598118, 0.25      ])],
#  [array([0.0562594 , 0.19396465, 0.85      ]),
#   array([1.08773848, 0.24064038, 0.06      ])],
#  [array([0.00392268, 1.1914161 , 0.31      ]),
#   array([7.61683185e-01, 1.00000000e+04, 4.70000000e-01])],
#  [array([0.17458156, 0.13703941, 0.4       ]),
#   array([0.9486524 , 0.13703941, 0.13      ])],
#  [array([0.06368179, 0.39186185, 0.22      ]),
#   array([0.82127248, 0.39186185, 0.29      ])],
#  [array([0.08988627, 0.16123397, 0.5       ]),
#   array([0.9688198 , 0.16123397, 0.48      ])],
#  [array([0.04299341, 0.74693153, 0.32      ]),
#   array([0.86493993, 2.95149974, 0.1       ])],
#  [array([5.52932263e-02, 1.00000000e+04, 1.20000000e-01]),
#   array([1.06289123e+00, 1.00000000e+04, 4.10000000e-01])],
#  [array([0.12359908, 0.13903383, 0.2       ]),
#   array([1.0839006 , 0.13903383, 0.3       ])],
#  [array([0.05264928, 0.20703336, 0.3       ]),
#   array([1.02280679, 0.2610871 , 0.85      ])],
#  [array([0.05754945, 0.27206437, 0.18      ]),
#   array([0.88413788, 0.37374785, 0.46      ])],
#  [array([0.20848063, 0.24450786, 0.45      ]),
#   array([1.25451361, 0.24450786, 0.25      ])],
#  [array([0.12488395, 0.11064695, 0.08      ]),
#   array([1.0111356 , 0.12441285, 0.23      ])],
#  [array([0.02649536, 0.11464599, 0.14      ]),
#   array([0.87104232, 0.1294917 , 0.48      ])],
#  [array([0.0041768 , 0.17453102, 0.47      ]),
#   array([0.7840028 , 0.21143257, 0.46      ])],
#  [array([0.01164558, 0.15770671, 0.01      ]),
#   array([0.81306234, 0.15770671, 0.13      ])],
#  [array([3.96146846e-02, 1.00000000e+04, 4.20000000e-01]),
#   array([1.04625398e+00, 1.00000000e+04, 4.70000000e-01])],
#  [array([0.02919594, 0.15602624, 0.03      ]),
#   array([0.99724483, 0.18487097, 0.13      ])],
#  [array([0.06413816, 0.11881315, 0.47      ]),
#   array([0.97289957, 0.1348331 , 0.25      ])],
#  [array([0.10845808, 0.13587661, 0.06      ]),
#   array([1.1154526 , 0.13587661, 0.2       ])],
#  [array([0.00965119, 0.16114818, 0.44      ]),
#   array([0.80985599, 0.16114818, 0.25      ])],
#  [array([0.16550862, 0.12356096, 0.22      ]),
#   array([0.8811264 , 0.12356096, 0.25      ])],
#  [array([0.15914084, 0.12063447, 0.23      ]),
#   array([1.30712048, 0.12063447, 0.25      ])],
#  [array([0.05865754, 1.98681234, 0.21      ]),
#   array([1.26538816, 1.98681234, 0.13      ])],
#  [array([0.05119632, 0.27847102, 0.74      ]),
#   array([0.90576288, 0.27847102, 0.65      ])],
#  [array([0.00976689, 0.36136778, 0.44      ]),
#   array([0.77405354, 0.56584645, 0.47      ])],
#  [array([0.01171021, 0.15231866, 0.67      ]),
#   array([0.91308161, 0.17968858, 0.35      ])],
#  [array([0.18708468, 0.53539112, 0.05      ]),
#   array([1.03029035, 1.152348  , 0.1       ])],
#  [array([0.02134496, 0.20342506, 0.03      ]),
#   array([1.02455754, 0.20342506, 0.46      ])],
#  [array([2.21993848e-01, 1.00000000e+04, 3.40000000e-01]),
#   array([1.37328718e+00, 1.00000000e+04, 4.10000000e-01])],
#  [array([1.24289816e-01, 1.00000000e+04, 1.70000000e-01]),
#   array([1.1434839e+00, 1.0000000e+04, 1.3000000e-01])],
#  [array([0.00225304, 1.08599016, 0.21      ]),
#   array([0.8267407 , 1.08599016, 0.25      ])],
#  [array([0.00152747, 0.74413038, 0.12      ]),
#   array([0.78413563, 0.74413038, 0.31      ])],
#  [array([0.00412151, 0.1605022 , 0.12      ]),
#   array([0.75233836, 0.1605022 , 0.03      ])],
#  [array([0.06468895, 2.53677067, 0.24      ]),
#   array([0.97828935, 2.53677067, 0.48      ])],
#  [array([0.05425148, 0.15558502, 0.26      ]),
#   array([1.03333911, 0.15558502, 0.13      ])],
#  [array([0.28122243, 0.1351663 , 0.2       ]),
#   array([1.36797067, 0.1351663 , 0.3       ])],
#  [array([0.00821767, 0.27275047, 0.03      ]),
#   array([0.77769617, 0.27275047, 0.95      ])],
#  [array([0.01017475, 0.28725507, 0.35      ]),
#   array([1.04094767, 0.28725507, 0.85      ])],
#  [array([0.11349737, 0.40864794, 0.39      ]),
#   array([1.2625035 , 0.40864794, 0.38      ])],
#  [array([0.04886648, 1.917827  , 0.22      ]),
#   array([0.91090477, 1.917827  , 0.13      ])],
#  [array([0.24454125, 0.25632973, 0.15      ]),
#   array([1.26981664, 0.25632973, 0.49      ])],
#  [array([0.03853837, 0.11425206, 0.06      ]),
#   array([0.85000561, 0.12898936, 0.06      ])],
#  [array([0.04680114, 0.30698388, 0.08      ]),
#   array([1.04168841, 0.30698388, 0.2       ])],
#  [array([0.12787688, 0.1307049 , 0.13      ]),
#   array([1.08677948, 0.15035734, 0.25      ])],
#  [array([0.14345208, 2.71175874, 0.46      ]),
#   array([1.13575874, 2.71175874, 0.44      ])],
#  [array([0.07047297, 0.12213479, 0.19      ]),
#   array([1.06037726, 0.12213479, 0.48      ])],
#  [array([0.26795625, 0.2817824 , 0.33      ]),
#   array([0.98403558, 0.2817824 , 0.46      ])],
#  [array([0.07812085, 1.68680029, 0.47      ]),
#   array([1.13074695, 1.68680029, 0.46      ])],
#  [array([0.0013503 , 0.31990751, 0.41      ]),
#   array([0.76702827, 0.47038825, 0.44      ])],
#  [array([0.07246436, 0.2168227 , 0.5       ]),
#   array([1.20773071, 0.2168227 , 0.55      ])],
#  [array([0.06394529, 0.22435603, 0.83      ]),
#   array([0.91422137, 0.22435603, 0.85      ])],
#  [array([0.28064302, 0.16205373, 0.38      ]),
#   array([1.11715348, 0.16205373, 0.36      ])],
#  [array([0.10831726, 0.14053144, 0.4       ]),
#   array([0.94595481, 0.14053144, 0.23      ])],
#  [array([2.13043257e-01, 1.00000000e+04, 6.00000000e-02]),
#   array([9.61756611e-01, 1.00000000e+04, 4.40000000e-01])],
#  [array([0.00360044, 0.906871  , 0.38      ]),
#   array([0.75057035, 9.73779367, 0.22      ])],
#  [array([0.02634647, 0.11645798, 0.3       ]),
#   array([0.94817454, 0.13180808, 0.06      ])],
#  [array([3.84844421e-02, 1.00000000e+04, 4.20000000e-01]),
#   array([1.05097868e+00, 1.00000000e+04, 4.70000000e-01])],
#  [array([0.01574681, 0.11601037, 0.22      ]),
#   array([0.78380207, 0.13123499, 0.48      ])],
#  [array([0.06482295, 0.20804013, 0.14      ]),
#   array([1.01151046, 0.20804013, 0.35      ])],
#  [array([0.01145506, 0.21099534, 0.47      ]),
#   array([0.78175218, 0.21099534, 0.06      ])],
#  [array([0.00750801, 0.33599104, 0.31      ]),
#   array([0.77640466, 0.50600378, 0.47      ])],
#  [array([0.05203032, 0.29762075, 0.2       ]),
#   array([0.88625494, 0.42373227, 0.29      ])],
#  [array([0.16057481, 0.12553841, 0.19      ]),
#   array([0.95177322, 0.12553841, 0.48      ])],
#  [array([0.00388778, 0.21121098, 0.5       ]),
#   array([1.15630326, 0.21121098, 0.06      ])],
#  [array([0.01123637, 0.27558532, 0.02      ]),
#   array([0.93236183, 0.38042481, 0.48      ])],
#  [array([0.01461562, 0.13304777, 0.05      ]),
#   array([0.88058046, 0.15346609, 0.25      ])],
#  [array([0.03102997, 2.39787389, 0.28      ]),
#   array([1.02262059, 2.39787389, 0.25      ])],
#  [array([0.02098406, 0.47985322, 0.09      ]),
#   array([0.78402153, 0.92253425, 0.31      ])],
#  [array([0.25869979, 0.14626275, 0.26      ]),
#   array([1.28915582, 0.14626275, 0.13      ])],
#  [array([0.17971568, 0.19684011, 0.12      ]),
#   array([1.0229156 , 0.19684011, 0.15      ])],
#  [array([0.15904548, 0.1114684 , 0.19      ]),
#   array([1.10706971, 0.1114684 , 0.48      ])],
#  [array([0.08566887, 0.15240658, 0.21      ]),
#   array([0.99863111, 0.15240658, 0.13      ])],
#  [array([0.0863915 , 0.78208997, 0.15      ]),
#   array([0.98936117, 3.58904988, 0.22      ])],
#  [array([0.06978876, 0.19501387, 0.29      ]),
#   array([1.19626033, 0.19501387, 0.69      ])],
#  [array([0.08750045, 0.53382724, 0.15      ]),
#   array([0.8742552 , 1.14512748, 0.22      ])],
#  [array([4.98824709e-02, 1.00000000e+04, 2.30000000e-01]),
#   array([9.75388585e-01, 1.00000000e+04, 4.40000000e-01])],
#  [array([0.04621415, 1.12917046, 0.14      ]),
#   array([0.89579674, 1.12917046, 0.47      ])],
#  [array([0.32097532, 0.35603853, 0.33      ]),
#   array([1.08776426, 0.35603853, 0.55      ])],
#  [array([0.22395204, 0.42862003, 0.3       ]),
#   array([1.17302335, 0.75014884, 0.33      ])],
#  [array([0.02550148, 0.11535873, 0.11      ]),
#   array([0.7658848 , 0.11535873, 0.28      ])],
#  [array([0.21297167, 0.2193935 , 0.62      ]),
#   array([1.36671409, 0.2193935 , 0.49      ])],
#  [array([0.23356383, 0.56104044, 0.38      ]),
#   array([1.05299379, 0.56104044, 0.29      ])],
#  [array([0.18407895, 0.12152829, 0.02      ]),
#   array([1.33152627, 0.12152829, 0.25      ])],
#  [array([0.04732045, 0.26451375, 0.01      ]),
#   array([0.80886304, 0.35964473, 0.38      ])],
#  [array([0.20502408, 0.38237396, 0.53      ]),
#   array([0.9184779 , 0.38237396, 0.55      ])],
#  [array([0.23728679, 0.86134443, 0.16      ]),
#   array([1.23731889, 0.86134443, 0.41      ])],
#  [array([0.0522824 , 0.16646434, 0.22      ]),
#   array([0.87333015, 0.19970873, 0.05      ])],
#  [array([0.06697618, 3.37914255, 0.31      ]),
#   array([1.03032717, 3.37914255, 0.39      ])],
#  [array([2.82266005e-03, 1.00000000e+04, 3.00000000e-01]),
#   array([7.55495945e-01, 1.00000000e+04, 4.60000000e-01])],
#  [array([0.09852586, 0.51243357, 0.07      ]),
#   array([1.04607158, 0.51243357, 0.46      ])],
#  [array([0.07543468, 0.1346666 , 0.29      ]),
#   array([1.09896163, 0.1346666 , 0.27      ])],
#  [array([0.29697598, 0.2192789 , 0.52      ]),
#   array([1.25239723, 0.2192789 , 0.15      ])],
#  [array([0.23298665, 0.11305541, 0.47      ]),
#   array([1.05029691, 0.11305541, 0.13      ])],
#  [array([7.95065545e-03, 1.00000000e+04, 3.60000000e-01]),
#   array([8.39830411e-01, 1.00000000e+04, 2.90000000e-01])],
#  [array([0.00472889, 0.28957845, 0.48      ]),
#   array([0.76680725, 0.28957845, 0.86      ])],
#  [array([0.04511877, 0.23745276, 0.53      ]),
#   array([0.98133768, 0.31139416, 0.24      ])],
#  [array([0.20264383, 0.12898227, 0.06      ]),
#   array([1.39704867, 0.12898227, 0.28      ])],
#  [array([0.06543019, 0.11257272, 0.19      ]),
#   array([1.13960813, 0.11257272, 0.48      ])],
#  [array([0.02303686, 0.4486091 , 0.46      ]),
#   array([0.83827881, 0.81359541, 0.37      ])],
#  [array([0.02232595, 0.30679979, 0.09      ]),
#   array([0.92049859, 0.30679979, 0.16      ])],
#  [array([0.09851597, 4.30652425, 0.21      ]),
#   array([1.21497914, 4.30652425, 0.25      ])],
#  [array([0.16058576, 4.29377575, 0.02      ]),
#   array([1.11749389, 4.29377575, 0.48      ])],
#  [array([0.04118781, 0.11445969, 0.39      ]),
#   array([1.18280501, 0.11445969, 0.25      ])],
#  [array([0.03126816, 0.19407689, 0.12      ]),
#   array([0.91012307, 0.24081316, 0.24      ])],
#  [array([3.9391529e-02, 1.0000000e+04, 1.0000000e-02]),
#   array([8.61008219e-01, 1.00000000e+04, 1.30000000e-01])],
#  [array([0.08268964, 0.33031192, 0.95      ]),
#   array([1.00117626, 0.33031192, 0.15      ])],
#  [array([0.07239885, 0.55086761, 0.22      ]),
#   array([0.808223  , 0.55086761, 0.29      ])],
#  [array([0.37606987, 0.1899045 , 0.11      ]),
#   array([1.09025667, 0.1899045 , 0.25      ])],
#  [array([0.03029746, 0.36527891, 0.16      ]),
#   array([0.96781591, 0.57549515, 0.31      ])],
#  [array([0.403864  , 0.19192285, 0.15      ]),
#   array([1.11666038, 0.19192285, 0.69      ])],
#  [array([0.03592257, 0.68607822, 0.33      ]),
#   array([0.87519456, 2.18550687, 0.25      ])],
#  [array([0.15406191, 0.11260129, 0.08      ]),
#   array([1.13128732, 0.12688918, 0.23      ])],
#  [array([0.07146252, 0.41760746, 0.91      ]),
#   array([0.90062774, 0.41760746, 0.55      ])],
#  [array([0.0773257 , 0.70806765, 0.04      ]),
#   array([1.16321984, 0.70806765, 0.18      ])],
#  [array([0.01746043, 0.68277245, 0.14      ]),
#   array([0.76369482, 0.68277245, 0.48      ])],
#  [array([0.28083963, 0.16435495, 0.2       ]),
#   array([1.26403014, 0.16435495, 0.3       ])],
#  [array([0.09100686, 0.23510101, 0.88      ]),
#   array([0.86581626, 0.23510101, 0.31      ])],
#  [array([0.15362559, 0.59999477, 0.35      ]),
#   array([0.9501698 , 0.59999477, 0.31      ])],
#  [array([0.07519112, 0.18146515, 0.26      ]),
#   array([1.08264791, 0.22169508, 0.89      ])],
#  [array([0.19720053, 0.14071747, 0.11      ]),
#   array([1.15215566, 0.14071747, 0.25      ])],
#  [array([0.0217604 , 0.44722225, 0.2       ]),
#   array([0.94370946, 0.44722225, 0.06      ])],
#  [array([0.08688398, 0.13562505, 0.21      ]),
#   array([1.23104268, 0.13562505, 0.06      ])],
#  [array([0.04512859, 0.19773234, 0.9       ]),
#   array([0.94442528, 0.19773234, 0.24      ])],
#  [array([0.31384874, 0.14741735, 0.47      ]),
#   array([1.25147913, 0.14741735, 0.13      ])],
#  [array([0.18963646, 0.18357173, 0.89      ]),
#   array([1.06942438, 0.18357173, 0.16      ])],
#  [array([0.06860647, 0.13183056, 0.22      ]),
#   array([1.08229798, 0.13183056, 0.06      ])],
#  [array([0.05471935, 0.12505348, 0.22      ]),
#   array([0.91131734, 0.142927  , 0.37      ])],
#  [array([0.06763052, 0.29949695, 0.04      ]),
#   array([0.82764024, 0.29949695, 0.89      ])],
#  [array([0.07456298, 0.11668965, 0.08      ]),
#   array([0.86637802, 0.11668965, 0.37      ])],
#  [array([0.03197713, 0.54544212, 0.32      ]),
#   array([1.02973775, 0.54544212, 0.39      ])],
#  [array([0.20777306, 0.27769219, 0.05      ]),
#   array([0.91139389, 0.38445131, 0.1       ])],
#  [array([0.10109633, 0.35412428, 0.48      ]),
#   array([1.12896273, 0.35412428, 0.29      ])],
#  [array([0.02667914, 0.30190446, 0.48      ]),
#   array([0.84289237, 0.43246868, 0.46      ])],
#  [array([0.00926859, 0.13708672, 0.18      ]),
#   array([0.7783584 , 0.13708672, 0.03      ])],
#  [array([0.01197814, 0.15505001, 0.42      ]),
#   array([1.30683704, 0.15505001, 0.13      ])],
#  [array([0.02294879, 0.11195186, 0.46      ]),
#   array([0.85252092, 0.11195186, 0.13      ])],
#  [array([0.14373246, 0.70166208, 0.48      ]),
#   array([1.20544264, 0.70166208, 0.29      ])],
#  [array([0.00323858, 0.24708396, 0.85      ]),
#   array([1.09139685, 0.32816934, 0.55      ])],
#  [array([0.02450946, 0.13487985, 0.46      ]),
#   array([0.83678214, 0.13487985, 0.13      ])],
#  [array([0.19341964, 0.30410383, 0.12      ]),
#   array([1.08092134, 0.30410383, 0.15      ])],
#  [array([0.03291729, 0.11523618, 0.18      ]),
#   array([0.98483494, 0.13024513, 0.13      ])],
#  [array([0.01277108, 1.91454417, 0.27      ]),
#   array([8.30485157e-01, 1.00000000e+04, 1.30000000e-01])],
#  [array([0.19244083, 0.11637511, 0.11      ]),
#   array([0.96635914, 0.11637511, 0.48      ])],
#  [array([0.09373319, 0.23295213, 0.3       ]),
#   array([0.95322955, 0.3036996 , 0.85      ])],
#  [array([0.22276586, 0.1469314 , 0.4       ]),
#   array([1.06022179, 0.1469314 , 0.21      ])],
#  [array([0.12988398, 0.14085476, 0.11      ]),
#   array([1.00725539, 0.14085476, 0.25      ])],
#  [array([0.1603657, 0.2805936, 0.75     ]),
#   array([1.22887597, 0.2805936 , 0.24      ])],
#  [array([0.05195166, 1.48332732, 0.05      ]),
#   array([1.00854491e+00, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.06257403, 1.35173074, 0.36      ]),
#   array([9.9040065e-01, 1.0000000e+04, 1.3000000e-01])],
#  [array([0.13460925, 0.32391743, 0.97      ]),
#   array([1.21622327, 0.32391743, 0.31      ])],
#  [array([0.0183288 , 2.72685501, 0.07      ]),
#   array([0.81928187, 2.72685501, 0.29      ])],
#  [array([0.0157553 , 0.28877857, 0.07      ]),
#   array([0.84821006, 0.40603187, 0.89      ])],
#  [array([0.02269393, 0.13314828, 0.2       ]),
#   array([0.81127188, 0.13314828, 0.06      ])],
#  [array([0.03868023, 0.64415858, 0.02      ]),
#   array([0.83332804, 1.81024061, 0.33      ])],
#  [array([0.11121377, 1.24725765, 0.24      ]),
#   array([1.16579309, 1.24725765, 0.37      ])],
#  [array([9.96134767e-03, 2.01456571e+01, 2.00000000e-01]),
#   array([ 0.77676647, 20.14565712,  0.25      ])],
#  [array([0.01090078, 0.1764311 , 0.43      ]),
#   array([0.80569702, 0.21422749, 0.7       ])],
#  [array([0.06196812, 0.35850632, 0.19      ]),
#   array([0.88436096, 0.35850632, 0.37      ])],
#  [array([0.09117497, 0.18327911, 0.32      ]),
#   array([0.82696405, 0.18327911, 0.16      ])],
#  [array([7.95380811e-02, 1.00000000e+04, 4.60000000e-01]),
#   array([1.11731978e+00, 1.00000000e+04, 4.40000000e-01])],
#  [array([0.20504144, 0.40528292, 0.16      ]),
#   array([0.90441937, 0.40528292, 0.48      ])],
#  [array([0.22000594, 0.12703261, 0.36      ]),
#   array([1.12088038, 0.14551816, 0.06      ])],
#  [array([0.16647844, 0.16515127, 0.4       ]),
#   array([1.13997415, 0.16515127, 0.28      ])],
#  [array([0.20291481, 0.21485296, 0.89      ]),
#   array([1.0431597 , 0.21485296, 0.16      ])],
#  [array([0.03593647, 0.13247113, 0.39      ]),
#   array([0.85169187, 0.15269939, 0.25      ])],
#  [array([0.02289392, 0.12772533, 0.15      ]),
#   array([0.7908341 , 0.14642788, 0.3       ])],
#  [array([0.1051615 , 1.03772255, 0.12      ]),
#   array([0.98323894, 1.03772255, 0.37      ])],
#  [array([0.26408642, 0.25985576, 0.62      ]),
#   array([1.05348863, 0.25985576, 0.49      ])],
#  [array([0.03141646, 0.11188707, 0.23      ]),
#   array([1.19659853, 0.11188707, 0.25      ])],
#  [array([0.19802556, 0.11460674, 0.19      ]),
#   array([1.13018522, 0.11460674, 0.06      ])],
#  [array([0.16022898, 0.27311093, 0.92      ]),
#   array([0.93160548, 0.27311093, 0.49      ])],
#  [array([0.0072701 , 0.14284044, 0.18      ]),
#   array([0.79904819, 0.16664393, 0.25      ])],
#  [array([0.01676541, 0.19090399, 0.41      ]),
#   array([1.14424434, 0.19090399, 0.95      ])],
#  [array([0.01816573, 0.1584937 , 0.6       ]),
#   array([0.81081271, 0.18834523, 0.35      ])],
#  [array([0.04059864, 0.12967301, 0.47      ]),
#   array([0.97771946, 0.12967301, 0.13      ])],
#  [array([0.0277123 , 0.38378629, 0.24      ]),
#   array([0.81270846, 0.62281363, 0.41      ])],
#  [array([0.07766986, 1.84496171, 0.42      ]),
#   array([1.12462768, 1.84496171, 0.48      ])],
#  [array([2.40591234e-03, 1.00000000e+04, 4.70000000e-01]),
#   array([7.76557563e-01, 1.00000000e+04, 1.80000000e-01])],
#  [array([0.07290965, 0.23070385, 0.32      ]),
#   array([0.82262363, 0.23070385, 0.16      ])],
#  [array([0.18619242, 0.1470198 , 0.11      ]),
#   array([1.14266001, 0.1470198 , 0.25      ])],
#  [array([0.01028904, 0.21744765, 0.23      ]),
#   array([0.81381278, 0.21744765, 0.06      ])],
#  [array([0.07305213, 0.84705805, 0.46      ]),
#   array([1.1874223 , 0.84705805, 0.48      ])],
#  [array([0.08908537, 2.05579169, 0.05      ]),
#   array([1.05040485e+00, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.04533389, 0.81525904, 0.34      ]),
#   array([0.8605663 , 4.41298475, 0.29      ])],
#  [array([8.48172001e-03, 1.00000000e+04, 1.40000000e-01]),
#   array([1.03852141e+00, 1.00000000e+04, 3.90000000e-01])],
#  [array([0.01127515, 0.18898246, 0.73      ]),
#   array([0.77734656, 0.23301896, 0.89      ])],
#  [array([0.20927631, 0.30092123, 0.11      ]),
#   array([1.01069129, 0.30092123, 0.65      ])],
#  [array([0.1434871 , 0.21977616, 0.59      ]),
#   array([1.26778324, 0.21977616, 0.55      ])],
#  [array([0.13377573, 0.17727324, 0.12      ]),
#   array([1.09818911, 0.17727324, 0.16      ])],
#  [array([0.2155469 , 1.04404816, 0.05      ]),
#   array([1.06515527e+00, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.06116109, 0.12790162, 0.01      ]),
#   array([1.01605335, 0.12790162, 0.25      ])],
#  [array([0.12004737, 0.15970209, 0.42      ]),
#   array([1.14476552, 0.19005414, 0.24      ])],
#  [array([0.04353674, 0.16257081, 0.41      ]),
#   array([0.8879116 , 0.16257081, 0.37      ])],
#  [array([0.21489994, 0.13793222, 0.17      ]),
#   array([0.9549576 , 0.13793222, 0.05      ])],
#  [array([0.04296146, 0.21379165, 0.72      ]),
#   array([1.077811  , 0.27192748, 0.16      ])],
#  [array([0.31928551, 0.41175615, 0.3       ]),
#   array([1.24124373, 0.69997529, 0.33      ])],
#  [array([0.06964995, 0.12109155, 0.46      ]),
#   array([1.38983623, 0.12109155, 0.25      ])],
#  [array([0.07451499, 0.24678289, 0.87      ]),
#   array([0.87204037, 0.24678289, 0.16      ])],
#  [array([0.09671717, 0.15281451, 0.26      ]),
#   array([1.04561065, 0.15281451, 0.3       ])],
#  [array([0.01153337, 0.31830499, 0.18      ]),
#   array([0.94518681, 0.46693167, 0.47      ])],
#  [array([0.03564962, 0.18903301, 0.68      ]),
#   array([0.86073732, 0.18903301, 0.35      ])],
#  [array([0.16914024, 4.18369863, 0.05      ]),
#   array([1.13655961e+00, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.02937386, 0.17582644, 0.63      ]),
#   array([0.92702682, 0.21333666, 0.55      ])],
#  [array([0.08274021, 0.43665877, 0.23      ]),
#   array([0.94751772, 0.43665877, 0.29      ])],
#  [array([0.00237938, 0.16953186, 0.12      ]),
#   array([0.78782414, 0.20414011, 0.49      ])],
#  [array([0.00659724, 0.16954146, 0.02      ]),
#   array([1.03330781, 0.16954146, 0.65      ])],
#  [array([0.07214756, 0.31784358, 0.42      ]),
#   array([1.29641263, 0.31784358, 0.89      ])],
#  [array([0.04968987, 0.25572365, 0.79      ]),
#   array([0.93235326, 0.25572365, 0.49      ])],
#  [array([0.01430235, 1.07587949, 0.19      ]),
#   array([1.00356463e+00, 1.00000000e+04, 7.00000000e-02])],
#  [array([0.05234389, 0.19528347, 0.06      ]),
#   array([0.9766396 , 0.19528347, 0.65      ])],
#  [array([0.25077135, 0.62495181, 0.36      ]),
#   array([1.02038688, 0.62495181, 0.2       ])],
#  [array([0.08675801, 1.17165072, 0.06      ]),
#   array([0.85403546, 1.17165072, 0.37      ])],
#  [array([0.01904269, 0.11186769, 0.03      ]),
#   array([0.78806812, 0.11186769, 0.06      ])],
#  [array([0.20293001, 0.13892872, 0.03      ]),
#   array([0.95030552, 0.13892872, 0.36      ])],
#  [array([0.36678525, 0.17553105, 0.38      ]),
#   array([1.1645925 , 0.21290196, 0.35      ])],
#  [array([0.22409702, 0.19917954, 0.11      ]),
#   array([1.06825358, 0.19917954, 0.65      ])],
#  [array([0.09520643, 0.20595893, 0.91      ]),
#   array([0.85222592, 0.25938071, 0.85      ])],
#  [array([0.00874467, 0.1430309 , 0.14      ]),
#   array([0.79271555, 0.16690322, 0.7       ])],
#  [array([0.14127205, 0.11230467, 0.08      ]),
#   array([1.10853539, 0.12651263, 0.23      ])],
#  [array([0.00394307, 0.32857371, 0.44      ]),
#   array([0.76182184, 0.48936676, 0.44      ])],
#  [array([0.02637657, 0.12288311, 0.21      ]),
#   array([0.77582507, 0.1400989 , 0.06      ])],
#  [array([0.02797033, 0.1709721 , 0.17      ]),
#   array([1.009263 , 0.1709721, 0.05     ])],
#  [array([0.02248507, 0.29912488, 0.38      ]),
#   array([0.87993901, 0.29912488, 0.2       ])],
#  [array([0.22728396, 0.20421689, 0.83      ]),
#   array([0.99861432, 0.20421689, 0.16      ])],
#  [array([0.01644371, 0.50379357, 0.42      ]),
#   array([0.79620386, 0.50379357, 0.22      ])],
#  [array([0.03155822, 0.55074468, 0.01      ]),
#   array([1.16983315, 0.55074468, 0.33      ])],
#  [array([0.17656854, 0.16759243, 0.7       ]),
#   array([1.35103576, 0.16759243, 0.95      ])],
#  [array([0.0211422 , 0.12376903, 0.24      ]),
#   array([0.78152087, 0.12376903, 0.23      ])],
#  [array([0.02393638, 0.13957388, 0.5       ]),
#   array([0.88699099, 0.13957388, 0.27      ])],
#  [array([1.21220015e-01, 1.00000000e+04, 2.40000000e-01]),
#   array([1.20394953e+00, 1.00000000e+04, 3.70000000e-01])],
#  [array([0.00305632, 0.14501   , 0.77      ]),
#   array([0.7688896 , 0.16960433, 0.15      ])],
#  [array([0.01954735, 0.10384383, 0.2       ]),
#   array([0.92696008, 0.11587693, 0.39      ])],
#  [array([0.24155438, 0.14662904, 0.19      ]),
#   array([1.01491826, 0.14662904, 0.28      ])],
#  [array([0.06793914, 0.12950182, 0.48      ]),
#   array([1.24303453, 0.12950182, 0.39      ])],
#  [array([0.04160778, 0.16452072, 0.32      ]),
#   array([1.26427432, 0.16452072, 0.03      ])],
#  [array([0.09054708, 1.18253527, 0.35      ]),
#   array([1.19398288, 1.18253527, 0.07      ])],
#  [array([0.11948166, 1.16715295, 0.3       ]),
#   array([1.02125529e+00, 1.00000000e+04, 3.30000000e-01])],
#  [array([0.05355681, 0.33325601, 0.1       ]),
#   array([1.06115613, 0.33325601, 0.2       ])],
#  [array([0.04334181, 0.30898806, 0.11      ]),
#   array([0.96238313, 0.30898806, 0.16      ])],
#  [array([0.19645524, 0.12207105, 0.47      ]),
#   array([0.98893854, 0.12207105, 0.13      ])],
#  [array([0.02999735, 0.2017594 , 0.94      ]),
#   array([1.03956966, 0.2017594 , 0.65      ])],
#  [array([0.00558674, 0.26959734, 0.03      ]),
#   array([0.87726016, 0.26959734, 0.95      ])],
#  [array([0.26700586, 0.32254514, 0.33      ]),
#   array([1.2516445 , 0.32254514, 0.55      ])],
#  [array([0.01773995, 0.54894971, 0.1       ]),
#   array([0.81766165, 0.54894971, 0.37      ])],
#  [array([0.02534134, 7.80162021, 0.32      ]),
#   array([9.82594976e-01, 1.00000000e+04, 2.20000000e-01])],
#  [array([0.00747897, 0.16158148, 0.45      ]),
#   array([0.75772414, 0.16158148, 0.22      ])],
#  [array([0.22106588, 0.2407531 , 0.52      ]),
#   array([1.19291055, 0.2407531 , 0.15      ])],
#  [array([0.0184316, 0.1240481, 0.45     ]),
#   array([0.93476677, 0.14161519, 0.3       ])],
#  [array([0.08490444, 0.25307209, 0.52      ]),
#   array([1.07684169, 0.25307209, 0.15      ])],
#  [array([0.01880379, 0.15427367, 0.89      ]),
#   array([0.80230829, 0.18241559, 0.85      ])],
#  [array([0.17712019, 0.1158331 , 0.13      ]),
#   array([1.12891713, 0.13100818, 0.25      ])],
#  [array([0.02781359, 0.95014377, 0.34      ]),
#   array([ 0.82586873, 19.05767377,  0.39      ])],
#  [array([0.03531555, 0.10121398, 0.02      ]),
#   array([1.01280782, 0.11261187, 0.39      ])],
#  [array([0.13158991, 0.17367592, 0.38      ]),
#   array([1.10710645, 0.21017895, 0.46      ])],
#  [array([0.04602556, 0.74848358, 0.1       ]),
#   array([1.02447091, 2.97588352, 0.1       ])],
#  [array([0.02521269, 0.40762705, 0.08      ]),
#   array([0.86005456, 0.6881257 , 0.18      ])],
#  [array([1.94118538e-01, 1.00000000e+04, 4.70000000e-01]),
#   array([1.24953723e+00, 1.00000000e+04, 4.60000000e-01])],
#  [array([0.24258762, 0.3091179 , 0.3       ]),
#   array([1.09201726, 0.44742496, 0.33      ])],
#  [array([0.01961871, 0.82533674, 0.06      ]),
#   array([0.83580821, 0.82533674, 0.37      ])],
#  [array([0.02795562, 0.46281313, 0.18      ]),
#   array([0.83716214, 0.46281313, 0.46      ])],
#  [array([0.17113661, 0.66350391, 0.39      ]),
#   array([1.32744499, 0.66350391, 0.38      ])],
#  [array([0.13256989, 0.17333924, 0.79      ]),
#   array([0.92350291, 0.17333924, 0.49      ])],
#  [array([0.04637429, 0.42921895, 0.12      ]),
#   array([0.97637401, 0.42921895, 0.22      ])],
#  [array([0.01884845, 0.11909598, 0.17      ]),
#   array([0.89090348, 0.13519745, 0.2       ])],
#  [array([0.04876633, 0.17480563, 0.26      ]),
#   array([0.9909437, 0.2118357, 0.89     ])],
#  [array([0.00844835, 0.34283557, 0.19      ]),
#   array([0.82200716, 0.52168918, 0.07      ])],
#  [array([0.16091654, 1.42233384, 0.21      ]),
#   array([1.07970635, 1.42233384, 0.22      ])],
#  [array([0.04159576, 0.57783205, 0.27      ]),
#   array([1.06423253, 1.36872555, 0.13      ])],
#  [array([1.57637254e-01, 1.59031409e+02, 6.00000000e-02]),
#   array([  0.93317286, 159.03140926,   0.44      ])],
#  [array([9.80463201e-02, 1.00000000e+04, 1.70000000e-01]),
#   array([1.08562627e+00, 1.00000000e+04, 1.30000000e-01])],
#  [array([0.34494491, 0.21350288, 0.3       ]),
#   array([1.10502294, 0.27146047, 0.85      ])],
#  [array([0.04457181, 0.1777886 , 0.86      ]),
#   array([0.86095228, 0.21623223, 0.16      ])],
#  [array([0.00906495, 0.15911921, 0.6       ]),
#   array([0.79413743, 0.18922922, 0.15      ])],
#  [array([0.26523694, 3.51952162, 0.02      ]),
#   array([1.16038679, 3.51952162, 0.38      ])],
#  [array([0.20874756, 0.2591267 , 0.37      ]),
#   array([0.93967407, 0.2591267 , 0.49      ])],
#  [array([0.02892934, 0.11487544, 0.16      ]),
#   array([0.93652023, 0.11487544, 0.28      ])],
#  [array([ 0.05827295, 10.00781604,  0.17      ]),
#   array([ 1.38495155, 10.00781604,  0.47      ])],
#  [array([0.01895565, 0.21234834, 0.47      ]),
#   array([0.80485683, 0.26959677, 0.25      ])],
#  [array([0.14151296, 0.11831752, 0.38      ]),
#   array([1.16128506, 0.13419516, 0.48      ])],
#  [array([0.01255612, 0.46154306, 0.5       ]),
#   array([0.80162919, 0.46154306, 0.47      ])],
#  [array([0.01177072, 0.33636508, 0.06      ]),
#   array([0.80192369, 0.50685259, 0.07      ])],
#  [array([0.0263471 , 0.14441094, 0.86      ]),
#   array([0.83409982, 0.1687854 , 0.16      ])],
#  [array([0.05788165, 0.36463225, 0.39      ]),
#   array([1.12381839, 0.36463225, 0.31      ])],
#  [array([ 0.1905403 , 46.20770373,  0.49      ]),
#   array([ 1.22753011, 46.20770373,  0.22      ])],
#  [array([0.23747713, 0.88426138, 0.33      ]),
#   array([1.3664776 , 0.88426138, 0.13      ])],
#  [array([0.07022055, 0.22120898, 0.97      ]),
#   array([1.10388167, 0.22120898, 0.31      ])],
#  [array([0.10701056, 0.2586855 , 0.97      ]),
#   array([1.28122453, 0.2586855 , 0.24      ])],
#  [array([0.18956722, 0.37225998, 0.74      ]),
#   array([1.21736602, 0.37225998, 0.89      ])],
#  [array([5.67071432e-02, 1.00000000e+04, 1.00000000e-02]),
#   array([8.72186357e-01, 1.00000000e+04, 1.80000000e-01])],
#  [array([0.04059879, 0.18318896, 0.11      ]),
#   array([0.89251259, 0.22427336, 0.46      ])],
#  [array([0.03896091, 0.21202074, 0.95      ]),
#   array([0.90684315, 0.21202074, 0.15      ])],
#  [array([0.03484259, 0.17854913, 0.32      ]),
#   array([0.92869761, 0.21735826, 0.69      ])],
#  [array([0.01129886, 0.1012595 , 0.27      ]),
#   array([0.77439884, 0.11266823, 0.25      ])],
#  [array([0.00430947, 0.13821378, 0.02      ]),
#   array([0.75931669, 0.16038059, 0.39      ])],
#  [array([0.03198541, 0.15076645, 0.34      ]),
#   array([0.96811583, 0.15076645, 0.23      ])],
#  [array([0.00780658, 0.14271347, 0.5       ]),
#   array([0.80137913, 0.14271347, 0.03      ])],
#  [array([0.16136345, 0.11523042, 0.44      ]),
#   array([1.04908198, 0.11523042, 0.28      ])],
#  [array([1.42228312e-02, 1.00000000e+04, 1.80000000e-01]),
#   array([8.35824848e-01, 1.00000000e+04, 1.30000000e-01])],
#  [array([0.09444108, 0.19482892, 0.57      ]),
#   array([1.16110488, 0.19482892, 0.31      ])],
#  [array([0.06474505, 0.22480651, 0.49      ]),
#   array([1.02789575, 0.22480651, 0.25      ])],
#  [array([0.0836765 , 0.13987059, 0.15      ]),
#   array([1.1543476 , 0.13987059, 0.06      ])],
#  [array([0.0396471, 1.0366315, 0.1      ]),
#   array([0.89202339, 1.0366315 , 0.37      ])],
#  [array([0.05216153, 0.13888193, 0.11      ]),
#   array([1.01888056, 0.13888193, 0.3       ])],
#  [array([0.21817052, 0.64939996, 0.46      ]),
#   array([1.0810508 , 0.64939996, 0.44      ])],
#  [array([0.03118099, 0.38591186, 0.42      ]),
#   array([1.29468869, 0.38591186, 0.06      ])],
#  [array([0.10149751, 0.19103456, 0.93      ]),
#   array([1.02188866, 0.23614674, 0.69      ])],
#  [array([3.54595676e-02, 1.00000000e+04, 1.00000000e-01]),
#   array([8.92349059e-01, 1.00000000e+04, 4.40000000e-01])],
#  [array([0.05863986, 0.1881351 , 0.75      ]),
#   array([1.05278999, 0.1881351 , 0.24      ])],
#  [array([0.13915691, 0.23712171, 0.33      ]),
#   array([1.07025617, 0.23712171, 0.55      ])],
#  [array([0.04381872, 1.24842738, 0.2       ]),
#   array([1.12175808, 1.24842738, 0.41      ])],
#  [array([0.23710892, 0.44959626, 0.1       ]),
#   array([1.36858123, 0.44959626, 0.29      ])],
#  [array([0.03301912, 1.45487987, 0.26      ]),
#   array([0.84618641, 1.45487987, 0.48      ])],
#  [array([0.00608832, 0.28848788, 0.02      ]),
#   array([1.08933888, 0.28848788, 0.65      ])],
#  [array([0.08746255, 0.68227592, 0.11      ]),
#   array([1.22499211, 0.68227592, 0.44      ])],
#  [array([0.01445385, 0.16573819, 0.08      ]),
#   array([0.81459777, 0.16573819, 0.3       ])],
#  [array([0.08625039, 0.33333037, 0.05      ]),
#   array([1.14034812, 0.33333037, 0.35      ])],
#  [array([0.01709103, 0.64956261, 0.22      ]),
#   array([0.94658454, 1.85357681, 0.47      ])],
#  [array([0.12035586, 1.5894453 , 0.27      ]),
#   array([1.28490459, 1.5894453 , 0.47      ])],
#  [array([0.0104328 , 0.12988599, 0.11      ]),
#   array([0.89216979, 0.12988599, 0.25      ])],
#  [array([0.16496419, 0.23563329, 0.84      ]),
#   array([1.32247376, 0.23563329, 0.2       ])],
#  [array([0.04521032, 0.17858021, 0.7       ]),
#   array([1.02992891, 0.17858021, 0.69      ])],
#  [array([0.04694734, 0.19531901, 0.02      ]),
#   array([0.99074499, 0.19531901, 0.65      ])],
#  [array([0.01379253, 0.16913156, 0.95      ]),
#   array([0.9487655 , 0.20355998, 0.69      ])],
#  [array([0.01380662, 0.33324775, 0.88      ]),
#   array([0.80730642, 0.33324775, 0.35      ])],
#  [array([0.04309629, 0.87590806, 0.14      ]),
#   array([1.21147484, 0.87590806, 0.1       ])],
#  [array([0.04475959, 0.10458788, 0.41      ]),
#   array([0.80501388, 0.11680418, 0.06      ])],
#  [array([0.07418876, 1.05952884, 0.35      ]),
#   array([0.95981842, 1.05952884, 0.13      ])],
#  [array([0.16984345, 0.12024777, 0.39      ]),
#   array([0.91089999, 0.12024777, 0.27      ])],
#  [array([0.20812322, 0.12626085, 0.36      ]),
#   array([1.03053713, 0.14450635, 0.06      ])],
#  [array([2.79374339e-01, 1.00000000e+04, 1.60000000e-01]),
#   array([1.2527268e+00, 1.0000000e+04, 4.1000000e-01])],
#  [array([0.23985996, 0.13524963, 0.26      ]),
#   array([1.3230656 , 0.13524963, 0.13      ])],
#  [array([0.02981755, 0.12802166, 0.06      ]),
#   array([0.82153677, 0.14681748, 0.36      ])],
#  [array([0.13243788, 0.20552932, 0.13      ]),
#   array([1.20469983, 0.20552932, 0.35      ])],
#  [array([0.05277299, 0.33317289, 0.78      ]),
#   array([0.83266304, 0.33317289, 0.85      ])],
#  [array([0.30985171, 0.15224153, 0.2       ]),
#   array([1.27207725, 0.15224153, 0.3       ])],
#  [array([0.02822046, 0.28197706, 0.24      ]),
#   array([0.83115988, 0.39271316, 0.37      ])],
#  [array([1.07309941e-01, 1.00000000e+04, 1.20000000e-01]),
#   array([9.02455647e-01, 1.00000000e+04, 3.70000000e-01])],
#  [array([0.02026448, 0.15103166, 0.08      ]),
#   array([0.92978951, 0.17790022, 0.46      ])],
#  [array([0.02988861, 0.34698213, 0.04      ]),
#   array([0.85738865, 0.34698213, 0.89      ])],
#  [array([0.01997631, 0.20053359, 0.43      ]),
#   array([0.79639325, 0.25083429, 0.2       ])],
#  [array([0.1903233 , 0.24432714, 0.15      ]),
#   array([1.05240273, 0.24432714, 0.49      ])],
#  [array([0.02048443, 0.19542302, 0.92      ]),
#   array([0.84868913, 0.19542302, 0.86      ])],
#  [array([0.0224506 , 0.18628978, 0.07      ]),
#   array([0.87907305, 0.22893872, 0.89      ])],
#  [array([6.20204619e-03, 7.66194418e+01, 3.10000000e-01]),
#   array([ 0.76309839, 76.61944183,  0.37      ])],
#  [array([4.82945781e-02, 1.00000000e+04, 2.40000000e-01]),
#   array([1.11375514e+00, 1.00000000e+04, 3.70000000e-01])],
#  [array([0.01371507, 0.13336296, 0.39      ]),
#   array([0.76994658, 0.13336296, 0.39      ])],
#  [array([0.06367751, 0.15858343, 0.09      ]),
#   array([1.04006513, 0.18847196, 0.85      ])],
#  [array([0.14067042, 0.21385335, 0.12      ]),
#   array([1.0626171 , 0.21385335, 0.15      ])],
#  [array([0.09395714, 2.38021472, 0.23      ]),
#   array([0.99838427, 2.38021472, 0.29      ])],
#  [array([0.22426843, 1.55544218, 0.05      ]),
#   array([1.09446988e+00, 1.00000000e+04, 1.00000000e-01])],
#  [array([1.24092337e-01, 1.00000000e+04, 1.10000000e-01]),
#   array([1.29822262e+00, 1.00000000e+04, 4.40000000e-01])],
#  [array([0.03817109, 0.11967211, 0.44      ]),
#   array([0.99197867, 0.13594038, 0.23      ])],
#  [array([0.01358106, 0.33168305, 0.75      ]),
#   array([0.81204302, 0.49629604, 0.06      ])],
#  [array([0.06001164, 0.26773643, 0.49      ]),
#   array([0.90425949, 0.26773643, 0.25      ])],
#  [array([0.01251834, 0.16472966, 0.4       ]),
#   array([0.79986008, 0.19721717, 0.85      ])],
#  [array([0.08178058, 0.57669527, 0.35      ]),
#   array([0.96007609, 0.57669527, 0.31      ])],
#  [array([0.02319214, 0.33107774, 0.27      ]),
#   array([0.78790745, 0.33107774, 0.85      ])],
#  [array([0.04388406, 1.65783519, 0.16      ]),
#   array([1.08126038, 1.65783519, 0.41      ])],
#  [array([0.01721917, 0.11891054, 0.4       ]),
#   array([1.14356521, 0.11891054, 0.25      ])],
#  [array([0.18154616, 0.16052166, 0.38      ]),
#   array([1.14962359, 0.16052166, 0.36      ])],
#  [array([0.06095992, 0.13131792, 0.2       ]),
#   array([1.03463998, 0.13131792, 0.37      ])],
#  [array([0.01354476, 1.45860401, 0.47      ]),
#   array([0.90103963, 0.59326512, 0.44      ])],
#  [array([0.0894925 , 0.78058785, 0.06      ]),
#   array([0.98058303, 0.78058785, 0.44      ])],
#  [array([0.07214058, 0.1765127 , 0.33      ]),
#   array([0.90736434, 0.1765127 , 0.05      ])],
#  [array([1.25912599e-01, 1.00000000e+04, 4.20000000e-01]),
#   array([1.10506047e+00, 1.00000000e+04, 4.80000000e-01])],
#  [array([0.02422548, 0.26441098, 0.91      ]),
#   array([0.90879848, 0.26441098, 0.55      ])],
#  [array([0.02072299, 1.3233835 , 0.24      ]),
#   array([0.91027501, 1.3233835 , 0.31      ])],
#  [array([7.48809124e-03, 1.00000000e+04, 3.20000000e-01]),
#   array([7.85253213e-01, 1.00000000e+04, 1.80000000e-01])],
#  [array([3.07987902e-02, 1.00000000e+04, 8.00000000e-02]),
#   array([9.1320124e-01, 1.0000000e+04, 1.3000000e-01])],
#  [array([0.02425883, 0.26464705, 0.81      ]),
#   array([0.80902195, 0.26464705, 0.25      ])],
#  [array([0.00952983, 0.3761738 , 0.24      ]),
#   array([0.76771424, 0.60301058, 0.07      ])],
#  [array([0.17835925, 0.13887889, 0.5       ]),
#   array([1.3175305 , 0.13887889, 0.27      ])],
#  [array([0.03314516, 0.98047351, 0.42      ]),
#   array([ 1.03970439, 50.21248721,  0.13      ])],
#  [array([0.01271676, 0.1607403 , 0.71      ]),
#   array([0.80132761, 0.19152629, 0.46      ])],
#  [array([0.05729908, 0.27030959, 0.05      ]),
#   array([1.16813801, 0.27030959, 0.35      ])],
#  [array([0.00765444, 0.12277658, 0.34      ]),
#   array([0.83711766, 0.13996044, 0.3       ])],
#  [array([0.05653928, 0.13460468, 0.4       ]),
#   array([1.11818772, 0.13460468, 0.28      ])],
#  [array([0.18528743, 0.14989129, 0.4       ]),
#   array([1.14647173, 0.14989129, 0.23      ])],
#  [array([0.00532073, 0.13614372, 0.09      ]),
#   array([0.81360316, 0.15759997, 0.28      ])],
#  [array([0.06329228, 0.11660628, 0.38      ]),
#   array([0.86530464, 0.13199809, 0.39      ])],
#  [array([0.04746555, 0.10661995, 0.5       ]),
#   array([0.94721547, 0.11934445, 0.23      ])],
#  [array([0.02051531, 0.25283729, 0.08      ]),
#   array([0.83895652, 0.25283729, 0.46      ])],
#  [array([0.0114584 , 0.12487694, 0.22      ]),
#   array([0.93898743, 0.14269644, 0.03      ])],
#  [array([0.04969029, 0.48762143, 0.03      ]),
#   array([0.80687604, 0.95168192, 0.48      ])],
#  [array([2.25598076e-02, 1.00000000e+04, 2.50000000e-01]),
#   array([9.79196803e-01, 1.00000000e+04, 4.80000000e-01])],
#  [array([0.13289445, 0.47129991, 0.59      ]),
#   array([1.20343243, 0.47129991, 0.55      ])],
#  [array([0.29070487, 0.11143562, 0.02      ]),
#   array([1.0786648 , 0.11143562, 0.25      ])],
#  [array([0.19715519, 0.30407433, 0.83      ]),
#   array([1.0767874 , 0.30407433, 0.85      ])],
#  [array([0.07183997, 0.44274093, 0.24      ]),
#   array([1.05660694, 0.44274093, 0.37      ])],
#  [array([0.04982166, 0.19450501, 0.49      ]),
#   array([1.02443485, 0.19450501, 0.35      ])],
#  [array([0.10544542, 0.12666942, 0.02      ]),
#   array([1.14108984, 0.12666942, 0.39      ])],
#  [array([0.15202893, 0.86114503, 0.35      ]),
#   array([1.05346213, 0.86114503, 0.13      ])],
#  [array([0.01998916, 0.52838165, 0.28      ]),
#   array([0.84788833, 0.52838165, 0.25      ])],
#  [array([0.00786099, 0.15862571, 0.19      ]),
#   array([0.80717264, 0.18853169, 0.13      ])],
#  [array([0.01536438, 0.11321217, 0.27      ]),
#   array([0.84069175, 0.12766546, 0.39      ])],
#  [array([0.18282073, 0.2673225 , 0.75      ]),
#   array([1.2639235, 0.2673225, 0.24     ])],
#  [array([0.01804314, 0.40296294, 0.27      ]),
#   array([0.78478473, 0.40296294, 0.1       ])],
#  [array([0.08422425, 0.19676155, 0.06      ]),
#   array([1.0215405 , 0.24496033, 0.25      ])],
#  [array([0.01666466, 0.11845353, 0.23      ]),
#   array([0.95267926, 0.13437015, 0.25      ])],
#  [array([0.05756001, 0.18594298, 0.95      ]),
#   array([0.89845946, 0.18594298, 0.15      ])],
#  [array([0.06614564, 0.30010195, 0.3       ]),
#   array([0.97583213, 0.42877951, 0.33      ])],
#  [array([0.06408154, 0.25765563, 0.21      ]),
#   array([1.12101127, 0.25765563, 0.85      ])],
#  [array([0.10708575, 0.16167541, 0.26      ]),
#   array([1.10765841, 0.16167541, 0.13      ])],
#  [array([0.01574267, 0.12700546, 0.15      ]),
#   array([1.23013864, 0.12700546, 0.06      ])],
#  [array([0.01846323, 0.310407  , 0.34      ]),
#   array([0.81817439, 0.45013073, 0.29      ])],
#  [array([0.04216703, 0.22246674, 0.12      ]),
#   array([1.27378289, 0.22246674, 0.25      ])],
#  [array([0.14096394, 0.19954532, 0.83      ]),
#   array([0.96989821, 0.19954532, 0.85      ])],
#  [array([0.01276924, 0.16188238, 0.46      ]),
#   array([0.81089188, 0.16188238, 0.13      ])],
#  [array([0.01352721, 0.1029509 , 0.13      ]),
#   array([0.81079477, 0.11476618, 0.25      ])],
#  [array([0.09464522, 0.13644337, 0.23      ]),
#   array([1.19227488, 0.13644337, 0.39      ])],
#  [array([0.03319163, 1.06996337, 0.24      ]),
#   array([8.49661516e-01, 1.00000000e+04, 3.70000000e-01])],
# ...
#  [array([0.21649652, 0.83052194, 0.05      ]),
#   array([1.14078837, 4.90046879, 0.1       ])],
#  [array([0.02531438, 0.11424417, 0.22      ]),
#   array([0.84343158, 0.1289793 , 0.37      ])],
#  [array([0.363536 , 0.1347177, 0.02     ]),
#   array([1.08683143, 0.1556922 , 0.39      ])],
#  [array([0.11738838, 0.21908542, 0.39      ]),
#   array([0.85838038, 0.21908542, 0.55      ])],
#  [array([0.03250887, 0.45191797, 0.37      ]),
#   array([0.94781213, 0.82454441, 0.1       ])],
#  [array([0.0570109 , 0.37379757, 0.17      ]),
#   array([1.36096372, 0.37379757, 0.47      ])],
#  [array([0.0392838 , 1.04664706, 0.04      ]),
#   array([8.12063096e-01, 1.00000000e+04, 1.00000000e-01])],
#  [array([0.13283538, 0.1170637 , 0.4       ]),
#   array([1.03960424, 0.1170637 , 0.23      ])],
#  [array([0.21170903, 5.76546261, 0.48      ]),
#   array([1.2948084 , 5.76546261, 0.29      ])],
#  [array([0.01362274, 0.15308806, 0.33      ]),
#   array([0.78633717, 0.15308806, 0.25      ])],
#  [array([0.11896634, 0.13589759, 0.11      ]),
#   array([1.2442694 , 0.13589759, 0.25      ])],
#  [array([0.02150993, 0.85978035, 0.12      ]),
#   array([0.97373912, 0.85978035, 0.22      ])],
#  [array([0.21727548, 0.12196966, 0.02      ]),
#   array([1.18696922, 0.13891281, 0.39      ])],
#  [array([0.06858046, 0.18919029, 0.12      ]),
#   array([1.05586976, 0.18919029, 0.16      ])],
#  [array([0.09860402, 0.75138385, 0.17      ]),
#   array([1.14586651, 0.75138385, 0.13      ])],
#  [array([5.69452951e-02, 1.00000000e+04, 4.90000000e-01]),
#   array([1.30622905e+00, 1.00000000e+04, 4.70000000e-01])],
#  [array([0.13768163, 0.15413692, 0.21      ]),
#   array([1.18326455, 0.15413692, 0.06      ])],
#  [array([0.03910558, 0.29530807, 0.68      ]),
#   array([1.21249251, 0.29530807, 0.85      ])],
#  [array([0.20537069, 0.3752421 , 0.33      ]),
#   array([0.99991044, 0.3752421 , 0.55      ])],
#  [array([0.29193481, 0.92585602, 0.35      ]),
#   array([ 1.15540242, 12.48727156,  0.22      ])],
#  [array([1.95555278e-01, 1.00000000e+04, 2.50000000e-01]),
#   array([1.22060516e+00, 1.00000000e+04, 3.30000000e-01])],
#  [array([1.22549352e-01, 1.00000000e+04, 3.50000000e-01]),
#   array([1.00530294e+00, 1.00000000e+04, 1.30000000e-01])],
#  [array([0.04102946, 0.19175569, 0.37      ]),
#   array([1.1165274 , 0.19175569, 0.46      ])],
#  [array([0.1576536 , 0.13518346, 0.02      ]),
#   array([1.13504808, 0.15631461, 0.39      ])],
#  [array([0.13404709, 0.19266363, 0.35      ]),
#   array([1.12233961, 0.19266363, 0.85      ])],
#  [array([0.12911083, 0.37423295, 0.24      ]),
#   array([0.86213295, 0.37423295, 0.39      ])],
#  [array([0.09766026, 0.39719797, 0.02      ]),
#   array([0.86707175, 0.65891942, 0.33      ])],
#  [array([0.0215255 , 0.26518771, 0.72      ]),
#   array([0.89511904, 0.36089177, 0.46      ])],
#  [array([0.03802275, 0.11384041, 0.23      ]),
#   array([0.91153151, 0.1284649 , 0.25      ])],
#  [array([0.14923547, 0.17252125, 0.38      ]),
#   array([1.10328662, 0.20849024, 0.46      ])],
#  [array([0.04686152, 1.3560081 , 0.14      ]),
#   array([1.00031595, 1.3560081 , 0.38      ])],
#  [array([1.09204722e-02, 1.00000000e+04, 2.10000000e-01]),
#   array([7.65901834e-01, 1.00000000e+04, 1.30000000e-01])],
#  [array([0.13193703, 0.36727071, 0.34      ]),
#   array([1.16944176, 0.36727071, 0.33      ])],
#  [array([0.02361293, 0.13130172, 0.32      ]),
#   array([0.85780273, 0.13130172, 0.36      ])],
#  [array([0.36504493, 0.91721971, 0.46      ]),
#   array([1.10505805, 0.91721971, 0.44      ])],
#  [array([0.13326727, 0.19345035, 0.75      ]),
#   array([1.09100075, 0.19345035, 0.24      ])],
#  [array([0.11472084, 0.27628208, 0.49      ]),
#   array([0.8850576 , 0.27628208, 0.31      ])],
#  [array([0.00629289, 0.23685822, 0.54      ]),
#   array([0.77503846, 0.23685822, 0.46      ])],
#  [array([0.04181925, 0.38840265, 0.35      ]),
#   array([0.95563615, 0.63506267, 0.22      ])],
#  [array([0.10336379, 2.84216566, 0.17      ]),
#   array([1.06049181e+00, 1.00000000e+04, 4.80000000e-01])],
#  [array([0.07828792, 0.11637742, 0.08      ]),
#   array([1.29375588, 0.11637742, 0.13      ])],
#  [array([0.17927532, 0.86251961, 0.17      ]),
#   array([1.15558196, 0.86251961, 0.13      ])],
#  [array([0.00577592, 0.11984592, 0.34      ]),
#   array([0.77343732, 0.1361647 , 0.25      ])],
#  [array([0.06537512, 0.73923024, 0.32      ]),
#   array([1.0337473 , 0.73923024, 0.18      ])],
#  [array([0.04675634, 1.4786544 , 0.48      ]),
#   array([1.13314257, 1.4786544 , 0.29      ])],
#  [array([0.00634644, 0.19451432, 0.01      ]),
#   array([0.83609834, 0.19451432, 0.46      ])],
#  [array([0.02361414, 0.11268204, 0.07      ]),
#   array([0.81843577, 0.12699173, 0.25      ])],
#  [array([2.64924686e-02, 1.00000000e+04, 7.00000000e-02]),
#   array([7.82398091e-01, 1.00000000e+04, 2.90000000e-01])],
#  [array([0.16233142, 0.75985407, 0.14      ]),
#   array([1.31972459, 0.75985407, 0.1       ])],
#  [array([0.00926439, 0.36076137, 0.38      ]),
#   array([0.77464664, 0.56436104, 0.46      ])],
#  [array([0.06058168, 0.41898685, 0.05      ]),
#   array([0.97987493, 0.41898685, 0.13      ])],
#  [array([0.07030971, 0.17503163, 0.89      ]),
#   array([1.02711608, 0.17503163, 0.2       ])],
#  [array([0.0268295 , 0.20885743, 0.32      ]),
#   array([0.87601086, 0.20885743, 0.16      ])],
#  [array([0.10108071, 0.11703408, 0.08      ]),
#   array([0.93806567, 0.13254654, 0.23      ])],
#  [array([0.02837782, 0.10708728, 0.18      ]),
#   array([0.91142308, 0.11993029, 0.13      ])],
#  [array([0.17343919, 4.4602258 , 0.11      ]),
#   array([1.34144723, 4.4602258 , 0.44      ])],
#  [array([0.23186781, 0.16535129, 0.11      ]),
#   array([1.19513988, 0.16535129, 0.25      ])],
#  [array([0.0051435 , 0.21869405, 0.51      ]),
#   array([0.77088928, 0.27990834, 0.06      ])],
#  [array([0.14631196, 0.14983186, 0.27      ]),
#   array([1.30205606, 0.14983186, 0.23      ])],
#  [array([0.1315411 , 0.28365923, 0.12      ]),
#   array([1.21891812, 0.28365923, 0.69      ])],
#  [array([0.00863978, 0.43584111, 0.03      ]),
#   array([0.82094059, 0.43584111, 0.33      ])],
#  [array([2.23131726e-02, 1.00000000e+04, 1.40000000e-01]),
#   array([9.54664134e-01, 1.00000000e+04, 1.80000000e-01])],
#  [array([0.32993025, 0.66542183, 0.17      ]),
#   array([1.09073611, 1.98883816, 0.48      ])],
#  [array([0.27077184, 0.1130605 , 0.4       ]),
#   array([1.33460554, 0.1130605 , 0.28      ])],
#  [array([0.00644987, 0.2990353 , 0.23      ]),
#   array([0.8176792, 0.2990353, 0.06     ])],
#  [array([0.01977156, 0.11204078, 0.4       ]),
#   array([0.8204555 , 0.12617784, 0.23      ])],
#  [array([0.2512663, 0.6626012, 0.32     ]),
#   array([1.25212856, 0.6626012 , 0.39      ])],
#  [array([0.21476837, 5.03832916, 0.35      ]),
#   array([1.01691005e+00, 1.00000000e+04, 2.20000000e-01])],
#  [array([0.246841  , 0.13176936, 0.02      ]),
#   array([1.03237847, 0.1517677 , 0.39      ])],
#  [array([0.22008762, 0.33217709, 0.89      ]),
#   array([1.09411942, 0.33217709, 0.16      ])],
#  [array([0.04888507, 0.17440035, 0.35      ]),
#   array([0.98530848, 0.17440035, 0.15      ])],
#  [array([0.28581189, 0.16074724, 0.38      ]),
#   array([1.22925365, 0.19153615, 0.35      ])],
#  [array([0.04285054, 0.1313216 , 0.41      ]),
#   array([0.910212  , 0.15117402, 0.05      ])],
#  [array([0.11154412, 0.58473747, 0.36      ]),
#   array([0.84015696, 1.4081152 , 0.1       ])],
#  [array([0.05101199, 0.1553044 , 0.72      ]),
#   array([1.08555182, 0.18385842, 0.16      ])],
#  [array([0.01753398, 0.11891978, 0.2       ]),
#   array([1.02548302, 0.13497043, 0.22      ])],
#  [array([1.3941618e-01, 1.0000000e+04, 2.4000000e-01]),
#   array([8.5909554e-01, 1.0000000e+04, 3.9000000e-01])],
#  [array([0.02404356, 0.14782974, 0.17      ]),
#   array([0.90403739, 0.17347442, 0.2       ])],
#  [array([0.23589098, 0.13372294, 0.43      ]),
#   array([1.12547853, 0.1543651 , 0.2       ])],
#  [array([0.0414489 , 0.17469697, 0.75      ]),
#   array([0.89675691, 0.21167616, 0.15      ])],
#  [array([0.06948363, 1.13007882, 0.1       ]),
#   array([8.255626e-01, 1.000000e+04, 1.300000e-01])],
#  [array([0.0177344 , 0.59829375, 0.28      ]),
#   array([0.84841932, 0.59829375, 0.13      ])],
#  [array([0.05561569, 0.47661677, 0.1       ]),
#   array([1.06744116, 0.47661677, 0.55      ])],
#  [array([0.08420236, 0.12502314, 0.38      ]),
#   array([1.1273591 , 0.12502314, 0.2       ])],
#  [array([0.02574451, 0.20391015, 0.52      ]),
#   array([0.91076791, 0.25613961, 0.25      ])],
#  [array([0.00168946, 0.29001339, 0.47      ]),
#   array([0.78658437, 0.40847727, 0.46      ])],
#  [array([0.08695793, 3.10739811, 0.32      ]),
#   array([0.96013648, 3.10739811, 0.18      ])],
#  [array([0.29363236, 0.2810076 , 0.14      ]),
#   array([1.2862191, 0.2810076, 0.89     ])],
#  [array([0.01813839, 0.26397748, 0.59      ]),
#   array([0.94719725, 0.26397748, 0.31      ])],
#  [array([0.00774026, 0.14972976, 0.1       ]),
#   array([0.88014435, 0.14972976, 0.05      ])],
#  [array([0.08590255, 0.27896607, 0.57      ]),
#   array([1.21752627, 0.27896607, 0.49      ])],
#  [array([0.09372603, 0.16666796, 0.38      ]),
#   array([1.05126762, 0.20000186, 0.35      ])],
#  [array([0.06017935, 0.11006462, 0.35      ]),
#   array([0.80334414, 0.1236771 , 0.23      ])],
#  [array([0.02717467, 0.14547006, 0.93      ]),
#   array([0.97559667, 0.17023401, 0.69      ])],
#  [array([0.08579801, 1.18613884, 0.05      ]),
#   array([0.90188334, 1.18613884, 0.13      ])],
#  [array([0.08025268, 3.18530401, 0.42      ]),
#   array([1.30702223, 3.18530401, 0.22      ])],
#  [array([1.80823425e-01, 1.00000000e+04, 1.90000000e-01]),
#   array([1.3424505e+00, 1.0000000e+04, 2.9000000e-01])],
#  [array([0.00414249, 0.20645597, 0.21      ]),
#   array([0.7868173 , 0.26016952, 0.35      ])],
#  [array([0.23791462, 0.17057236, 0.13      ]),
#   array([1.29082094, 0.17057236, 0.35      ])],
#  [array([0.02229019, 0.12118047, 0.38      ]),
#   array([1.04361442, 0.12118047, 0.36      ])],
#  [array([0.20887513, 0.25839562, 0.08      ]),
#   array([1.06711753, 0.25839562, 0.2       ])],
#  [array([0.09662057, 0.11869343, 0.44      ]),
#   array([0.90573396, 0.11869343, 0.28      ])],
#  [array([1.76043583e-01, 1.00000000e+04, 2.40000000e-01]),
#   array([8.88425199e-01, 1.00000000e+04, 3.30000000e-01])],
#  [array([0.11401584, 0.16817134, 0.15      ]),
#   array([1.12857706, 0.16817134, 0.49      ])],
#  [array([0.16561695, 0.18591098, 0.68      ]),
#   array([1.21494978, 0.18591098, 0.85      ])],
#  [array([0.00451506, 0.33376669, 0.6       ]),
#   array([0.96731534, 0.33376669, 0.89      ])],
#  [array([3.55880247e-03, 1.00000000e+04, 2.00000000e-01]),
#   array([7.59446082e-01, 1.00000000e+04, 1.80000000e-01])],
#  [array([0.11939092, 0.16511451, 0.34      ]),
#   array([1.33008616, 0.16511451, 0.25      ])],
#  [array([0.09536468, 0.26474443, 0.02      ]),
#   array([0.87429142, 0.3600713 , 0.33      ])],
#  [array([0.02118461, 0.40466751, 0.16      ]),
#   array([0.870778  , 0.40466751, 0.38      ])],
#  [array([0.01637676, 0.30709113, 0.09      ]),
#   array([0.96556857, 0.30709113, 0.31      ])],
#  [array([0.0586388 , 0.39207122, 0.42      ]),
#   array([0.92863376, 0.64492954, 0.41      ])],
#  [array([0.00438844, 0.71498918, 0.28      ]),
#   array([0.77420984, 2.50863877, 0.25      ])],
#  [array([0.02288542, 0.56657668, 0.01      ]),
#   array([0.87251555, 0.56657668, 0.18      ])],
#  [array([0.01134526, 0.14696053, 0.46      ]),
#   array([0.7743932, 0.1722787, 0.2      ])],
#  [array([0.04678302, 0.22453333, 0.41      ]),
#   array([1.19445678, 0.22453333, 0.95      ])],
#  [array([0.01033709, 0.10363478, 0.06      ]),
#   array([0.94895599, 0.1156167 , 0.23      ])],
#  [array([0.0494746 , 0.11614851, 0.14      ]),
#   array([0.90173572, 0.13141179, 0.48      ])],
#  [array([0.04238392, 0.96000308, 0.14      ]),
#   array([1.21313957, 0.96000308, 0.1       ])],
#  [array([0.33942156, 0.13680016, 0.34      ]),
#   array([1.05485857, 0.13680016, 0.39      ])],
#  [array([0.18827653, 0.11232857, 0.26      ]),
#   array([1.27095315, 0.11232857, 0.13      ])],
#  [array([0.19261643, 0.15577834, 0.4       ]),
#   array([1.06492723, 0.15577834, 0.23      ])],
#  [array([0.2135854 , 0.11337606, 0.19      ]),
#   array([0.98817896, 0.11337606, 0.28      ])],
#  [array([0.2024478 , 0.81253029, 0.32      ]),
#   array([1.11715454, 0.81253029, 0.39      ])],
#  [array([2.11112366e-02, 1.00000000e+04, 8.00000000e-02]),
#   array([9.16817002e-01, 1.00000000e+04, 1.30000000e-01])],
#  [array([0.00699959, 0.38607473, 0.44      ]),
#   array([0.76948046, 0.62886276, 0.47      ])],
#  [array([0.10641627, 0.12407285, 0.36      ]),
#   array([0.97464135, 0.14164745, 0.06      ])],
#  [array([0.00582312, 0.21994193, 0.13      ]),
#   array([0.75994993, 0.28195584, 0.86      ])],
#  [array([0.11694273, 0.21555012, 0.31      ]),
#   array([1.05864472, 0.21555012, 0.31      ])],
#  [array([0.04093669, 1.30579225, 0.03      ]),
#   array([0.84277303, 1.30579225, 0.13      ])],
#  [array([0.23460008, 0.46187044, 0.02      ]),
#   array([0.99670089, 0.46187044, 0.38      ])],
#  [array([0.09317997, 0.20644162, 0.68      ]),
#   array([1.31391246, 0.20644162, 0.85      ])],
#  [array([0.11551015, 0.75856628, 0.17      ]),
#   array([1.0449056 , 3.14192358, 0.48      ])],
#  [array([0.07618066, 0.29184507, 0.68      ]),
#   array([1.01771032, 0.29184507, 0.35      ])],
#  [array([0.01411222, 0.25327442, 0.87      ]),
#   array([0.7987022 , 0.25327442, 0.06      ])],
#  [array([0.23510384, 0.23708655, 0.32      ]),
#   array([1.19776179, 0.23708655, 0.46      ])],
#  [array([0.04348823, 0.11931493, 0.21      ]),
#   array([1.00632829, 0.11931493, 0.13      ])],
#  [array([ 0.21430035, 10.81284958,  0.17      ]),
#   array([1.00779163e+00, 1.00000000e+04, 4.80000000e-01])],
#  [array([0.05848279, 0.68090593, 0.45      ]),
#   array([1.26261457, 0.68090593, 0.1       ])],
#  [array([0.02170869, 0.15632411, 0.35      ]),
#   array([0.84562798, 0.15632411, 0.48      ])],
#  [array([0.0449996 , 0.13264743, 0.27      ]),
#   array([0.86444987, 0.15293369, 0.05      ])],
#  [array([0.01743714, 0.14627496, 0.41      ]),
#   array([0.77974211, 0.14627496, 0.06      ])],
#  [array([0.01127258, 0.15076292, 0.5       ]),
#   array([0.81101225, 0.17752749, 0.16      ])],
#  [array([0.2739951 , 0.16845855, 0.62      ]),
#   array([1.04458902, 0.16845855, 0.49      ])],
#  [array([0.03145716, 0.19712008, 0.75      ]),
#   array([0.88140681, 0.24551626, 0.15      ])],
#  [array([0.02564838, 1.64407722, 0.34      ]),
#   array([8.371174e-01, 1.000000e+04, 2.900000e-01])],
#  [array([0.06565991, 2.12824122, 0.03      ]),
#   array([1.01889599, 2.12824122, 0.29      ])],
#  [array([0.02645087, 0.40185546, 0.12      ]),
#   array([0.98348658, 0.40185546, 0.22      ])],
#  [array([1.58137073e-02, 1.00000000e+04, 5.00000000e-01]),
#   array([8.08176539e-01, 1.00000000e+04, 1.30000000e-01])],
#  [array([4.66970623e-02, 1.00000000e+04, 1.00000000e-01]),
#   array([8.8476598e-01, 1.0000000e+04, 3.7000000e-01])],
#  [array([0.25512642, 0.4498097 , 0.05      ]),
#   array([1.1383405 , 0.81755293, 0.1       ])],
#  [array([0.06286921, 0.4493837 , 0.32      ]),
#   array([0.94828634, 0.4493837 , 0.46      ])],
#  [array([0.00824388, 0.81309097, 0.14      ]),
#   array([0.76076434, 0.81309097, 0.48      ])],
#  [array([0.05633854, 6.10288901, 0.28      ]),
#   array([1.0053707 , 6.10288901, 0.44      ])],
#  [array([0.14947916, 0.30068364, 0.83      ]),
#   array([1.17972939, 0.30068364, 0.24      ])],
#  [array([0.109487  , 0.13806499, 0.3       ]),
#   array([1.08796762, 0.16018028, 0.2       ])],
#  [array([0.09558106, 0.24002319, 0.52      ]),
#   array([1.17726507, 0.24002319, 0.15      ])],
#  [array([0.01864487, 0.30131528, 0.88      ]),
#   array([0.87923653, 0.43126073, 0.55      ])],
#  [array([2.98561449e-02, 1.00000000e+04, 2.40000000e-01]),
#   array([1.03328238e+00, 1.00000000e+04, 4.80000000e-01])],
#  [array([0.21140859, 0.24842368, 0.38      ]),
#   array([1.02781878, 0.33053686, 0.35      ])],
#  [array([0.05391426, 0.68296891, 0.34      ]),
#   array([1.11846631, 0.68296891, 0.33      ])],
#  [array([0.20045506, 0.13498906, 0.2       ]),
#   array([1.24420174, 0.13498906, 0.3       ])],
#  [array([0.24198149, 0.12656207, 0.21      ]),
#   array([1.12914976, 0.12656207, 0.27      ])],
#  [array([0.0471371 , 0.19860545, 0.38      ]),
#   array([0.99664279, 0.24782481, 0.46      ])],
#  ...]

# %%
X = np.reshape(np.array(vect), (-1, 3))

# %%
y = np.reshape(np.array([[0, 1] for _ in range(8192)]), (8192*2))

# %%
y = np.reshape(y, 8192*2)

# %%
from skopt import BayesSearchCV
from sklearn.datasets import load_digits
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
from torch.autograd import Variable
from torchvision import datasets
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data_utils
import torch
import matplotlib.pyplot as plt

import os
import pandas as pd
import skimage.io
from skimage.transform import resize

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# разные режимы датасета 
DATA_MODES = ['train', 'val', 'test']
# работаем на видеокарте
DEVICE = torch.device("cuda")

EPOCHS = 1000
BATCH_SIZE = 256

# %%
class JustSigmoid(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Sequential(
                nn.Linear(3, 1)
            )
    def forward(self, x):
        return self.layer(x)

# %%
lean = JustSigmoid().to(DEVICE)
print(lean)
# Out:
# JustSigmoid(
#   (layer): Sequential(
#     (0): Linear(in_features=3, out_features=1, bias=True)
#   )
# )

# %%
from torch.utils.data import DataLoader, Dataset
criterion = F.mse_loss

optimizer = torch.optim.Adam(lean.parameters(), lr=0.001)
train_losses = []
val_losses = []
X = torch.Tensor(X)
y = torch.Tensor(y)
train_X, val_X, train_y, val_y = train_test_split(X, y, train_size=0.9)
# train_dataset = Dataset(train_X, train_y)
# val_dataset = Dataset(val_X, val_y)
train_loader = DataLoader(list(zip(train_X, train_y)), batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(list(zip(val_X, val_y)), batch_size=BATCH_SIZE, shuffle=True)

# %%
from tqdm import notebook

for epoch in notebook.tqdm(range(EPOCHS)):
    lean.train()
    train_losses_per_epoch = []
    for X_batch, y_batch in train_loader:
        torch.cuda.empty_cache()
        optimizer.zero_grad()
        calculated = torch.reshape(lean(torch.Tensor(X_batch).to(DEVICE)), (-1,))
        loss = criterion(calculated, torch.Tensor(y_batch).to(DEVICE))
        loss.backward()
        optimizer.step()
        train_losses_per_epoch.append(loss.item())

    train_losses.append(np.mean(train_losses_per_epoch))

    lean.eval()
    val_losses_per_epoch = []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            calculated = torch.reshape(lean(torch.Tensor(X_batch).to(DEVICE)), (-1,))
            loss = criterion(calculated, torch.Tensor(y_batch).to(DEVICE))
            val_losses_per_epoch.append(loss.item())

    val_losses.append(np.mean(val_losses_per_epoch))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
with torch.no_grad():
    calc = torch.reshape(lean(torch.Tensor([[0.03095769, 0.2211782 , 0.93], [0.9236934 , 0.19648128, 0.55]]).to(DEVICE)), (-1,))

# %%
calc
# Out:
# tensor([-0.0135,  0.8823], device='cuda:0')

# %%
torch.save(lean.state_dict(), 'weights/lean')

# %%
java = torch.jit.trace(lean, torch.Tensor(val_X).to(DEVICE))

# %%
java.save('./model1.zip')
